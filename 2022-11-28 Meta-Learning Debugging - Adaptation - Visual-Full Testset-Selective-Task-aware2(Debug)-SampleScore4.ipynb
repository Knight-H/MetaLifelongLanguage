# %%
import random, gc, os, pickle, csv, time

import datasets.utils
import models.utils
from models.cls_oml_ori_v2 import OML
from models.base_models_ori import LabelAwareReplayMemory

import numpy as np
import matplotlib.pyplot as plt

import higher
import torch
import torch.nn.functional as F
from torch.utils import data

# %% [markdown]
# # Constants

# %%
dataset_order_mapping = {
    1: [2, 0, 3, 1, 4],
    2: [3, 4, 0, 1, 2],
    3: [2, 4, 1, 3, 0],
    4: [0, 2, 1, 4, 3]
}
n_classes = 33
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
# model_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518612.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456804.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477968.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869765.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241546.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424113.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167637.pt"

# v. SR 
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695669.pt"
# v. SR Query
model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228.pt"

# memory_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518639_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456828_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477992_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869797_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241572_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424139_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167666_memory.pickle"
# v. SR 
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695692_memory.pickle"
# v. SR Query
memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854254_memory.pickle"

# For Sample Score
TRIM_ER = 500
TOTAL_EPOCH = 600
# new_memory_path, ext = os.path.splitext(memory_path)
# new_memory_path = new_memory_path + "_label" + ext

use_db_cache = True
cache_dir = 'tmp'

# %%
args = {
    "order": 1,
    "n_epochs": 1,
    "lr": 3e-5,
    "inner_lr": 0.001*10,
    "meta_lr": 3e-5,
    "model": "bert",
    "learner": "oml",
    "mini_batch_size": 16,
    "updates": 5*1,
    "write_prob": 1.0,
    "max_length": 448,
    "seed": 42,
    "replay_rate": 0.01,
    "replay_every": 9600
}
updates = args["updates"]
mini_batch_size = args["mini_batch_size"]
order = args["order"]

# %%
torch.manual_seed(args["seed"])
random.seed(args["seed"])
np.random.seed(args["seed"])

# %% [markdown]
# # Load Dataset

# %%
print('Loading the datasets')
test_datasets = []
for dataset_id in dataset_order_mapping[order]:
    test_dataset_file = os.path.join(cache_dir, f"{dataset_id}.cache")
    if os.path.exists(test_dataset_file):
        with open(test_dataset_file, 'rb') as f:
            test_dataset = pickle.load(f)
    else:
        test_dataset = datasets.utils.get_dataset_test("", dataset_id)
        print('Loaded {}'.format(test_dataset.__class__.__name__))
        test_dataset = datasets.utils.offset_labels(test_dataset)
        pickle.dump(test_dataset, open( test_dataset_file, "wb" ), protocol=pickle.HIGHEST_PROTOCOL)
        print(f"Pickle saved at {test_dataset_file}")
    test_datasets.append(test_dataset)
print('Finished loading all the datasets')
# Out:
# Loading the datasets
# Finished loading all the datasets

# %% [markdown]
# # Load Model

# %%
learner = OML(device=device, n_classes=n_classes, **args)
print('Using {} as learner'.format(learner.__class__.__name__))
learner.load_model(model_path)
with open(memory_path, 'rb') as f:
#     learner.memory = pickle.load(f)
    memory_buffer = pickle.load(f)
# Out:
# 2022-11-28 17:04:26,077 - transformers.tokenization_utils_base - INFO - loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2022-11-28 17:04:27,330 - transformers.configuration_utils - INFO - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2022-11-28 17:04:27,334 - transformers.configuration_utils - INFO - Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2022-11-28 17:04:28,312 - transformers.modeling_utils - INFO - loading weights file https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2022-11-28 17:04:31,472 - transformers.modeling_utils - INFO - All model checkpoint weights were used when initializing BertModel.
#
# 2022-11-28 17:04:31,475 - transformers.modeling_utils - INFO - All the weights of BertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use BertModel for predictions without further training.
# 2022-11-28 17:04:36,365 - OML-Log - INFO - Loaded TransformerRLN as RLN
# 2022-11-28 17:04:36,369 - OML-Log - INFO - Loaded LinearPLN as PLN
# Using OML as learner

# %%
# Setting up task dict for task-aware
memory_buffer.task_dict = {
    0: list(range(5, 9)), # AG
    1: list(range(0, 5)), # Amazon
    2: list(range(0, 5)), # Yelp
    3: list(range(9, 23)), # DBPedia
    4: list(range(23, 33)), # Yahoo
}

# %%
# label to task converter - hack, since normally we would just use the task token/identifier
def get_task_from_label(label_idx, task_dict):
    for task_idx, class_list in task_dict.items():
        if label_idx in class_list: return task_idx
    return -1
print(get_task_from_label(8, memory_buffer.task_dict))
# Find mode: https://stackoverflow.com/questions/10797819/finding-the-mode-of-a-list
def mode(array):
    return max(array, key = array.count)
# label list to task id
def get_task_from_label_list(label_list, task_dict):
    return mode([get_task_from_label(label, task_dict) for label in label_list])
print(get_task_from_label_list([1,2,32,1,4,2,0], memory_buffer.task_dict))
# Out:
# 0
# 1

# %%
dataclass_mapper = {
    "AGNewsDataset": 0,
    "AmazonDataset": 1,
    "YelpDataset": 2,
    "DBPediaDataset": 3,
    "YahooAnswersDataset": 4
}
dataclass_mapper["AGNewsDataset"]
# Out:
# 0

# %%
# Trim buffer dict to 1000 per class
memory_buffer.reset_meta()
memory_buffer.trim_buffer_dict(limit_n=TRIM_ER)

# %%
len(memory_buffer.buffer_dict[0])
# Out:
# 500

# %% [markdown]
# # Get Scores for each sample in ER

# %%
# Returns loss,preds,labels, labels_conf
def validate(fpln, validation_set):
    all_valid_preds, all_valid_labels, all_valid_label_conf = [], [], []
    
    for valid_text, valid_labels, _ in validation_set:        
        valid_labels = torch.tensor(valid_labels).to(device)
        valid_input_dict = learner.rln.encode_text(valid_text)
        valid_repr = learner.rln(valid_input_dict)
        valid_output = fpln(valid_repr) # Output has size of torch.Size([16, 33]) [BATCH, CLASSES]
        valid_loss = learner.loss_fn(valid_output, valid_labels)
        valid_loss = valid_loss.item()

        # output.detach().max(-1) max on each Batch, which will return [0] max, [1] indices
        valid_output_softmax = F.softmax(valid_output, -1)
        valid_label_conf = valid_output_softmax[np.arange(len(valid_output_softmax)), valid_labels] # Select labels in the softmax of 33 classes

        valid_pred = models.utils.make_prediction(valid_output.detach())
        
        
        # Put in things to return
        # all_valid_losses.extend(valid_loss)
        all_valid_preds.extend(valid_pred.tolist())
        all_valid_labels.extend(valid_labels.tolist())
        all_valid_label_conf.extend(valid_label_conf.tolist())
    return all_valid_preds, all_valid_labels, all_valid_label_conf # removed loss, since no need

# Compare diff results between the unadapted vs adapted
# Returns Dictionary of class_idx -> [ a - n, ...  ] for each i (300). Can np.sum() or np.mean() later
# validate_labels = The labels (Shared)
# validate_label_conf_0 = The label conf of validate_0
# validate_label_conf_n = The label conf of validate_n
def calculate_diff_class(validate_labels, validate_label_conf_0, validate_label_conf_n, initial_dict={}, return_dict=True): 
    # Adapted confs - NonAdapted Confs (a-n)
    validate_label_conf_diff = np.array(validate_label_conf_n) - np.array(validate_label_conf_0)
    
    if return_dict:
        # The dictionary to return  class_idx -> [ a - n, ...  ] 
        return_dict = initial_dict.copy()
        for i, class_idx in enumerate(validate_labels):
            # Filter conf_diff by class
            return_dict[class_idx] = return_dict.get(class_idx, []) + [validate_label_conf_diff[i]]
        return return_dict
    
    return validate_label_conf_diff

# %% [markdown]
# Every Task, we do `16*1 = 16` batch , there are 5 tasks so `16*5 = 80` per epoch (takes around 0.2s per task ~1s). So we need to do it 300 times so that it will be ~5 minutes (300s) and it means `80*300 = 24,000`, and hopefully support will be around  `16*300/300 ~ 16` per sample.
#
# ```
# Adapt Time: 0.165510892868042 s
# Support set metrics: Loss = 0.3509, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# ```
#
# ```
# For 600 Epoch
# Total Scoring Time: 29.0 m
# ```

# %%
TIC_score = time.time()
for epoch in range(TOTAL_EPOCH):
    print(f"This is epoch {epoch}/{TOTAL_EPOCH}")
    learner.rln.eval()
    learner.pln.train()
    
    for task_idx in memory_buffer.task_dict.keys():
        support_set = []
        #for _ in range(updates):
        for _ in range(1): # CHANGE THIS to 1 minibatch.
            text, labels, indexes = memory_buffer.read_batch_task(batch_size=mini_batch_size, task_idx=task_idx, \
                                                                  with_index=True)
            support_set.append((text, labels, indexes))
        
        with higher.innerloop_ctx(learner.pln, learner.inner_optimizer,
                                  copy_initial_weights=False, track_higher_grads=False) as (fpln, diffopt):
            
            # Test validation_set BEFORE the update (update=0)
            with torch.no_grad():
                all_valid_preds_0, all_valid_labels_0, all_valid_label_conf_0  = validate(fpln, support_set)
            
            INNER_tic = time.time()
            # Inner loop
            task_predictions, task_labels, task_indexes = [], [], []
            support_loss = []
            for text, labels, indexes in support_set:
                labels = torch.tensor(labels).to(device)
                input_dict = learner.rln.encode_text(text)
                _repr = learner.rln(input_dict)
                output = fpln(_repr)
                loss = learner.loss_fn(output, labels)
                diffopt.step(loss)
                pred = models.utils.make_prediction(output.detach())
                support_loss.append(loss.item())
                task_predictions.extend(pred.tolist())
                task_labels.extend(labels.tolist())
                task_indexes.extend(indexes)
            INNER_toc = time.time() - INNER_tic
            print("Adapt Time: "+ str(INNER_toc) +" s" )
            
            # Test validation_set AFTER ALL the update
            with torch.no_grad():
                all_valid_preds_n, all_valid_labels_n, all_valid_label_conf_n = validate(fpln, support_set)
                diff_list = calculate_diff_class(all_valid_labels_0, all_valid_label_conf_0, all_valid_label_conf_n, return_dict=False)
                memory_buffer.update_meta(all_valid_labels_0, task_indexes, diff_list)

            acc, prec, rec, f1 = models.utils.calculate_metrics(task_predictions, task_labels)

            print('Support set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                        'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(support_loss), acc, prec, rec, f1))

TOC_score = time.time() - TIC_score 
print("Total Scoring Time: "+ str(TOC_score//60) +" m" )
# Out:
# This is epoch 0/600
# Adapt Time: 0.1737689971923828 s
# Support set metrics: Loss = 0.1472, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2063593864440918 s
# Support set metrics: Loss = 1.1926, accuracy = 0.5625, precision = 0.6867, recall = 0.5500, F1 score = 0.5743
# Adapt Time: 0.21673583984375 s
# Support set metrics: Loss = 1.0968, accuracy = 0.5625, precision = 0.6333, recall = 0.5667, F1 score = 0.5571
# Adapt Time: 0.1852414608001709 s
# Support set metrics: Loss = 0.0077, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1921062469482422 s
# Support set metrics: Loss = 0.4191, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 1/600
# Adapt Time: 0.17055368423461914 s
# Support set metrics: Loss = 0.3647, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2014784812927246 s
# Support set metrics: Loss = 0.6718, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7848
# Adapt Time: 0.20186853408813477 s
# Support set metrics: Loss = 1.2023, accuracy = 0.4375, precision = 0.4167, recall = 0.4500, F1 score = 0.4229
# Adapt Time: 0.18223142623901367 s
# Support set metrics: Loss = 0.0081, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22060799598693848 s
# Support set metrics: Loss = 1.1378, accuracy = 0.6250, precision = 0.5833, recall = 0.6000, F1 score = 0.5767
# This is epoch 2/600
# Adapt Time: 0.16829943656921387 s
# Support set metrics: Loss = 0.2392, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.2264997959136963 s
# Support set metrics: Loss = 1.1036, accuracy = 0.6250, precision = 0.8333, recall = 0.6333, F1 score = 0.6676
# Adapt Time: 0.19852900505065918 s
# Support set metrics: Loss = 0.9678, accuracy = 0.6250, precision = 0.6000, recall = 0.6000, F1 score = 0.5886
# Adapt Time: 0.17848968505859375 s
# Support set metrics: Loss = 0.0622, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.24883675575256348 s
# Support set metrics: Loss = 0.7699, accuracy = 0.8125, precision = 0.8167, recall = 0.8000, F1 score = 0.7967
# This is epoch 3/600
# Adapt Time: 0.17825078964233398 s
# Support set metrics: Loss = 0.1981, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21120691299438477 s
# Support set metrics: Loss = 0.7851, accuracy = 0.7500, precision = 0.8200, recall = 0.7500, F1 score = 0.7476
# Adapt Time: 0.18722105026245117 s
# Support set metrics: Loss = 0.7385, accuracy = 0.7500, precision = 0.8400, recall = 0.7500, F1 score = 0.7314
# Adapt Time: 0.17612791061401367 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19262003898620605 s
# Support set metrics: Loss = 1.1991, accuracy = 0.6250, precision = 0.5417, recall = 0.6000, F1 score = 0.5367
# This is epoch 4/600
# Adapt Time: 0.1651458740234375 s
# Support set metrics: Loss = 0.2000, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8611
# Adapt Time: 0.19466853141784668 s
# Support set metrics: Loss = 0.7032, accuracy = 0.8125, precision = 0.8800, recall = 0.8000, F1 score = 0.7878
# Adapt Time: 0.20143556594848633 s
# Support set metrics: Loss = 1.2164, accuracy = 0.5625, precision = 0.6333, recall = 0.5667, F1 score = 0.5886
# Adapt Time: 0.1701810359954834 s
# Support set metrics: Loss = 0.4112, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.20035839080810547 s
# Support set metrics: Loss = 0.7737, accuracy = 0.8125, precision = 0.8400, recall = 0.8000, F1 score = 0.7905
# This is epoch 5/600
# Adapt Time: 0.16830682754516602 s
# Support set metrics: Loss = 0.3020, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.18735837936401367 s
# Support set metrics: Loss = 0.9269, accuracy = 0.6250, precision = 0.6700, recall = 0.6167, F1 score = 0.6000
# Adapt Time: 0.1935255527496338 s
# Support set metrics: Loss = 1.1292, accuracy = 0.4375, precision = 0.4333, recall = 0.4167, F1 score = 0.4205
# Adapt Time: 0.1744532585144043 s
# Support set metrics: Loss = 0.0078, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19544386863708496 s
# Support set metrics: Loss = 1.2939, accuracy = 0.6875, precision = 0.7667, recall = 0.7500, F1 score = 0.6967
# This is epoch 6/600
# Adapt Time: 0.17205500602722168 s
# Support set metrics: Loss = 0.4225, accuracy = 0.8125, precision = 0.8167, recall = 0.8125, F1 score = 0.8016
# Adapt Time: 0.22861504554748535 s
# Support set metrics: Loss = 0.6410, accuracy = 0.7500, precision = 0.7833, recall = 0.7667, F1 score = 0.7600
# Adapt Time: 0.2054750919342041 s
# Support set metrics: Loss = 0.8782, accuracy = 0.5625, precision = 0.5667, recall = 0.5333, F1 score = 0.5467
# Adapt Time: 0.17559099197387695 s
# Support set metrics: Loss = 0.0070, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19714689254760742 s
# Support set metrics: Loss = 0.8227, accuracy = 0.7500, precision = 0.7667, recall = 0.8000, F1 score = 0.7467
# This is epoch 7/600
# Adapt Time: 0.17669129371643066 s
# Support set metrics: Loss = 0.0724, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20873761177062988 s
# Support set metrics: Loss = 0.5219, accuracy = 0.8125, precision = 0.8333, recall = 0.8167, F1 score = 0.8148
# Adapt Time: 0.19494843482971191 s
# Support set metrics: Loss = 1.4472, accuracy = 0.3125, precision = 0.2333, recall = 0.3000, F1 score = 0.2556
# Adapt Time: 0.17421483993530273 s
# Support set metrics: Loss = 0.0080, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19563841819763184 s
# Support set metrics: Loss = 0.6119, accuracy = 0.7500, precision = 0.7000, recall = 0.7500, F1 score = 0.7200
# This is epoch 8/600
# Adapt Time: 0.16911005973815918 s
# Support set metrics: Loss = 0.2780, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.22705364227294922 s
# Support set metrics: Loss = 0.8879, accuracy = 0.6250, precision = 0.5133, recall = 0.6000, F1 score = 0.5411
# Adapt Time: 0.2076396942138672 s
# Support set metrics: Loss = 1.0935, accuracy = 0.5625, precision = 0.5833, recall = 0.5667, F1 score = 0.5714
# Adapt Time: 0.17842435836791992 s
# Support set metrics: Loss = 0.0063, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19562077522277832 s
# Support set metrics: Loss = 0.8104, accuracy = 0.8125, precision = 0.7667, recall = 0.8000, F1 score = 0.7633
# This is epoch 9/600
# Adapt Time: 0.16428899765014648 s
# Support set metrics: Loss = 0.1146, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1868879795074463 s
# Support set metrics: Loss = 0.8829, accuracy = 0.7500, precision = 0.7833, recall = 0.7500, F1 score = 0.7505
# Adapt Time: 0.22111964225769043 s
# Support set metrics: Loss = 0.6567, accuracy = 0.8125, precision = 0.8267, recall = 0.8000, F1 score = 0.8044
# Adapt Time: 0.16983819007873535 s
# Support set metrics: Loss = 0.0052, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1978015899658203 s
# Support set metrics: Loss = 0.5936, accuracy = 0.8125, precision = 0.8000, recall = 0.8000, F1 score = 0.7667
# This is epoch 10/600
# Adapt Time: 0.1691148281097412 s
# Support set metrics: Loss = 0.0388, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.195573091506958 s
# Support set metrics: Loss = 0.9614, accuracy = 0.5625, precision = 0.6133, recall = 0.5667, F1 score = 0.5610
# Adapt Time: 0.20502614974975586 s
# Support set metrics: Loss = 0.8999, accuracy = 0.6875, precision = 0.7400, recall = 0.6667, F1 score = 0.6778
# Adapt Time: 0.17255353927612305 s
# Support set metrics: Loss = 0.0078, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1985323429107666 s
# Support set metrics: Loss = 0.8616, accuracy = 0.7500, precision = 0.6500, recall = 0.7500, F1 score = 0.6833
# This is epoch 11/600
# Adapt Time: 0.16468572616577148 s
# Support set metrics: Loss = 0.1213, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20013427734375 s
# Support set metrics: Loss = 0.6563, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7429
# Adapt Time: 0.2014601230621338 s
# Support set metrics: Loss = 0.8190, accuracy = 0.7500, precision = 0.7833, recall = 0.7333, F1 score = 0.7190
# Adapt Time: 0.17616605758666992 s
# Support set metrics: Loss = 0.0068, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22463560104370117 s
# Support set metrics: Loss = 1.1994, accuracy = 0.5625, precision = 0.3333, recall = 0.5000, F1 score = 0.3933
# This is epoch 12/600
# Adapt Time: 0.17286372184753418 s
# Support set metrics: Loss = 0.1102, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19372105598449707 s
# Support set metrics: Loss = 0.7863, accuracy = 0.7500, precision = 0.8500, recall = 0.7500, F1 score = 0.7529
# Adapt Time: 0.20786404609680176 s
# Support set metrics: Loss = 0.6144, accuracy = 0.7500, precision = 0.7867, recall = 0.7333, F1 score = 0.7167
# Adapt Time: 0.17989659309387207 s
# Support set metrics: Loss = 0.0102, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22504281997680664 s
# Support set metrics: Loss = 0.4512, accuracy = 0.8750, precision = 0.7500, recall = 0.8000, F1 score = 0.7667
# This is epoch 13/600
# Adapt Time: 0.16999363899230957 s
# Support set metrics: Loss = 0.8559, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7500
# Adapt Time: 0.20363593101501465 s
# Support set metrics: Loss = 0.9650, accuracy = 0.6875, precision = 0.8000, recall = 0.6833, F1 score = 0.7048
# Adapt Time: 0.2080669403076172 s
# Support set metrics: Loss = 0.7159, accuracy = 0.6250, precision = 0.5733, recall = 0.6167, F1 score = 0.5767
# Adapt Time: 0.18323731422424316 s
# Support set metrics: Loss = 0.0062, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1998767852783203 s
# Support set metrics: Loss = 0.4108, accuracy = 0.9375, precision = 0.9667, recall = 0.9500, F1 score = 0.9467
# This is epoch 14/600
# Adapt Time: 0.16869425773620605 s
# Support set metrics: Loss = 0.5907, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.1973247528076172 s
# Support set metrics: Loss = 0.9613, accuracy = 0.5625, precision = 0.6400, recall = 0.5333, F1 score = 0.5443
# Adapt Time: 0.1963033676147461 s
# Support set metrics: Loss = 1.0215, accuracy = 0.4375, precision = 0.4133, recall = 0.4500, F1 score = 0.4143
# Adapt Time: 0.16761493682861328 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19225430488586426 s
# Support set metrics: Loss = 0.6236, accuracy = 0.7500, precision = 0.7000, recall = 0.7000, F1 score = 0.6867
# This is epoch 15/600
# Adapt Time: 0.16745281219482422 s
# Support set metrics: Loss = 0.2315, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.18325185775756836 s
# Support set metrics: Loss = 0.9514, accuracy = 0.6250, precision = 0.6000, recall = 0.6167, F1 score = 0.6014
# Adapt Time: 0.18480825424194336 s
# Support set metrics: Loss = 0.7786, accuracy = 0.6875, precision = 0.6933, recall = 0.6667, F1 score = 0.6711
# Adapt Time: 0.17096948623657227 s
# Support set metrics: Loss = 0.0066, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19921612739562988 s
# Support set metrics: Loss = 0.5856, accuracy = 0.8125, precision = 0.8500, recall = 0.8500, F1 score = 0.8333
# This is epoch 16/600
# Adapt Time: 0.16248536109924316 s
# Support set metrics: Loss = 0.4143, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.19596481323242188 s
# Support set metrics: Loss = 1.0033, accuracy = 0.6250, precision = 0.6867, recall = 0.6333, F1 score = 0.6300
# Adapt Time: 0.21542787551879883 s
# Support set metrics: Loss = 1.0958, accuracy = 0.6250, precision = 0.6800, recall = 0.6333, F1 score = 0.6333
# Adapt Time: 0.1747453212738037 s
# Support set metrics: Loss = 0.4424, accuracy = 0.8750, precision = 0.7976, recall = 0.8571, F1 score = 0.8190
# Adapt Time: 0.21132683753967285 s
# Support set metrics: Loss = 1.0581, accuracy = 0.6875, precision = 0.6667, recall = 0.7000, F1 score = 0.6467
# This is epoch 17/600
# Adapt Time: 0.16910076141357422 s
# Support set metrics: Loss = 0.6435, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.21513676643371582 s
# Support set metrics: Loss = 0.8550, accuracy = 0.6875, precision = 0.7033, recall = 0.6833, F1 score = 0.6781
# Adapt Time: 0.21322345733642578 s
# Support set metrics: Loss = 0.8097, accuracy = 0.7500, precision = 0.7700, recall = 0.7500, F1 score = 0.7329
# Adapt Time: 0.17351031303405762 s
# Support set metrics: Loss = 0.0095, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22526812553405762 s
# Support set metrics: Loss = 0.3137, accuracy = 0.9375, precision = 0.8667, recall = 0.9000, F1 score = 0.8800
# This is epoch 18/600
# Adapt Time: 0.17246055603027344 s
# Support set metrics: Loss = 0.2294, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.18909382820129395 s
# Support set metrics: Loss = 1.5051, accuracy = 0.3750, precision = 0.5000, recall = 0.3667, F1 score = 0.4000
# Adapt Time: 0.2448594570159912 s
# Support set metrics: Loss = 0.9116, accuracy = 0.4375, precision = 0.4333, recall = 0.4333, F1 score = 0.4286
# Adapt Time: 0.19144797325134277 s
# Support set metrics: Loss = 0.0083, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20912623405456543 s
# Support set metrics: Loss = 1.1283, accuracy = 0.8125, precision = 0.8500, recall = 0.8000, F1 score = 0.8000
# This is epoch 19/600
# Adapt Time: 0.1663682460784912 s
# Support set metrics: Loss = 0.1990, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.18996286392211914 s
# Support set metrics: Loss = 0.9492, accuracy = 0.5000, precision = 0.5800, recall = 0.5167, F1 score = 0.4943
# Adapt Time: 0.21744084358215332 s
# Support set metrics: Loss = 1.4867, accuracy = 0.3125, precision = 0.2571, recall = 0.3333, F1 score = 0.2743
# Adapt Time: 0.17925190925598145 s
# Support set metrics: Loss = 0.0088, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2100069522857666 s
# Support set metrics: Loss = 1.0634, accuracy = 0.6875, precision = 0.6167, recall = 0.7000, F1 score = 0.6267
# This is epoch 20/600
# Adapt Time: 0.16868185997009277 s
# Support set metrics: Loss = 0.2245, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19097280502319336 s
# Support set metrics: Loss = 0.6409, accuracy = 0.7500, precision = 0.8300, recall = 0.7500, F1 score = 0.7500
# Adapt Time: 0.20696568489074707 s
# Support set metrics: Loss = 0.4702, accuracy = 0.8750, precision = 0.9200, recall = 0.8667, F1 score = 0.8500
# Adapt Time: 0.17476892471313477 s
# Support set metrics: Loss = 0.0058, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18219256401062012 s
# Support set metrics: Loss = 0.9924, accuracy = 0.6875, precision = 0.5500, recall = 0.6500, F1 score = 0.5733
# This is epoch 21/600
# Adapt Time: 0.16734600067138672 s
# Support set metrics: Loss = 0.3731, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20386505126953125 s
# Support set metrics: Loss = 1.1030, accuracy = 0.4375, precision = 0.4333, recall = 0.4500, F1 score = 0.4348
# Adapt Time: 0.22165131568908691 s
# Support set metrics: Loss = 1.0366, accuracy = 0.6250, precision = 0.6190, recall = 0.6333, F1 score = 0.5943
# Adapt Time: 0.1679389476776123 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19219350814819336 s
# Support set metrics: Loss = 1.4406, accuracy = 0.6250, precision = 0.6500, recall = 0.6500, F1 score = 0.6167
# This is epoch 22/600
# Adapt Time: 0.1664738655090332 s
# Support set metrics: Loss = 0.1320, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19668269157409668 s
# Support set metrics: Loss = 1.1721, accuracy = 0.5000, precision = 0.5200, recall = 0.5000, F1 score = 0.4900
# Adapt Time: 0.188079833984375 s
# Support set metrics: Loss = 0.7430, accuracy = 0.7500, precision = 0.8033, recall = 0.7500, F1 score = 0.7533
# Adapt Time: 0.17727398872375488 s
# Support set metrics: Loss = 0.0162, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2167813777923584 s
# Support set metrics: Loss = 0.9505, accuracy = 0.6875, precision = 0.6333, recall = 0.7000, F1 score = 0.6600
# This is epoch 23/600
# Adapt Time: 0.17246103286743164 s
# Support set metrics: Loss = 0.1702, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2080075740814209 s
# Support set metrics: Loss = 1.2940, accuracy = 0.6250, precision = 0.7333, recall = 0.6333, F1 score = 0.6476
# Adapt Time: 0.20990347862243652 s
# Support set metrics: Loss = 1.0517, accuracy = 0.4375, precision = 0.5633, recall = 0.4333, F1 score = 0.4514
# Adapt Time: 0.18964672088623047 s
# Support set metrics: Loss = 0.0074, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20729684829711914 s
# Support set metrics: Loss = 0.5913, accuracy = 0.8125, precision = 0.7667, recall = 0.7500, F1 score = 0.7467
# This is epoch 24/600
# Adapt Time: 0.17338275909423828 s
# Support set metrics: Loss = 0.4770, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8667
# Adapt Time: 0.20389032363891602 s
# Support set metrics: Loss = 0.7753, accuracy = 0.5625, precision = 0.5200, recall = 0.5500, F1 score = 0.5333
# Adapt Time: 0.20727038383483887 s
# Support set metrics: Loss = 0.6974, accuracy = 0.8125, precision = 0.8600, recall = 0.8000, F1 score = 0.7806
# Adapt Time: 0.18150877952575684 s
# Support set metrics: Loss = 0.0192, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20212888717651367 s
# Support set metrics: Loss = 0.7992, accuracy = 0.8750, precision = 0.8333, recall = 0.8500, F1 score = 0.8267
# This is epoch 25/600
# Adapt Time: 0.16988849639892578 s
# Support set metrics: Loss = 0.1015, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20442819595336914 s
# Support set metrics: Loss = 1.2829, accuracy = 0.5625, precision = 0.6167, recall = 0.5833, F1 score = 0.5790
# Adapt Time: 0.1842358112335205 s
# Support set metrics: Loss = 0.8551, accuracy = 0.6250, precision = 0.6467, recall = 0.6167, F1 score = 0.6181
# Adapt Time: 0.17472434043884277 s
# Support set metrics: Loss = 0.4217, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.18191838264465332 s
# Support set metrics: Loss = 0.7722, accuracy = 0.6875, precision = 0.7667, recall = 0.7500, F1 score = 0.7133
# This is epoch 26/600
# Adapt Time: 0.17166852951049805 s
# Support set metrics: Loss = 0.0848, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2008066177368164 s
# Support set metrics: Loss = 0.5722, accuracy = 0.7500, precision = 0.7500, recall = 0.7333, F1 score = 0.7257
# Adapt Time: 0.21723270416259766 s
# Support set metrics: Loss = 1.0505, accuracy = 0.5625, precision = 0.6467, recall = 0.5667, F1 score = 0.5743
# Adapt Time: 0.16762280464172363 s
# Support set metrics: Loss = 0.0053, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18564844131469727 s
# Support set metrics: Loss = 0.9636, accuracy = 0.7500, precision = 0.7333, recall = 0.7500, F1 score = 0.6933
# This is epoch 27/600
# Adapt Time: 0.16550254821777344 s
# Support set metrics: Loss = 0.1931, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20195436477661133 s
# Support set metrics: Loss = 0.6665, accuracy = 0.8125, precision = 0.8000, recall = 0.8000, F1 score = 0.7943
# Adapt Time: 0.19785571098327637 s
# Support set metrics: Loss = 0.8895, accuracy = 0.6250, precision = 0.6667, recall = 0.6000, F1 score = 0.5876
# Adapt Time: 0.17023229598999023 s
# Support set metrics: Loss = 0.4886, accuracy = 0.8750, precision = 0.8571, recall = 0.8929, F1 score = 0.8690
# Adapt Time: 0.22513413429260254 s
# Support set metrics: Loss = 1.3022, accuracy = 0.7500, precision = 0.8167, recall = 0.8000, F1 score = 0.7800
# This is epoch 28/600
# Adapt Time: 0.1639723777770996 s
# Support set metrics: Loss = 0.2235, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20126867294311523 s
# Support set metrics: Loss = 0.4509, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20351099967956543 s
# Support set metrics: Loss = 0.8918, accuracy = 0.6875, precision = 0.7000, recall = 0.6833, F1 score = 0.6757
# Adapt Time: 0.17826557159423828 s
# Support set metrics: Loss = 0.1075, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.2107546329498291 s
# Support set metrics: Loss = 0.4119, accuracy = 0.9375, precision = 0.9667, recall = 0.9500, F1 score = 0.9467
# This is epoch 29/600
# Adapt Time: 0.16670632362365723 s
# Support set metrics: Loss = 0.2967, accuracy = 0.8125, precision = 0.8375, recall = 0.8125, F1 score = 0.8185
# Adapt Time: 0.21955323219299316 s
# Support set metrics: Loss = 1.1585, accuracy = 0.4375, precision = 0.4000, recall = 0.4333, F1 score = 0.4095
# Adapt Time: 0.18862366676330566 s
# Support set metrics: Loss = 0.9806, accuracy = 0.6875, precision = 0.6767, recall = 0.6667, F1 score = 0.6559
# Adapt Time: 0.1744680404663086 s
# Support set metrics: Loss = 0.1951, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.24161195755004883 s
# Support set metrics: Loss = 0.4139, accuracy = 0.8750, precision = 0.8000, recall = 0.8500, F1 score = 0.8167
# This is epoch 30/600
# Adapt Time: 0.16776132583618164 s
# Support set metrics: Loss = 0.5976, accuracy = 0.6875, precision = 0.6875, recall = 0.6875, F1 score = 0.6875
# Adapt Time: 0.1991264820098877 s
# Support set metrics: Loss = 1.5276, accuracy = 0.5000, precision = 0.6750, recall = 0.5000, F1 score = 0.5024
# Adapt Time: 0.25846290588378906 s
# Support set metrics: Loss = 1.2579, accuracy = 0.4375, precision = 0.4933, recall = 0.4500, F1 score = 0.4133
# Adapt Time: 0.17812728881835938 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2102055549621582 s
# Support set metrics: Loss = 1.3556, accuracy = 0.4375, precision = 0.4000, recall = 0.4500, F1 score = 0.4167
# This is epoch 31/600
# Adapt Time: 0.17002105712890625 s
# Support set metrics: Loss = 0.3500, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8786
# Adapt Time: 0.1833209991455078 s
# Support set metrics: Loss = 0.9534, accuracy = 0.6250, precision = 0.6600, recall = 0.6000, F1 score = 0.5921
# Adapt Time: 0.19235014915466309 s
# Support set metrics: Loss = 0.5499, accuracy = 0.8125, precision = 0.8000, recall = 0.8167, F1 score = 0.8014
# Adapt Time: 0.17473435401916504 s
# Support set metrics: Loss = 0.0055, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.17818236351013184 s
# Support set metrics: Loss = 0.5191, accuracy = 0.9375, precision = 0.8667, recall = 0.9000, F1 score = 0.8800
# This is epoch 32/600
# Adapt Time: 0.16516971588134766 s
# Support set metrics: Loss = 0.0663, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2230684757232666 s
# Support set metrics: Loss = 0.7019, accuracy = 0.5625, precision = 0.5367, recall = 0.5500, F1 score = 0.5314
# Adapt Time: 0.2219405174255371 s
# Support set metrics: Loss = 0.4585, accuracy = 0.9375, precision = 0.9500, recall = 0.9333, F1 score = 0.9314
# Adapt Time: 0.16827750205993652 s
# Support set metrics: Loss = 0.0128, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20497345924377441 s
# Support set metrics: Loss = 0.6963, accuracy = 0.7500, precision = 0.6333, recall = 0.7000, F1 score = 0.6600
# This is epoch 33/600
# Adapt Time: 0.16562223434448242 s
# Support set metrics: Loss = 0.1671, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.17135405540466309 s
# Support set metrics: Loss = 0.6428, accuracy = 0.6875, precision = 0.7000, recall = 0.6833, F1 score = 0.6857
# Adapt Time: 0.19582748413085938 s
# Support set metrics: Loss = 0.4297, accuracy = 0.8125, precision = 0.8600, recall = 0.8000, F1 score = 0.7806
# Adapt Time: 0.17836284637451172 s
# Support set metrics: Loss = 0.0079, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20659422874450684 s
# Support set metrics: Loss = 0.7411, accuracy = 0.8750, precision = 0.9333, recall = 0.9000, F1 score = 0.8833
# This is epoch 34/600
# Adapt Time: 0.17269611358642578 s
# Support set metrics: Loss = 0.4968, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.22520089149475098 s
# Support set metrics: Loss = 0.6615, accuracy = 0.8125, precision = 0.8333, recall = 0.8167, F1 score = 0.8148
# Adapt Time: 0.21340036392211914 s
# Support set metrics: Loss = 0.6693, accuracy = 0.6875, precision = 0.5900, recall = 0.6667, F1 score = 0.6092
# Adapt Time: 0.18024992942810059 s
# Support set metrics: Loss = 0.0240, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22648859024047852 s
# Support set metrics: Loss = 0.4636, accuracy = 0.8750, precision = 0.9500, recall = 0.9000, F1 score = 0.9000
# This is epoch 35/600
# Adapt Time: 0.17006325721740723 s
# Support set metrics: Loss = 0.2345, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.22509074211120605 s
# Support set metrics: Loss = 0.7854, accuracy = 0.8125, precision = 0.8167, recall = 0.8333, F1 score = 0.8190
# Adapt Time: 0.20201849937438965 s
# Support set metrics: Loss = 0.5655, accuracy = 0.8125, precision = 0.7000, recall = 0.8000, F1 score = 0.7333
# Adapt Time: 0.1743166446685791 s
# Support set metrics: Loss = 0.0179, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20202326774597168 s
# Support set metrics: Loss = 0.6638, accuracy = 0.7500, precision = 0.7000, recall = 0.7000, F1 score = 0.7000
# This is epoch 36/600
# Adapt Time: 0.17068696022033691 s
# Support set metrics: Loss = 0.2269, accuracy = 0.8750, precision = 0.9500, recall = 0.8750, F1 score = 0.8889
# Adapt Time: 0.20518183708190918 s
# Support set metrics: Loss = 0.7702, accuracy = 0.7500, precision = 0.7667, recall = 0.7500, F1 score = 0.7481
# Adapt Time: 0.20352745056152344 s
# Support set metrics: Loss = 1.1548, accuracy = 0.5625, precision = 0.7133, recall = 0.5667, F1 score = 0.5476
# Adapt Time: 0.1831345558166504 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2098710536956787 s
# Support set metrics: Loss = 0.6987, accuracy = 0.7500, precision = 0.6500, recall = 0.7500, F1 score = 0.6633
# This is epoch 37/600
# Adapt Time: 0.16916298866271973 s
# Support set metrics: Loss = 0.1429, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19868111610412598 s
# Support set metrics: Loss = 1.2101, accuracy = 0.3750, precision = 0.4500, recall = 0.3667, F1 score = 0.3981
# Adapt Time: 0.1946711540222168 s
# Support set metrics: Loss = 1.2184, accuracy = 0.3750, precision = 0.4333, recall = 0.3833, F1 score = 0.3911
# Adapt Time: 0.17821288108825684 s
# Support set metrics: Loss = 0.0047, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20701026916503906 s
# Support set metrics: Loss = 0.7495, accuracy = 0.7500, precision = 0.6167, recall = 0.7000, F1 score = 0.6467
# This is epoch 38/600
# Adapt Time: 0.1649637222290039 s
# Support set metrics: Loss = 0.0449, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1872408390045166 s
# Support set metrics: Loss = 0.7127, accuracy = 0.6875, precision = 0.6333, recall = 0.6833, F1 score = 0.6381
# Adapt Time: 0.1936204433441162 s
# Support set metrics: Loss = 1.1040, accuracy = 0.6250, precision = 0.6633, recall = 0.6333, F1 score = 0.6181
# Adapt Time: 0.17893242835998535 s
# Support set metrics: Loss = 0.0091, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21062445640563965 s
# Support set metrics: Loss = 0.7059, accuracy = 0.8125, precision = 0.7667, recall = 0.8500, F1 score = 0.7800
# This is epoch 39/600
# Adapt Time: 0.16527724266052246 s
# Support set metrics: Loss = 0.2138, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8786
# Adapt Time: 0.19440269470214844 s
# Support set metrics: Loss = 0.8645, accuracy = 0.6875, precision = 0.7133, recall = 0.6667, F1 score = 0.6411
# Adapt Time: 0.2035844326019287 s
# Support set metrics: Loss = 0.9766, accuracy = 0.5625, precision = 0.6700, recall = 0.5833, F1 score = 0.5614
# Adapt Time: 0.17891597747802734 s
# Support set metrics: Loss = 0.0764, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.2263476848602295 s
# Support set metrics: Loss = 1.0289, accuracy = 0.6250, precision = 0.5167, recall = 0.6500, F1 score = 0.5633
# This is epoch 40/600
# Adapt Time: 0.16977930068969727 s
# Support set metrics: Loss = 0.1852, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19890284538269043 s
# Support set metrics: Loss = 1.0748, accuracy = 0.6250, precision = 0.6733, recall = 0.6000, F1 score = 0.5911
# Adapt Time: 0.21766400337219238 s
# Support set metrics: Loss = 0.7653, accuracy = 0.6250, precision = 0.5167, recall = 0.6000, F1 score = 0.5524
# Adapt Time: 0.17838382720947266 s
# Support set metrics: Loss = 0.0234, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2235095500946045 s
# Support set metrics: Loss = 0.6771, accuracy = 0.8125, precision = 0.9000, recall = 0.8500, F1 score = 0.8500
# This is epoch 41/600
# Adapt Time: 0.1729435920715332 s
# Support set metrics: Loss = 0.5731, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8786
# Adapt Time: 0.20218443870544434 s
# Support set metrics: Loss = 1.2690, accuracy = 0.7500, precision = 0.8833, recall = 0.7333, F1 score = 0.7648
# Adapt Time: 0.2330007553100586 s
# Support set metrics: Loss = 1.0465, accuracy = 0.6250, precision = 0.6867, recall = 0.6167, F1 score = 0.6400
# Adapt Time: 0.18601560592651367 s
# Support set metrics: Loss = 0.0062, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.24741458892822266 s
# Support set metrics: Loss = 0.9066, accuracy = 0.6875, precision = 0.7333, recall = 0.6500, F1 score = 0.6733
# This is epoch 42/600
# Adapt Time: 0.16751360893249512 s
# Support set metrics: Loss = 0.2605, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.19609737396240234 s
# Support set metrics: Loss = 0.6874, accuracy = 0.6875, precision = 0.7100, recall = 0.6667, F1 score = 0.6435
# Adapt Time: 0.1991887092590332 s
# Support set metrics: Loss = 1.1565, accuracy = 0.4375, precision = 0.4333, recall = 0.4333, F1 score = 0.4032
# Adapt Time: 0.17706584930419922 s
# Support set metrics: Loss = 0.0044, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21320796012878418 s
# Support set metrics: Loss = 1.0204, accuracy = 0.8125, precision = 0.8667, recall = 0.8500, F1 score = 0.8300
# This is epoch 43/600
# Adapt Time: 0.16573166847229004 s
# Support set metrics: Loss = 0.0847, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20720243453979492 s
# Support set metrics: Loss = 1.1310, accuracy = 0.6250, precision = 0.7300, recall = 0.6500, F1 score = 0.6314
# Adapt Time: 0.21016907691955566 s
# Support set metrics: Loss = 0.7161, accuracy = 0.8125, precision = 0.8333, recall = 0.8000, F1 score = 0.7762
# Adapt Time: 0.17599153518676758 s
# Support set metrics: Loss = 0.0232, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2009258270263672 s
# Support set metrics: Loss = 1.6707, accuracy = 0.5625, precision = 0.5000, recall = 0.5500, F1 score = 0.4967
# This is epoch 44/600
# Adapt Time: 0.16970157623291016 s
# Support set metrics: Loss = 0.0752, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20021748542785645 s
# Support set metrics: Loss = 1.0366, accuracy = 0.5625, precision = 0.5133, recall = 0.5500, F1 score = 0.5133
# Adapt Time: 0.21422338485717773 s
# Support set metrics: Loss = 0.9753, accuracy = 0.6250, precision = 0.6667, recall = 0.6500, F1 score = 0.6476
# Adapt Time: 0.1734325885772705 s
# Support set metrics: Loss = 0.1763, accuracy = 0.9375, precision = 0.9762, recall = 0.9643, F1 score = 0.9619
# Adapt Time: 0.2023777961730957 s
# Support set metrics: Loss = 0.8820, accuracy = 0.7500, precision = 0.7400, recall = 0.7500, F1 score = 0.7238
# This is epoch 45/600
# Adapt Time: 0.17031478881835938 s
# Support set metrics: Loss = 0.4694, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8611
# Adapt Time: 0.19989609718322754 s
# Support set metrics: Loss = 0.6653, accuracy = 0.8125, precision = 0.8533, recall = 0.8167, F1 score = 0.8148
# Adapt Time: 0.1969127655029297 s
# Support set metrics: Loss = 0.7569, accuracy = 0.7500, precision = 0.7533, recall = 0.7500, F1 score = 0.7348
# Adapt Time: 0.18700265884399414 s
# Support set metrics: Loss = 0.2664, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.20523285865783691 s
# Support set metrics: Loss = 0.2908, accuracy = 0.9375, precision = 0.9500, recall = 0.9500, F1 score = 0.9333
# This is epoch 46/600
# Adapt Time: 0.1804659366607666 s
# Support set metrics: Loss = 0.1828, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.1939234733581543 s
# Support set metrics: Loss = 1.2801, accuracy = 0.5625, precision = 0.5167, recall = 0.5667, F1 score = 0.5333
# Adapt Time: 0.1992321014404297 s
# Support set metrics: Loss = 0.8308, accuracy = 0.7500, precision = 0.7333, recall = 0.7333, F1 score = 0.7333
# Adapt Time: 0.17597150802612305 s
# Support set metrics: Loss = 0.0308, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2600090503692627 s
# Support set metrics: Loss = 0.4832, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 47/600
# Adapt Time: 0.16620182991027832 s
# Support set metrics: Loss = 0.2137, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.1929478645324707 s
# Support set metrics: Loss = 0.9486, accuracy = 0.5625, precision = 0.5767, recall = 0.5333, F1 score = 0.5416
# Adapt Time: 0.19041180610656738 s
# Support set metrics: Loss = 1.2206, accuracy = 0.3125, precision = 0.3467, recall = 0.3167, F1 score = 0.3171
# Adapt Time: 0.1803264617919922 s
# Support set metrics: Loss = 0.0056, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2478044033050537 s
# Support set metrics: Loss = 0.8142, accuracy = 0.7500, precision = 0.7833, recall = 0.7500, F1 score = 0.7267
# This is epoch 48/600
# Adapt Time: 0.16620397567749023 s
# Support set metrics: Loss = 0.2438, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.18588709831237793 s
# Support set metrics: Loss = 0.9234, accuracy = 0.5000, precision = 0.4867, recall = 0.4833, F1 score = 0.4743
# Adapt Time: 0.20122027397155762 s
# Support set metrics: Loss = 1.1471, accuracy = 0.8125, precision = 0.8933, recall = 0.8000, F1 score = 0.8311
# Adapt Time: 0.17558598518371582 s
# Support set metrics: Loss = 0.2236, accuracy = 0.8750, precision = 0.8810, recall = 0.8929, F1 score = 0.8690
# Adapt Time: 0.2006700038909912 s
# Support set metrics: Loss = 0.7966, accuracy = 0.7500, precision = 0.7000, recall = 0.7000, F1 score = 0.6667
# This is epoch 49/600
# Adapt Time: 0.16467833518981934 s
# Support set metrics: Loss = 0.1695, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.18212509155273438 s
# Support set metrics: Loss = 0.9561, accuracy = 0.5625, precision = 0.5967, recall = 0.5833, F1 score = 0.5648
# Adapt Time: 0.19522762298583984 s
# Support set metrics: Loss = 0.6995, accuracy = 0.8125, precision = 0.8833, recall = 0.8000, F1 score = 0.7914
# Adapt Time: 0.17426776885986328 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2140364646911621 s
# Support set metrics: Loss = 0.4488, accuracy = 0.8750, precision = 0.9000, recall = 0.9000, F1 score = 0.8667
# This is epoch 50/600
# Adapt Time: 0.16768980026245117 s
# Support set metrics: Loss = 0.5216, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8611
# Adapt Time: 0.2110118865966797 s
# Support set metrics: Loss = 0.7396, accuracy = 0.6875, precision = 0.6933, recall = 0.6667, F1 score = 0.6654
# Adapt Time: 0.20598769187927246 s
# Support set metrics: Loss = 1.2641, accuracy = 0.5000, precision = 0.5367, recall = 0.5167, F1 score = 0.4786
# Adapt Time: 0.17727875709533691 s
# Support set metrics: Loss = 0.0327, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2026958465576172 s
# Support set metrics: Loss = 0.7717, accuracy = 0.7500, precision = 0.7667, recall = 0.8000, F1 score = 0.7467
# This is epoch 51/600
# Adapt Time: 0.17040252685546875 s
# Support set metrics: Loss = 0.5065, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20302987098693848 s
# Support set metrics: Loss = 0.9849, accuracy = 0.4375, precision = 0.4567, recall = 0.4167, F1 score = 0.4267
# Adapt Time: 0.18791604042053223 s
# Support set metrics: Loss = 1.3328, accuracy = 0.4375, precision = 0.4833, recall = 0.4333, F1 score = 0.4457
# Adapt Time: 0.1772785186767578 s
# Support set metrics: Loss = 0.0597, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.24902963638305664 s
# Support set metrics: Loss = 0.9462, accuracy = 0.6875, precision = 0.6167, recall = 0.7000, F1 score = 0.6333
# This is epoch 52/600
# Adapt Time: 0.16929841041564941 s
# Support set metrics: Loss = 0.0549, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20214629173278809 s
# Support set metrics: Loss = 0.7989, accuracy = 0.6875, precision = 0.8033, recall = 0.7000, F1 score = 0.6881
# Adapt Time: 0.2119121551513672 s
# Support set metrics: Loss = 1.1888, accuracy = 0.3750, precision = 0.4333, recall = 0.3667, F1 score = 0.3933
# Adapt Time: 0.17680025100708008 s
# Support set metrics: Loss = 0.0084, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21520137786865234 s
# Support set metrics: Loss = 0.5629, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7900
# This is epoch 53/600
# Adapt Time: 0.1760563850402832 s
# Support set metrics: Loss = 0.1319, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.24647116661071777 s
# Support set metrics: Loss = 0.7559, accuracy = 0.7500, precision = 0.9000, recall = 0.7500, F1 score = 0.7814
# Adapt Time: 0.17894673347473145 s
# Support set metrics: Loss = 1.4566, accuracy = 0.5000, precision = 0.5000, recall = 0.4833, F1 score = 0.4737
# Adapt Time: 0.1722869873046875 s
# Support set metrics: Loss = 0.0054, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19075727462768555 s
# Support set metrics: Loss = 0.8030, accuracy = 0.7500, precision = 0.6833, recall = 0.7500, F1 score = 0.6833
# This is epoch 54/600
# Adapt Time: 0.17114567756652832 s
# Support set metrics: Loss = 0.0891, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2315654754638672 s
# Support set metrics: Loss = 0.8278, accuracy = 0.6250, precision = 0.7000, recall = 0.6167, F1 score = 0.6400
# Adapt Time: 0.2113349437713623 s
# Support set metrics: Loss = 1.2886, accuracy = 0.3125, precision = 0.3167, recall = 0.3167, F1 score = 0.3048
# Adapt Time: 0.1743450164794922 s
# Support set metrics: Loss = 0.0109, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21028780937194824 s
# Support set metrics: Loss = 0.5529, accuracy = 0.7500, precision = 0.7167, recall = 0.7500, F1 score = 0.7133
# This is epoch 55/600
# Adapt Time: 0.16452431678771973 s
# Support set metrics: Loss = 0.0527, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18496417999267578 s
# Support set metrics: Loss = 0.6009, accuracy = 0.7500, precision = 0.8400, recall = 0.7500, F1 score = 0.7314
# Adapt Time: 0.19450807571411133 s
# Support set metrics: Loss = 1.0069, accuracy = 0.5625, precision = 0.6800, recall = 0.5667, F1 score = 0.6089
# Adapt Time: 0.16950345039367676 s
# Support set metrics: Loss = 0.0221, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20833611488342285 s
# Support set metrics: Loss = 0.2477, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# This is epoch 56/600
# Adapt Time: 0.17332744598388672 s
# Support set metrics: Loss = 0.3834, accuracy = 0.8750, precision = 0.9500, recall = 0.8750, F1 score = 0.8889
# Adapt Time: 0.21260762214660645 s
# Support set metrics: Loss = 1.0541, accuracy = 0.5625, precision = 0.5333, recall = 0.5667, F1 score = 0.5143
# Adapt Time: 0.20812439918518066 s
# Support set metrics: Loss = 1.2868, accuracy = 0.4375, precision = 0.4667, recall = 0.4333, F1 score = 0.4222
# Adapt Time: 0.18129396438598633 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21904420852661133 s
# Support set metrics: Loss = 1.0741, accuracy = 0.7500, precision = 0.6500, recall = 0.7000, F1 score = 0.6467
# This is epoch 57/600
# Adapt Time: 0.17026591300964355 s
# Support set metrics: Loss = 0.7448, accuracy = 0.8125, precision = 0.8250, recall = 0.8125, F1 score = 0.8115
# Adapt Time: 0.2157001495361328 s
# Support set metrics: Loss = 1.4885, accuracy = 0.4375, precision = 0.5467, recall = 0.4333, F1 score = 0.4467
# Adapt Time: 0.22724699974060059 s
# Support set metrics: Loss = 0.6273, accuracy = 0.7500, precision = 0.7500, recall = 0.7333, F1 score = 0.7257
# Adapt Time: 0.18206429481506348 s
# Support set metrics: Loss = 0.0358, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2007584571838379 s
# Support set metrics: Loss = 1.4708, accuracy = 0.5625, precision = 0.5667, recall = 0.5500, F1 score = 0.5233
# This is epoch 58/600
# Adapt Time: 0.16877055168151855 s
# Support set metrics: Loss = 0.0572, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1870124340057373 s
# Support set metrics: Loss = 1.2166, accuracy = 0.5000, precision = 0.5533, recall = 0.5000, F1 score = 0.4786
# Adapt Time: 0.21104836463928223 s
# Support set metrics: Loss = 0.8407, accuracy = 0.5625, precision = 0.6133, recall = 0.5667, F1 score = 0.5667
# Adapt Time: 0.183762788772583 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1931464672088623 s
# Support set metrics: Loss = 1.2606, accuracy = 0.6250, precision = 0.5500, recall = 0.6500, F1 score = 0.5667
# This is epoch 59/600
# Adapt Time: 0.16784405708312988 s
# Support set metrics: Loss = 0.0518, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19376492500305176 s
# Support set metrics: Loss = 0.9382, accuracy = 0.6250, precision = 0.6833, recall = 0.6167, F1 score = 0.5967
# Adapt Time: 0.18615269660949707 s
# Support set metrics: Loss = 1.0098, accuracy = 0.6875, precision = 0.7833, recall = 0.6833, F1 score = 0.6905
# Adapt Time: 0.18162989616394043 s
# Support set metrics: Loss = 0.1777, accuracy = 0.9375, precision = 0.9762, recall = 0.9643, F1 score = 0.9619
# Adapt Time: 0.18709659576416016 s
# Support set metrics: Loss = 0.9819, accuracy = 0.6875, precision = 0.6500, recall = 0.7000, F1 score = 0.6300
# This is epoch 60/600
# Adapt Time: 0.16634249687194824 s
# Support set metrics: Loss = 0.1681, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20686030387878418 s
# Support set metrics: Loss = 0.8817, accuracy = 0.6875, precision = 0.9000, recall = 0.6833, F1 score = 0.7048
# Adapt Time: 0.1940004825592041 s
# Support set metrics: Loss = 0.8834, accuracy = 0.4375, precision = 0.3700, recall = 0.4333, F1 score = 0.3881
# Adapt Time: 0.17226052284240723 s
# Support set metrics: Loss = 0.0232, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22017288208007812 s
# Support set metrics: Loss = 1.4666, accuracy = 0.4375, precision = 0.4333, recall = 0.5500, F1 score = 0.4333
# This is epoch 61/600
# Adapt Time: 0.16660189628601074 s
# Support set metrics: Loss = 0.0965, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19929790496826172 s
# Support set metrics: Loss = 1.2078, accuracy = 0.5000, precision = 0.5667, recall = 0.5000, F1 score = 0.5219
# Adapt Time: 0.18619012832641602 s
# Support set metrics: Loss = 0.9208, accuracy = 0.7500, precision = 0.6700, recall = 0.7333, F1 score = 0.6814
# Adapt Time: 0.18085145950317383 s
# Support set metrics: Loss = 0.0157, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19002246856689453 s
# Support set metrics: Loss = 0.9044, accuracy = 0.7500, precision = 0.7167, recall = 0.7500, F1 score = 0.6967
# This is epoch 62/600
# Adapt Time: 0.17212367057800293 s
# Support set metrics: Loss = 0.0427, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19718718528747559 s
# Support set metrics: Loss = 0.7564, accuracy = 0.7500, precision = 0.7833, recall = 0.7500, F1 score = 0.7262
# Adapt Time: 0.21706652641296387 s
# Support set metrics: Loss = 1.0783, accuracy = 0.6875, precision = 0.6600, recall = 0.6667, F1 score = 0.6578
# Adapt Time: 0.17790985107421875 s
# Support set metrics: Loss = 0.0055, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19181108474731445 s
# Support set metrics: Loss = 1.1855, accuracy = 0.5000, precision = 0.4417, recall = 0.5500, F1 score = 0.4533
# This is epoch 63/600
# Adapt Time: 0.17659735679626465 s
# Support set metrics: Loss = 0.3337, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19500327110290527 s
# Support set metrics: Loss = 0.9364, accuracy = 0.5625, precision = 0.4500, recall = 0.5667, F1 score = 0.5000
# Adapt Time: 0.1997978687286377 s
# Support set metrics: Loss = 1.0720, accuracy = 0.6250, precision = 0.6833, recall = 0.6333, F1 score = 0.6457
# Adapt Time: 0.17612648010253906 s
# Support set metrics: Loss = 0.0357, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2131807804107666 s
# Support set metrics: Loss = 0.8661, accuracy = 0.8125, precision = 0.8667, recall = 0.8500, F1 score = 0.8300
# This is epoch 64/600
# Adapt Time: 0.16994333267211914 s
# Support set metrics: Loss = 0.1273, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19857239723205566 s
# Support set metrics: Loss = 0.7824, accuracy = 0.6875, precision = 0.8333, recall = 0.6667, F1 score = 0.6533
# Adapt Time: 0.2031855583190918 s
# Support set metrics: Loss = 0.9634, accuracy = 0.6875, precision = 0.7333, recall = 0.6833, F1 score = 0.6990
# Adapt Time: 0.1771254539489746 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22022724151611328 s
# ...
# Support set metrics: Loss = 0.6481, accuracy = 0.7500, precision = 0.7833, recall = 0.7333, F1 score = 0.7314
# Adapt Time: 0.1867220401763916 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2310466766357422 s
# Support set metrics: Loss = 0.5076, accuracy = 0.8125, precision = 0.7500, recall = 0.8000, F1 score = 0.7500
# This is epoch 579/600
# Adapt Time: 0.17214393615722656 s
# Support set metrics: Loss = 0.2777, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.22828912734985352 s
# Support set metrics: Loss = 1.0450, accuracy = 0.6875, precision = 0.6600, recall = 0.6667, F1 score = 0.6578
# Adapt Time: 0.19443416595458984 s
# Support set metrics: Loss = 0.6660, accuracy = 0.8125, precision = 0.8833, recall = 0.8000, F1 score = 0.7914
# Adapt Time: 0.1791377067565918 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2385272979736328 s
# Support set metrics: Loss = 1.0534, accuracy = 0.6250, precision = 0.4900, recall = 0.5500, F1 score = 0.5071
# This is epoch 580/600
# Adapt Time: 0.16679072380065918 s
# Support set metrics: Loss = 0.2807, accuracy = 0.8750, precision = 0.9375, recall = 0.8750, F1 score = 0.9018
# Adapt Time: 0.18214035034179688 s
# Support set metrics: Loss = 1.0812, accuracy = 0.5625, precision = 0.7057, recall = 0.5833, F1 score = 0.5367
# Adapt Time: 0.2082986831665039 s
# Support set metrics: Loss = 1.5550, accuracy = 0.5000, precision = 0.4967, recall = 0.4833, F1 score = 0.4767
# Adapt Time: 0.1702582836151123 s
# Support set metrics: Loss = 0.0065, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1921536922454834 s
# Support set metrics: Loss = 0.7156, accuracy = 0.7500, precision = 0.6667, recall = 0.7000, F1 score = 0.6800
# This is epoch 581/600
# Adapt Time: 0.16678905487060547 s
# Support set metrics: Loss = 0.8064, accuracy = 0.8125, precision = 0.8042, recall = 0.8125, F1 score = 0.8026
# Adapt Time: 0.20825433731079102 s
# Support set metrics: Loss = 0.5606, accuracy = 0.8750, precision = 0.9000, recall = 0.8667, F1 score = 0.8629
# Adapt Time: 0.2587616443634033 s
# Support set metrics: Loss = 0.9396, accuracy = 0.5625, precision = 0.6333, recall = 0.5500, F1 score = 0.5381
# Adapt Time: 0.17342495918273926 s
# Support set metrics: Loss = 0.0088, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19728302955627441 s
# Support set metrics: Loss = 0.4478, accuracy = 0.8125, precision = 0.7500, recall = 0.8000, F1 score = 0.7667
# This is epoch 582/600
# Adapt Time: 0.1743311882019043 s
# Support set metrics: Loss = 0.4940, accuracy = 0.8125, precision = 0.8929, recall = 0.8125, F1 score = 0.8128
# Adapt Time: 0.19503211975097656 s
# Support set metrics: Loss = 1.5522, accuracy = 0.5000, precision = 0.6000, recall = 0.5167, F1 score = 0.5086
# Adapt Time: 0.19900178909301758 s
# Support set metrics: Loss = 0.9265, accuracy = 0.4375, precision = 0.4167, recall = 0.4167, F1 score = 0.4095
# Adapt Time: 0.17818307876586914 s
# Support set metrics: Loss = 0.0052, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2449939250946045 s
# Support set metrics: Loss = 0.8219, accuracy = 0.6875, precision = 0.5000, recall = 0.6000, F1 score = 0.5233
# This is epoch 583/600
# Adapt Time: 0.17348170280456543 s
# Support set metrics: Loss = 0.1346, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19739794731140137 s
# Support set metrics: Loss = 1.0130, accuracy = 0.3750, precision = 0.4867, recall = 0.3833, F1 score = 0.3871
# Adapt Time: 0.19476079940795898 s
# Support set metrics: Loss = 1.1263, accuracy = 0.6250, precision = 0.7667, recall = 0.6500, F1 score = 0.6400
# Adapt Time: 0.18660855293273926 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1982128620147705 s
# Support set metrics: Loss = 1.0555, accuracy = 0.6250, precision = 0.6083, recall = 0.6000, F1 score = 0.5600
# This is epoch 584/600
# Adapt Time: 0.16886186599731445 s
# Support set metrics: Loss = 0.6525, accuracy = 0.8125, precision = 0.8667, recall = 0.8125, F1 score = 0.8032
# Adapt Time: 0.2140064239501953 s
# Support set metrics: Loss = 1.0791, accuracy = 0.5625, precision = 0.7000, recall = 0.5833, F1 score = 0.5676
# Adapt Time: 0.22068071365356445 s
# Support set metrics: Loss = 0.6990, accuracy = 0.6250, precision = 0.5100, recall = 0.6000, F1 score = 0.5492
# Adapt Time: 0.18148136138916016 s
# Support set metrics: Loss = 0.0056, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21233582496643066 s
# Support set metrics: Loss = 1.8911, accuracy = 0.5625, precision = 0.6000, recall = 0.5000, F1 score = 0.5200
# This is epoch 585/600
# Adapt Time: 0.16934657096862793 s
# Support set metrics: Loss = 0.0914, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19814348220825195 s
# Support set metrics: Loss = 0.7351, accuracy = 0.7500, precision = 0.8033, recall = 0.7500, F1 score = 0.7262
# Adapt Time: 0.2396867275238037 s
# Support set metrics: Loss = 0.9994, accuracy = 0.5625, precision = 0.4200, recall = 0.5333, F1 score = 0.4567
# Adapt Time: 0.17676949501037598 s
# Support set metrics: Loss = 0.0161, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20126700401306152 s
# Support set metrics: Loss = 0.6274, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7200
# This is epoch 586/600
# Adapt Time: 0.16573643684387207 s
# Support set metrics: Loss = 0.1149, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.18159818649291992 s
# Support set metrics: Loss = 0.9996, accuracy = 0.5625, precision = 0.6167, recall = 0.5333, F1 score = 0.5381
# Adapt Time: 0.19386076927185059 s
# Support set metrics: Loss = 0.9278, accuracy = 0.6875, precision = 0.7833, recall = 0.6833, F1 score = 0.6767
# Adapt Time: 0.1720895767211914 s
# Support set metrics: Loss = 0.0048, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21204829216003418 s
# Support set metrics: Loss = 1.3451, accuracy = 0.5625, precision = 0.5000, recall = 0.5000, F1 score = 0.4500
# This is epoch 587/600
# Adapt Time: 0.16451382637023926 s
# Support set metrics: Loss = 0.4060, accuracy = 0.7500, precision = 0.8429, recall = 0.7500, F1 score = 0.7183
# Adapt Time: 0.19476556777954102 s
# Support set metrics: Loss = 0.8547, accuracy = 0.6250, precision = 0.7000, recall = 0.6333, F1 score = 0.6432
# Adapt Time: 0.21756339073181152 s
# Support set metrics: Loss = 0.8941, accuracy = 0.5625, precision = 0.5667, recall = 0.5500, F1 score = 0.5467
# Adapt Time: 0.18376731872558594 s
# Support set metrics: Loss = 0.3550, accuracy = 0.9375, precision = 0.9762, recall = 0.9643, F1 score = 0.9619
# Adapt Time: 0.2073662281036377 s
# Support set metrics: Loss = 1.0475, accuracy = 0.6250, precision = 0.5367, recall = 0.5500, F1 score = 0.5252
# This is epoch 588/600
# Adapt Time: 0.16859698295593262 s
# Support set metrics: Loss = 0.3052, accuracy = 0.8125, precision = 0.8929, recall = 0.8125, F1 score = 0.7818
# Adapt Time: 0.22869324684143066 s
# Support set metrics: Loss = 0.9212, accuracy = 0.6250, precision = 0.6467, recall = 0.6167, F1 score = 0.6181
# Adapt Time: 0.20754742622375488 s
# Support set metrics: Loss = 1.1689, accuracy = 0.5625, precision = 0.6000, recall = 0.5667, F1 score = 0.5800
# Adapt Time: 0.18199419975280762 s
# Support set metrics: Loss = 0.0056, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.23191142082214355 s
# Support set metrics: Loss = 0.6966, accuracy = 0.8125, precision = 0.6667, recall = 0.7500, F1 score = 0.6967
# This is epoch 589/600
# Adapt Time: 0.17314982414245605 s
# Support set metrics: Loss = 0.2834, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.18791460990905762 s
# Support set metrics: Loss = 1.2661, accuracy = 0.3750, precision = 0.4000, recall = 0.3667, F1 score = 0.3752
# Adapt Time: 0.2129509449005127 s
# Support set metrics: Loss = 0.6559, accuracy = 0.5625, precision = 0.5833, recall = 0.5667, F1 score = 0.5648
# Adapt Time: 0.18749570846557617 s
# Support set metrics: Loss = 0.0047, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19923686981201172 s
# Support set metrics: Loss = 0.5819, accuracy = 0.8125, precision = 0.7333, recall = 0.7500, F1 score = 0.7267
# This is epoch 590/600
# Adapt Time: 0.17330312728881836 s
# Support set metrics: Loss = 0.7465, accuracy = 0.7500, precision = 0.9375, recall = 0.7500, F1 score = 0.7875
# Adapt Time: 0.19123148918151855 s
# Support set metrics: Loss = 1.0753, accuracy = 0.6250, precision = 0.6500, recall = 0.6500, F1 score = 0.6362
# Adapt Time: 0.21124482154846191 s
# Support set metrics: Loss = 0.9793, accuracy = 0.6250, precision = 0.6833, recall = 0.6167, F1 score = 0.6362
# Adapt Time: 0.18029475212097168 s
# Support set metrics: Loss = 0.0048, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20160365104675293 s
# Support set metrics: Loss = 1.0067, accuracy = 0.7500, precision = 0.6833, recall = 0.7000, F1 score = 0.6767
# This is epoch 591/600
# Adapt Time: 0.167069673538208 s
# Support set metrics: Loss = 0.0635, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18909931182861328 s
# Support set metrics: Loss = 0.9278, accuracy = 0.5000, precision = 0.5467, recall = 0.5000, F1 score = 0.4943
# Adapt Time: 0.19193124771118164 s
# Support set metrics: Loss = 1.0123, accuracy = 0.7500, precision = 0.8333, recall = 0.7500, F1 score = 0.7748
# Adapt Time: 0.17242717742919922 s
# Support set metrics: Loss = 0.3554, accuracy = 0.9375, precision = 0.9762, recall = 0.9643, F1 score = 0.9619
# Adapt Time: 0.19609451293945312 s
# Support set metrics: Loss = 1.6068, accuracy = 0.5000, precision = 0.3367, recall = 0.4500, F1 score = 0.3752
# This is epoch 592/600
# Adapt Time: 0.16385340690612793 s
# Support set metrics: Loss = 0.2074, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.18570613861083984 s
# Support set metrics: Loss = 1.3907, accuracy = 0.6250, precision = 0.7367, recall = 0.6500, F1 score = 0.6281
# Adapt Time: 0.2037355899810791 s
# Support set metrics: Loss = 0.8745, accuracy = 0.5625, precision = 0.5667, recall = 0.5667, F1 score = 0.5619
# Adapt Time: 0.1724531650543213 s
# Support set metrics: Loss = 0.0658, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.21892189979553223 s
# Support set metrics: Loss = 1.0104, accuracy = 0.6250, precision = 0.6500, recall = 0.6500, F1 score = 0.6167
# This is epoch 593/600
# Adapt Time: 0.1703178882598877 s
# Support set metrics: Loss = 0.5964, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.19357538223266602 s
# Support set metrics: Loss = 0.6659, accuracy = 0.8125, precision = 0.8200, recall = 0.8000, F1 score = 0.7900
# Adapt Time: 0.24190449714660645 s
# Support set metrics: Loss = 0.6787, accuracy = 0.6875, precision = 0.7333, recall = 0.6833, F1 score = 0.6948
# Adapt Time: 0.17751836776733398 s
# Support set metrics: Loss = 0.0090, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2445211410522461 s
# Support set metrics: Loss = 1.2039, accuracy = 0.6250, precision = 0.5250, recall = 0.5500, F1 score = 0.5333
# This is epoch 594/600
# Adapt Time: 0.17233705520629883 s
# Support set metrics: Loss = 0.1114, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21585798263549805 s
# Support set metrics: Loss = 0.8764, accuracy = 0.6250, precision = 0.6667, recall = 0.6333, F1 score = 0.6410
# Adapt Time: 0.19156885147094727 s
# Support set metrics: Loss = 0.8642, accuracy = 0.7500, precision = 0.8167, recall = 0.7500, F1 score = 0.7695
# Adapt Time: 0.17896676063537598 s
# Support set metrics: Loss = 0.0062, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1941697597503662 s
# Support set metrics: Loss = 1.0215, accuracy = 0.7500, precision = 0.8167, recall = 0.8000, F1 score = 0.7467
# This is epoch 595/600
# Adapt Time: 0.16834068298339844 s
# Support set metrics: Loss = 0.3693, accuracy = 0.8125, precision = 0.8250, recall = 0.8125, F1 score = 0.8115
# Adapt Time: 0.1913454532623291 s
# Support set metrics: Loss = 1.0470, accuracy = 0.5000, precision = 0.5867, recall = 0.5000, F1 score = 0.4976
# Adapt Time: 0.2047278881072998 s
# Support set metrics: Loss = 0.8311, accuracy = 0.6250, precision = 0.7867, recall = 0.6333, F1 score = 0.6500
# Adapt Time: 0.1826624870300293 s
# Support set metrics: Loss = 0.0791, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.20563602447509766 s
# Support set metrics: Loss = 0.6310, accuracy = 0.8125, precision = 0.8833, recall = 0.8500, F1 score = 0.8333
# This is epoch 596/600
# Adapt Time: 0.16532516479492188 s
# Support set metrics: Loss = 0.1910, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19807910919189453 s
# Support set metrics: Loss = 0.7544, accuracy = 0.5625, precision = 0.5967, recall = 0.5500, F1 score = 0.5567
# Adapt Time: 0.19635772705078125 s
# Support set metrics: Loss = 1.2343, accuracy = 0.5000, precision = 0.5000, recall = 0.4833, F1 score = 0.4800
# Adapt Time: 0.1747729778289795 s
# Support set metrics: Loss = 0.0191, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21294856071472168 s
# Support set metrics: Loss = 1.1220, accuracy = 0.6250, precision = 0.5667, recall = 0.6500, F1 score = 0.5567
# This is epoch 597/600
# Adapt Time: 0.16902542114257812 s
# Support set metrics: Loss = 0.0906, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.1922144889831543 s
# Support set metrics: Loss = 0.9004, accuracy = 0.6250, precision = 0.7000, recall = 0.6500, F1 score = 0.6229
# Adapt Time: 0.19696497917175293 s
# Support set metrics: Loss = 1.2540, accuracy = 0.6250, precision = 0.5133, recall = 0.6167, F1 score = 0.5548
# Adapt Time: 0.16884899139404297 s
# Support set metrics: Loss = 0.3162, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.1799774169921875 s
# Support set metrics: Loss = 0.6971, accuracy = 0.6875, precision = 0.6700, recall = 0.6500, F1 score = 0.6000
# This is epoch 598/600
# Adapt Time: 0.1637718677520752 s
# Support set metrics: Loss = 0.4337, accuracy = 0.7500, precision = 0.8167, recall = 0.7500, F1 score = 0.7540
# Adapt Time: 0.18978619575500488 s
# Support set metrics: Loss = 1.0259, accuracy = 0.5000, precision = 0.4467, recall = 0.5000, F1 score = 0.4619
# Adapt Time: 0.1921987533569336 s
# Support set metrics: Loss = 1.0066, accuracy = 0.5625, precision = 0.4367, recall = 0.5500, F1 score = 0.4810
# Adapt Time: 0.18229365348815918 s
# Support set metrics: Loss = 0.0044, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21825075149536133 s
# Support set metrics: Loss = 0.6206, accuracy = 0.8125, precision = 0.8000, recall = 0.8500, F1 score = 0.8000
# This is epoch 599/600
# Adapt Time: 0.17247772216796875 s
# Support set metrics: Loss = 0.0786, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1982269287109375 s
# Support set metrics: Loss = 0.6135, accuracy = 0.8750, precision = 0.9100, recall = 0.8667, F1 score = 0.8492
# Adapt Time: 0.20405125617980957 s
# Support set metrics: Loss = 1.2706, accuracy = 0.5625, precision = 0.5867, recall = 0.5833, F1 score = 0.5633
# Adapt Time: 0.1792304515838623 s
# Support set metrics: Loss = 0.0410, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21274542808532715 s
# Support set metrics: Loss = 1.1073, accuracy = 0.6250, precision = 0.4500, recall = 0.5500, F1 score = 0.4867
# Total Scoring Time: 29.0 m

# %%
print("Support of each class: ")
for class_idx in range(len(memory_buffer.meta_score)):
    total_support = np.sum(memory_buffer.meta_score[class_idx, :TRIM_ER, 1])
    mean_support = np.mean(memory_buffer.meta_score[class_idx, :TRIM_ER, 1])
    print(f"\t#Class {class_idx}: {total_support} , Avg: {mean_support}")
# Out:
# Support of each class:
# 	#Class 0: 4785.0 , Avg: 9.57
# 	#Class 1: 3594.0 , Avg: 7.188
# 	#Class 2: 3589.0 , Avg: 7.178
# 	#Class 3: 3592.0 , Avg: 7.184
# 	#Class 4: 3589.0 , Avg: 7.178
# 	#Class 5: 2388.0 , Avg: 4.776
# 	#Class 6: 2394.0 , Avg: 4.788
# 	#Class 7: 2392.0 , Avg: 4.784
# 	#Class 8: 2397.0 , Avg: 4.794
# 	#Class 9: 1197.0 , Avg: 2.394
# 	#Class 10: 1200.0 , Avg: 2.4
# 	#Class 11: 600.0 , Avg: 1.2
# 	#Class 12: 600.0 , Avg: 1.2
# 	#Class 13: 600.0 , Avg: 1.2
# 	#Class 14: 600.0 , Avg: 1.2
# 	#Class 15: 600.0 , Avg: 1.2
# 	#Class 16: 600.0 , Avg: 1.2
# 	#Class 17: 600.0 , Avg: 1.2
# 	#Class 18: 600.0 , Avg: 1.2
# 	#Class 19: 600.0 , Avg: 1.2
# 	#Class 20: 600.0 , Avg: 1.2
# 	#Class 21: 600.0 , Avg: 1.2
# 	#Class 22: 600.0 , Avg: 1.2
# 	#Class 23: 1196.0 , Avg: 2.392
# 	#Class 24: 1200.0 , Avg: 2.4
# 	#Class 25: 1200.0 , Avg: 2.4
# 	#Class 26: 1200.0 , Avg: 2.4
# 	#Class 27: 1198.0 , Avg: 2.396
# 	#Class 28: 1199.0 , Avg: 2.398
# 	#Class 29: 600.0 , Avg: 1.2
# 	#Class 30: 600.0 , Avg: 1.2
# 	#Class 31: 600.0 , Avg: 1.2
# 	#Class 32: 600.0 , Avg: 1.2

# %%
print("Average Score of each class: ")
for class_idx in range(len(memory_buffer.meta_score)):
    #mean_score = np.mean(memory_buffer.meta_score[class_idx, ..., 0])
    mean_score = np.mean(memory_buffer.meta_score[class_idx][memory_buffer.meta_score[class_idx, ...,1] != 0][:TRIM_ER, 0])
    print(f"\tScore Class {class_idx}: {mean_score}")
# Out:
# Average Score of each class:
# 	Score Class 0: 0.01950489419545685
# 	Score Class 1: 0.012139429529096293
# 	Score Class 2: 0.004768333603006275
# 	Score Class 3: 0.012291637525130069
# 	Score Class 4: -0.0038124021203460156
# 	Score Class 5: 0.004475105298903
# 	Score Class 6: 0.0011870669954655798
# 	Score Class 7: 0.01711971285715674
# 	Score Class 8: -0.00759336976961645
# 	Score Class 9: 0.0009240013768754618
# 	Score Class 10: 0.00022002653941318844
# 	Score Class 11: 4.50828983488336e-05
# 	Score Class 12: 9.861210386631853e-06
# 	Score Class 13: 0.0006562866301281594
# 	Score Class 14: 0.0001498754562408124
# 	Score Class 15: 0.0010560663785653477
# 	Score Class 16: 1.8856430074598036e-05
# 	Score Class 17: 9.774091359745001e-05
# 	Score Class 18: 0.00020715437152952855
# 	Score Class 19: 3.818445440351619e-05
# 	Score Class 20: 0.00018847364395218239
# 	Score Class 21: 0.0002168958193221978
# 	Score Class 22: 2.787437186377089e-05
# 	Score Class 23: 0.001683297738098764
# 	Score Class 24: 0.006878699544908058
# 	Score Class 25: 0.014519559722914984
# 	Score Class 26: 0.009462821772913025
# 	Score Class 27: 0.0005854468263852781
# 	Score Class 28: 0.0012405181397541413
# 	Score Class 29: -0.0008746768642423308
# 	Score Class 30: 0.0048647944600057735
# 	Score Class 31: 0.0011689637958191977
# 	Score Class 32: 0.0021248679451083196

# %%
print(memory_buffer.meta_score[0,:TRIM_ER,0].shape)
print(memory_buffer.meta_score[0,:TRIM_ER,0][memory_buffer.meta_score[0,:TRIM_ER,1] != 0].shape)
# Out:
# (500,)
# (500,)

# %%
_model_path0 = os.path.splitext(model_path)[0]
MEMORY_SAVE_LOC = _model_path0 + "_memory_ss4.pickle"
pickle.dump( memory_buffer, open( MEMORY_SAVE_LOC, "wb" ), protocol=pickle.HIGHEST_PROTOCOL)
print(f"Done writing Memory Pickle File at {MEMORY_SAVE_LOC}")
# Out:
# Done writing Memory Pickle File at /data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228_memory_ss4.pickle

# %%
# new_memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228_memory_ss4.pickle"
# with open(new_memory_path, 'rb') as f:
#     memory_buffer = pickle.load(f)

# %% [markdown]
# ### Plotting Distribution of Scores for each Class

# %%
class_idx = 1
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)
# Out:
# (array([  4.,   5.,  11.,  16.,  37.,  50.,  61., 105.,  76.,  56.,  41.,
#          23.,  11.,   0.,   4.]),
#  array([-0.05114654, -0.04278651, -0.03442648, -0.02606644, -0.01770641,
#         -0.00934638, -0.00098635,  0.00737368,  0.01573372,  0.02409375,
#          0.03245378,  0.04081381,  0.04917384,  0.05753388,  0.06589391,
#          0.07425394]),
#  <BarContainer object of 15 artists>)

# %%
class_idx = 8
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)
# Out:
# (array([  1.,   2.,   5.,  12.,  19.,  45., 117., 262.,  17.,   5.,   6.,
#           3.,   2.,   0.,   2.]),
#  array([-0.07609638, -0.0662211 , -0.05634583, -0.04647055, -0.03659528,
#         -0.02672   , -0.01684473, -0.00696945,  0.00290582,  0.0127811 ,
#          0.02265637,  0.03253165,  0.04240692,  0.0522822 ,  0.06215747,
#          0.07203275]),
#  <BarContainer object of 15 artists>)

# %%
class_idx = 30
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)
# Out:
# (array([ 7., 12., 16., 84., 68., 52., 32., 19., 16., 22.,  8.,  4.,  9.,
#          2.,  3.]),
#  array([-0.01010499, -0.007401  , -0.004697  , -0.00199301,  0.00071098,
#          0.00341497,  0.00611897,  0.00882296,  0.01152695,  0.01423094,
#          0.01693494,  0.01963893,  0.02234292,  0.02504691,  0.02775091,
#          0.0304549 ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ### Plotting Distribution of Scores for one sample

# %%
class_idx = 0
sample_idx = 0
score_list = memory_buffer.meta_debug[class_idx][sample_idx]

print(f"#Scores in ScoreList {len(score_list)}")
print(f"# Score in sample_idx: {memory_buffer.meta_score[class_idx, sample_idx, 0]}")
print(f"# Support in sample_idx: {memory_buffer.meta_score[class_idx, sample_idx, 1]}")

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)
# Out:
# #Scores in ScoreList 7
# # Score in sample_idx: 0.03234183959317356
# # Support in sample_idx: 7.0
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 0., 2., 0., 0., 0., 2.]),
#  array([-0.04685856, -0.03814467, -0.02943078, -0.02071688, -0.01200299,
#         -0.0032891 ,  0.00542479,  0.01413869,  0.02285258,  0.03156647,
#          0.04028037,  0.04899426,  0.05770815,  0.06642205,  0.07513594,
#          0.08384983]),
#  <BarContainer object of 15 artists>)

# %%
memory_buffer.meta_debug[class_idx].keys()
# Out:
# dict_keys([101, 440, 82, 110, 283, 18, 269, 248, 425, 165, 154, 135, 496, 149, 208, 464, 315, 429, 392, 379, 172, 352, 2, 287, 447, 151, 472, 314, 84, 104, 190, 176, 140, 218, 319, 277, 303, 143, 261, 241, 60, 396, 197, 452, 85, 168, 129, 139, 17, 203, 421, 335, 428, 459, 369, 483, 340, 342, 389, 326, 370, 348, 328, 382, 27, 142, 106, 282, 46, 111, 239, 264, 71, 288, 20, 390, 55, 215, 295, 262, 305, 432, 81, 351, 124, 65, 204, 173, 77, 420, 488, 42, 388, 76, 362, 416, 24, 444, 455, 316, 427, 291, 19, 415, 371, 383, 309, 145, 9, 136, 325, 313, 384, 15, 180, 11, 380, 275, 206, 422, 272, 424, 88, 297, 210, 479, 67, 105, 350, 308, 498, 411, 471, 332, 53, 296, 86, 72, 107, 365, 311, 116, 155, 186, 235, 6, 400, 103, 320, 34, 433, 274, 404, 59, 226, 153, 3, 240, 473, 441, 256, 170, 161, 201, 481, 330, 51, 56, 166, 293, 130, 202, 270, 8, 258, 485, 294, 199, 345, 334, 395, 460, 437, 228, 394, 47, 484, 359, 493, 23, 289, 401, 467, 306, 243, 127, 337, 236, 167, 263, 95, 249, 49, 134, 48, 409, 355, 324, 439, 489, 402, 302, 36, 457, 299, 227, 45, 442, 253, 141, 50, 391, 363, 367, 403, 417, 412, 436, 448, 133, 410, 276, 182, 164, 407, 469, 181, 14, 360, 338, 408, 70, 159, 205, 79, 456, 419, 61, 431, 144, 434, 91, 22, 486, 163, 211, 97, 307, 21, 254, 478, 147, 33, 368, 189, 146, 495, 188, 73, 450, 64, 482, 426, 12, 341, 160, 430, 298, 343, 43, 69, 16, 5, 194, 198, 192, 175, 174, 474, 487, 123, 245, 250, 209, 231, 255, 492, 361, 120, 497, 99, 323, 376, 216, 281, 466, 28, 26, 131, 94, 54, 317, 195, 7, 233, 285, 238, 191, 177, 75, 278, 374, 397, 44, 463, 93, 292, 244, 118, 37, 385, 480, 115, 399, 237, 470, 349, 304, 185, 35, 137, 414, 312, 157, 357, 207, 491, 356, 268, 150, 445, 468, 125, 259, 381, 196, 214, 290, 266, 398, 260, 301, 98, 310, 246, 329, 300, 458, 80, 490, 92, 213, 184, 242, 114, 230, 90, 476, 336, 128, 32, 267, 212, 13, 162, 108, 41, 322, 331, 221, 10, 100, 52, 387, 257, 321, 89, 375, 112, 39, 373, 347, 220, 148, 271, 284, 68, 449, 405, 63, 121, 252, 494, 217, 406, 413, 234, 183, 344, 446, 393, 279, 25, 178, 354, 66, 339, 438, 126, 378, 200, 453, 372, 386, 377, 102, 451, 251, 96, 58, 454, 40, 223, 358, 29, 224, 109, 462, 219, 78, 179, 229, 117, 156, 333, 418, 247, 364, 423, 499, 225, 132, 280, 171, 273, 318, 232, 122, 477, 31, 62, 353, 222, 152, 475, 83, 87, 366, 327, 435, 38, 0, 443, 57, 193, 461, 113, 4, 346, 138, 74, 1, 187, 158, 119, 265, 30, 169, 286, 465])

# %% [markdown]
# # Testing
#
# Select specific column index per row
# https://stackoverflow.com/questions/23435782/numpy-selecting-specific-column-index-per-row-by-using-a-list-of-indexes

# %%
def evaluate(dataloader, updates, mini_batch_size, dataname=""):
    learner.rln.eval()
    learner.pln.train()
    
    all_losses, all_predictions, all_labels, all_label_conf = [], [], [], []
    all_adaptation_time = []
    # Get Query set first. and then find supporting support set
    for query_idx, (query_text, query_labels) in enumerate(dataloader):
        print(f"Query ID {query_idx}/{len(dataloader)}")
        # The task id to optimize to for support set
        # task_idx = get_task_from_label_list(query_labels, memory_buffer.task_dict)
        task_idx = dataclass_mapper[dataname]
        
    
        support_set = []
        for _ in range(updates):
            text, labels = memory_buffer.read_batch_task(batch_size=mini_batch_size, task_idx=task_idx, sort_score=True)
            support_set.append((text, labels))

        with higher.innerloop_ctx(learner.pln, learner.inner_optimizer,
                                  copy_initial_weights=False, track_higher_grads=False) as (fpln, diffopt):
            
            INNER_tic = time.time()
            # Inner loop
            task_predictions, task_labels = [], []
            support_loss = []
            for text, labels in support_set:
                labels = torch.tensor(labels).to(device)
                input_dict = learner.rln.encode_text(text)
                _repr = learner.rln(input_dict)
                output = fpln(_repr)
                loss = learner.loss_fn(output, labels)
                diffopt.step(loss)
                pred = models.utils.make_prediction(output.detach())
                support_loss.append(loss.item())
                task_predictions.extend(pred.tolist())
                task_labels.extend(labels.tolist())
            INNER_toc = time.time() - INNER_tic
            all_adaptation_time.append(INNER_toc)

            acc, prec, rec, f1 = models.utils.calculate_metrics(task_predictions, task_labels)

            print('Support set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                        'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(support_loss), acc, prec, rec, f1))

            # Query set is now here!
            query_labels = torch.tensor(query_labels).to(device)
            query_input_dict = learner.rln.encode_text(query_text)
            with torch.no_grad():
                query_repr = learner.rln(query_input_dict)
                query_output = fpln(query_repr) # Output has size of torch.Size([16, 33]) [BATCH, CLASSES]
                query_loss = learner.loss_fn(query_output, query_labels)
            query_loss = query_loss.item()
            # print(output.detach().size())
            # output.detach().max(-1) max on each Batch, which will return [0] max, [1] indices
            query_output_softmax = F.softmax(query_output, -1)
            query_label_conf = query_output_softmax[np.arange(len(query_output_softmax)), query_labels] # Select labels in the softmax of 33 classes

            query_pred = models.utils.make_prediction(query_output.detach())
            query_acc, query_prec, query_rec, query_f1 = models.utils.calculate_metrics(query_pred.tolist(), query_labels.tolist())
            
            print('Query set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(query_loss), query_acc, query_prec, query_rec, query_f1))

            all_losses.append(query_loss)
            all_predictions.extend(query_pred.tolist())
            all_labels.extend(query_labels.tolist())
            all_label_conf.extend(query_label_conf.tolist())

    acc, prec, rec, f1 = models.utils.calculate_metrics(all_predictions, all_labels)
    print('Test metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
                'F1 score = {:.4f}'.format(np.mean(all_losses), acc, prec, rec, f1))
    return acc, prec, rec, f1, all_predictions, all_labels, all_label_conf, all_adaptation_time

# %%
tic = time.time()
print('----------Testing on test set starts here----------')

accuracies, precisions, recalls, f1s = [], [], [], []
all_adapt_time = []
# Data for Visualization: [data_idx, label, label_conf, pred]
data_for_visual = []

for test_dataset in test_datasets:
    print('Testing on {}'.format(test_dataset.__class__.__name__))
    test_dataloader = data.DataLoader(test_dataset, batch_size=mini_batch_size, shuffle=False,
                                      collate_fn=datasets.utils.batch_encode)
    acc, prec, rec, f1, all_pred, all_label, all_label_conf, all_adaptation_time = evaluate(dataloader=test_dataloader, updates=updates, 
                                                mini_batch_size=mini_batch_size, dataname=test_dataset.__class__.__name__)
    
    data_ids = [test_dataset.__class__.__name__ + str(i) for i in range(len(all_label))]
    data_for_visual.extend(list(zip(data_ids, all_label, all_label_conf, all_pred)))
    all_adapt_time.extend(all_adaptation_time)
#     print(data_ids)
#     print(all_label)
#     raise Exception("BREAKPOINT")
    
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1s.append(f1)


print()
print("COPY PASTA - not really but ok")
for row in accuracies:
    print(row)
print()
print('Overall test metrics: Accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
            'F1 score = {:.4f}'.format(np.mean(accuracies), np.mean(precisions), np.mean(recalls), np.mean(f1s)))

toc = time.time() - tic
print(f"Total Time used: {toc//60} minutes")
# Out:
# ----------Testing on test set starts here----------
# Testing on YelpDataset
# Query ID 0/475
# Support set metrics: Loss = 0.9578, accuracy = 0.5000, precision = 0.4682, recall = 0.4800, F1 score = 0.4621
# Query set metrics: Loss = 0.6016, accuracy = 0.8125, precision = 0.9167, recall = 0.8000, F1 score = 0.8132
# Query ID 1/475
# Support set metrics: Loss = 0.9681, accuracy = 0.4375, precision = 0.4340, recall = 0.4100, F1 score = 0.4116
# Query set metrics: Loss = 0.6031, accuracy = 0.7500, precision = 0.7267, recall = 0.7933, F1 score = 0.7200
# Query ID 2/475
# Support set metrics: Loss = 1.0594, accuracy = 0.3625, precision = 0.3421, recall = 0.3333, F1 score = 0.3331
# Query set metrics: Loss = 1.0159, accuracy = 0.5625, precision = 0.3400, recall = 0.5000, F1 score = 0.4000
# Query ID 3/475
# Support set metrics: Loss = 1.0404, accuracy = 0.3625, precision = 0.3560, recall = 0.3367, F1 score = 0.3429
# Query set metrics: Loss = 0.9342, accuracy = 0.7500, precision = 0.8133, recall = 0.7500, F1 score = 0.7444
# Query ID 4/475
# Support set metrics: Loss = 0.9671, accuracy = 0.4125, precision = 0.4330, recall = 0.3867, F1 score = 0.4052
# Query set metrics: Loss = 1.1750, accuracy = 0.4375, precision = 0.3750, recall = 0.5000, F1 score = 0.4034
# Query ID 5/475
# Support set metrics: Loss = 1.0243, accuracy = 0.3375, precision = 0.3191, recall = 0.3167, F1 score = 0.3166
# Query set metrics: Loss = 0.9602, accuracy = 0.6250, precision = 0.6167, recall = 0.6200, F1 score = 0.6133
# Query ID 6/475
# Support set metrics: Loss = 1.0050, accuracy = 0.4125, precision = 0.4132, recall = 0.3933, F1 score = 0.3956
# Query set metrics: Loss = 0.8991, accuracy = 0.6875, precision = 0.6133, recall = 0.6333, F1 score = 0.5933
# Query ID 7/475
# Support set metrics: Loss = 0.9713, accuracy = 0.4375, precision = 0.4258, recall = 0.4200, F1 score = 0.4178
# Query set metrics: Loss = 0.9306, accuracy = 0.6875, precision = 0.7000, recall = 0.6667, F1 score = 0.6743
# Query ID 8/475
# Support set metrics: Loss = 1.0542, accuracy = 0.3500, precision = 0.3459, recall = 0.3167, F1 score = 0.3295
# Query set metrics: Loss = 1.0774, accuracy = 0.3750, precision = 0.4300, recall = 0.4800, F1 score = 0.3743
# Query ID 9/475
# Support set metrics: Loss = 1.0096, accuracy = 0.4000, precision = 0.4272, recall = 0.3767, F1 score = 0.3981
# Query set metrics: Loss = 1.2167, accuracy = 0.5625, precision = 0.7238, recall = 0.7083, F1 score = 0.5913
# Query ID 10/475
# Support set metrics: Loss = 1.0466, accuracy = 0.3125, precision = 0.3236, recall = 0.2867, F1 score = 0.3025
# Query set metrics: Loss = 1.3226, accuracy = 0.3125, precision = 0.3238, recall = 0.3619, F1 score = 0.2300
# Query ID 11/475
# Support set metrics: Loss = 1.0083, accuracy = 0.4000, precision = 0.3854, recall = 0.3733, F1 score = 0.3751
# Query set metrics: Loss = 1.0126, accuracy = 0.4375, precision = 0.4375, recall = 0.3750, F1 score = 0.4000
# Query ID 12/475
# Support set metrics: Loss = 0.9553, accuracy = 0.4375, precision = 0.4335, recall = 0.4167, F1 score = 0.4167
# Query set metrics: Loss = 0.9956, accuracy = 0.5625, precision = 0.5333, recall = 0.6350, F1 score = 0.5255
# Query ID 13/475
# Support set metrics: Loss = 1.0299, accuracy = 0.3750, precision = 0.3864, recall = 0.3533, F1 score = 0.3676
# Query set metrics: Loss = 0.8679, accuracy = 0.6250, precision = 0.4767, recall = 0.5667, F1 score = 0.5112
# Query ID 14/475
# Support set metrics: Loss = 0.9817, accuracy = 0.4375, precision = 0.4149, recall = 0.4100, F1 score = 0.4061
# Query set metrics: Loss = 1.0544, accuracy = 0.4375, precision = 0.4500, recall = 0.3625, F1 score = 0.3944
# Query ID 15/475
# Support set metrics: Loss = 0.9627, accuracy = 0.4000, precision = 0.4159, recall = 0.3733, F1 score = 0.3893
# Query set metrics: Loss = 1.4718, accuracy = 0.4375, precision = 0.6267, recall = 0.5233, F1 score = 0.4410
# Query ID 16/475
# Support set metrics: Loss = 0.9985, accuracy = 0.4000, precision = 0.4190, recall = 0.3833, F1 score = 0.3962
# Query set metrics: Loss = 0.7098, accuracy = 0.7500, precision = 0.8133, recall = 0.7500, F1 score = 0.7190
# Query ID 17/475
# Support set metrics: Loss = 1.0560, accuracy = 0.2875, precision = 0.3017, recall = 0.2667, F1 score = 0.2806
# Query set metrics: Loss = 0.8197, accuracy = 0.6250, precision = 0.3629, recall = 0.5500, F1 score = 0.4333
# Query ID 18/475
# Support set metrics: Loss = 1.0464, accuracy = 0.4250, precision = 0.3938, recall = 0.4067, F1 score = 0.3947
# Query set metrics: Loss = 0.3809, accuracy = 0.9375, precision = 0.7667, recall = 0.8000, F1 score = 0.7818
# Query ID 19/475
# Support set metrics: Loss = 0.9752, accuracy = 0.3625, precision = 0.3731, recall = 0.3333, F1 score = 0.3492
# Query set metrics: Loss = 1.4368, accuracy = 0.4375, precision = 0.4333, recall = 0.5167, F1 score = 0.3905
# Query ID 20/475
# Support set metrics: Loss = 0.9600, accuracy = 0.4375, precision = 0.4411, recall = 0.4167, F1 score = 0.4247
# Query set metrics: Loss = 0.6988, accuracy = 0.7500, precision = 0.8667, recall = 0.7500, F1 score = 0.7581
# Query ID 21/475
# Support set metrics: Loss = 0.9894, accuracy = 0.3125, precision = 0.3416, recall = 0.2867, F1 score = 0.3092
# Query set metrics: Loss = 1.0656, accuracy = 0.4375, precision = 0.3133, recall = 0.4000, F1 score = 0.3276
# Query ID 22/475
# Support set metrics: Loss = 1.0022, accuracy = 0.4250, precision = 0.4273, recall = 0.4033, F1 score = 0.4089
# Query set metrics: Loss = 0.7959, accuracy = 0.6250, precision = 0.5167, recall = 0.5800, F1 score = 0.5264
# Query ID 23/475
# Support set metrics: Loss = 1.0258, accuracy = 0.3625, precision = 0.3453, recall = 0.3367, F1 score = 0.3369
# Query set metrics: Loss = 0.8325, accuracy = 0.5000, precision = 0.4000, recall = 0.3867, F1 score = 0.3767
# Query ID 24/475
# Support set metrics: Loss = 1.0543, accuracy = 0.3250, precision = 0.3071, recall = 0.2967, F1 score = 0.3001
# Query set metrics: Loss = 0.8238, accuracy = 0.5000, precision = 0.5143, recall = 0.4933, F1 score = 0.4500
# Query ID 25/475
# Support set metrics: Loss = 1.0645, accuracy = 0.3250, precision = 0.3291, recall = 0.3000, F1 score = 0.3110
# Query set metrics: Loss = 1.0028, accuracy = 0.5000, precision = 0.5400, recall = 0.5905, F1 score = 0.5305
# Query ID 26/475
# Support set metrics: Loss = 1.0167, accuracy = 0.3250, precision = 0.3313, recall = 0.3033, F1 score = 0.3126
# Query set metrics: Loss = 0.9291, accuracy = 0.6250, precision = 0.5343, recall = 0.6833, F1 score = 0.5897
# Query ID 27/475
# Support set metrics: Loss = 1.0514, accuracy = 0.3500, precision = 0.3311, recall = 0.3200, F1 score = 0.3236
# Query set metrics: Loss = 1.0537, accuracy = 0.4375, precision = 0.4667, recall = 0.5267, F1 score = 0.4371
# Query ID 28/475
# Support set metrics: Loss = 0.9791, accuracy = 0.4125, precision = 0.4288, recall = 0.3900, F1 score = 0.4059
# Query set metrics: Loss = 1.1000, accuracy = 0.3750, precision = 0.4133, recall = 0.3571, F1 score = 0.3175
# Query ID 29/475
# Support set metrics: Loss = 1.0604, accuracy = 0.2875, precision = 0.2602, recall = 0.2600, F1 score = 0.2589
# Query set metrics: Loss = 0.5583, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7500
# Query ID 30/475
# Support set metrics: Loss = 1.0403, accuracy = 0.3125, precision = 0.2937, recall = 0.2900, F1 score = 0.2902
# Query set metrics: Loss = 1.0521, accuracy = 0.4375, precision = 0.3869, recall = 0.3625, F1 score = 0.3512
# Query ID 31/475
# Support set metrics: Loss = 1.0245, accuracy = 0.4125, precision = 0.3716, recall = 0.3800, F1 score = 0.3717
# Query set metrics: Loss = 1.1631, accuracy = 0.6250, precision = 0.5833, recall = 0.5500, F1 score = 0.5114
# Query ID 32/475
# Support set metrics: Loss = 0.9980, accuracy = 0.3500, precision = 0.3761, recall = 0.3233, F1 score = 0.3434
# Query set metrics: Loss = 0.7402, accuracy = 0.6250, precision = 0.7857, recall = 0.7833, F1 score = 0.6819
# Query ID 33/475
# Support set metrics: Loss = 1.0007, accuracy = 0.3750, precision = 0.3727, recall = 0.3467, F1 score = 0.3525
# Query set metrics: Loss = 0.7290, accuracy = 0.6250, precision = 0.5250, recall = 0.5167, F1 score = 0.5095
# Query ID 34/475
# Support set metrics: Loss = 1.0073, accuracy = 0.4000, precision = 0.4151, recall = 0.3800, F1 score = 0.3934
# Query set metrics: Loss = 1.0056, accuracy = 0.5625, precision = 0.4433, recall = 0.4533, F1 score = 0.4444
# Query ID 35/475
# Support set metrics: Loss = 1.0261, accuracy = 0.3625, precision = 0.3701, recall = 0.3400, F1 score = 0.3529
# Query set metrics: Loss = 0.6844, accuracy = 0.6875, precision = 0.5750, recall = 0.7000, F1 score = 0.6167
# Query ID 36/475
# Support set metrics: Loss = 0.9655, accuracy = 0.4125, precision = 0.4005, recall = 0.3867, F1 score = 0.3887
# Query set metrics: Loss = 0.7468, accuracy = 0.6875, precision = 0.4267, recall = 0.5000, F1 score = 0.4587
# Query ID 37/475
# Support set metrics: Loss = 1.0573, accuracy = 0.3875, precision = 0.3886, recall = 0.3567, F1 score = 0.3696
# Query set metrics: Loss = 0.8319, accuracy = 0.6875, precision = 0.7200, recall = 0.7267, F1 score = 0.6421
# Query ID 38/475
# Support set metrics: Loss = 1.0701, accuracy = 0.3625, precision = 0.3461, recall = 0.3300, F1 score = 0.3347
# Query set metrics: Loss = 0.9786, accuracy = 0.3750, precision = 0.2967, recall = 0.3900, F1 score = 0.3143
# Query ID 39/475
# Support set metrics: Loss = 1.0124, accuracy = 0.3875, precision = 0.3613, recall = 0.3633, F1 score = 0.3593
# Query set metrics: Loss = 0.8979, accuracy = 0.5625, precision = 0.4500, recall = 0.5000, F1 score = 0.4552
# Query ID 40/475
# Support set metrics: Loss = 0.9903, accuracy = 0.4000, precision = 0.3537, recall = 0.3867, F1 score = 0.3648
# Query set metrics: Loss = 0.9866, accuracy = 0.5000, precision = 0.5100, recall = 0.5619, F1 score = 0.4338
# Query ID 41/475
# Support set metrics: Loss = 0.9616, accuracy = 0.3875, precision = 0.4211, recall = 0.3600, F1 score = 0.3844
# Query set metrics: Loss = 1.1989, accuracy = 0.5625, precision = 0.4300, recall = 0.5000, F1 score = 0.4467
# Query ID 42/475
# Support set metrics: Loss = 0.9900, accuracy = 0.4375, precision = 0.4347, recall = 0.4133, F1 score = 0.4198
# Query set metrics: Loss = 1.0258, accuracy = 0.4375, precision = 0.6167, recall = 0.6250, F1 score = 0.5111
# Query ID 43/475
# Support set metrics: Loss = 0.9277, accuracy = 0.4750, precision = 0.4792, recall = 0.4467, F1 score = 0.4571
# Query set metrics: Loss = 1.4826, accuracy = 0.5625, precision = 0.4667, recall = 0.5300, F1 score = 0.4771
# Query ID 44/475
# Support set metrics: Loss = 1.0492, accuracy = 0.3750, precision = 0.3230, recall = 0.3433, F1 score = 0.3280
# Query set metrics: Loss = 0.7158, accuracy = 0.6875, precision = 0.8125, recall = 0.8071, F1 score = 0.7902
# Query ID 45/475
# Support set metrics: Loss = 1.0026, accuracy = 0.4375, precision = 0.4436, recall = 0.4167, F1 score = 0.4225
# Query set metrics: Loss = 0.8176, accuracy = 0.6250, precision = 0.7000, recall = 0.6667, F1 score = 0.6402
# Query ID 46/475
# Support set metrics: Loss = 1.0022, accuracy = 0.3750, precision = 0.3860, recall = 0.3600, F1 score = 0.3693
# Query set metrics: Loss = 1.2482, accuracy = 0.2500, precision = 0.1150, recall = 0.2667, F1 score = 0.1591
# Query ID 47/475
# Support set metrics: Loss = 1.0700, accuracy = 0.3375, precision = 0.3468, recall = 0.3100, F1 score = 0.3256
# Query set metrics: Loss = 0.7898, accuracy = 0.6875, precision = 0.6033, recall = 0.6533, F1 score = 0.6248
# Query ID 48/475
# Support set metrics: Loss = 1.0894, accuracy = 0.2875, precision = 0.3050, recall = 0.2700, F1 score = 0.2835
# Query set metrics: Loss = 0.8150, accuracy = 0.4375, precision = 0.5467, recall = 0.4333, F1 score = 0.4556
# Query ID 49/475
# Support set metrics: Loss = 1.0536, accuracy = 0.3875, precision = 0.3694, recall = 0.3600, F1 score = 0.3609
# Query set metrics: Loss = 1.4052, accuracy = 0.4375, precision = 0.5667, recall = 0.4833, F1 score = 0.4610
# Query ID 50/475
# Support set metrics: Loss = 1.0505, accuracy = 0.3500, precision = 0.3525, recall = 0.3233, F1 score = 0.3348
# Query set metrics: Loss = 1.0842, accuracy = 0.4375, precision = 0.4571, recall = 0.4417, F1 score = 0.3780
# Query ID 51/475
# Support set metrics: Loss = 1.0540, accuracy = 0.3750, precision = 0.3416, recall = 0.3467, F1 score = 0.3396
# Query set metrics: Loss = 0.9226, accuracy = 0.5625, precision = 0.5800, recall = 0.6600, F1 score = 0.6000
# Query ID 52/475
# Support set metrics: Loss = 0.9933, accuracy = 0.3750, precision = 0.3632, recall = 0.3500, F1 score = 0.3524
# Query set metrics: Loss = 0.7748, accuracy = 0.5000, precision = 0.5000, recall = 0.4800, F1 score = 0.4622
# Query ID 53/475
# Support set metrics: Loss = 0.9938, accuracy = 0.4375, precision = 0.4474, recall = 0.4167, F1 score = 0.4293
# Query set metrics: Loss = 1.3892, accuracy = 0.4375, precision = 0.6133, recall = 0.4467, F1 score = 0.4671
# Query ID 54/475
# Support set metrics: Loss = 1.0401, accuracy = 0.3750, precision = 0.3570, recall = 0.3467, F1 score = 0.3449
# Query set metrics: Loss = 1.3014, accuracy = 0.4375, precision = 0.5467, recall = 0.4200, F1 score = 0.4190
# Query ID 55/475
# Support set metrics: Loss = 0.9691, accuracy = 0.4125, precision = 0.3837, recall = 0.3867, F1 score = 0.3818
# Query set metrics: Loss = 0.9252, accuracy = 0.6250, precision = 0.3750, recall = 0.3833, F1 score = 0.3676
# Query ID 56/475
# Support set metrics: Loss = 0.9454, accuracy = 0.4750, precision = 0.4856, recall = 0.4500, F1 score = 0.4616
# Query set metrics: Loss = 1.0328, accuracy = 0.5000, precision = 0.3429, recall = 0.3667, F1 score = 0.3538
# Query ID 57/475
# Support set metrics: Loss = 0.9886, accuracy = 0.4875, precision = 0.4857, recall = 0.4633, F1 score = 0.4674
# Query set metrics: Loss = 1.4696, accuracy = 0.5000, precision = 0.4917, recall = 0.5667, F1 score = 0.4762
# Query ID 58/475
# Support set metrics: Loss = 1.0325, accuracy = 0.3375, precision = 0.3204, recall = 0.3167, F1 score = 0.3158
# Query set metrics: Loss = 0.7533, accuracy = 0.7500, precision = 0.6133, recall = 0.6333, F1 score = 0.5810
# Query ID 59/475
# Support set metrics: Loss = 1.0391, accuracy = 0.3125, precision = 0.3241, recall = 0.2833, F1 score = 0.3011
# Query set metrics: Loss = 0.9782, accuracy = 0.5625, precision = 0.7000, recall = 0.6133, F1 score = 0.6222
# Query ID 60/475
# Support set metrics: Loss = 1.0467, accuracy = 0.4000, precision = 0.3941, recall = 0.3733, F1 score = 0.3810
# Query set metrics: Loss = 0.8186, accuracy = 0.6875, precision = 0.5300, recall = 0.5833, F1 score = 0.5455
# Query ID 61/475
# Support set metrics: Loss = 1.0586, accuracy = 0.3000, precision = 0.2962, recall = 0.2733, F1 score = 0.2834
# Query set metrics: Loss = 1.0823, accuracy = 0.6250, precision = 0.5700, recall = 0.6500, F1 score = 0.5667
# Query ID 62/475
# Support set metrics: Loss = 0.9804, accuracy = 0.4250, precision = 0.4362, recall = 0.4067, F1 score = 0.4184
# Query set metrics: Loss = 1.0781, accuracy = 0.6250, precision = 0.6433, recall = 0.5433, F1 score = 0.5448
# Query ID 63/475
# Support set metrics: Loss = 1.1184, accuracy = 0.3625, precision = 0.3510, recall = 0.3367, F1 score = 0.3423
# Query set metrics: Loss = 0.6466, accuracy = 0.6875, precision = 0.7812, recall = 0.7125, F1 score = 0.7131
# Query ID 64/475
# Support set metrics: Loss = 1.0097, accuracy = 0.4625, precision = 0.4581, recall = 0.4400, F1 score = 0.4415
# Query set metrics: Loss = 0.8319, accuracy = 0.6875, precision = 0.7714, recall = 0.6833, F1 score = 0.6456
# Query ID 65/475
# Support set metrics: Loss = 1.0065, accuracy = 0.4500, precision = 0.4541, recall = 0.4300, F1 score = 0.4380
# Query set metrics: Loss = 0.8317, accuracy = 0.5625, precision = 0.5367, recall = 0.6200, F1 score = 0.5167
# Query ID 66/475
# Support set metrics: Loss = 1.0858, accuracy = 0.3000, precision = 0.2839, recall = 0.2733, F1 score = 0.2772
# Query set metrics: Loss = 1.0476, accuracy = 0.5625, precision = 0.4500, recall = 0.6000, F1 score = 0.4857
# Query ID 67/475
# Support set metrics: Loss = 0.9748, accuracy = 0.3750, precision = 0.3683, recall = 0.3500, F1 score = 0.3505
# Query set metrics: Loss = 0.8042, accuracy = 0.8125, precision = 0.8542, recall = 0.7625, F1 score = 0.7860
# Query ID 68/475
# Support set metrics: Loss = 1.0192, accuracy = 0.3625, precision = 0.3434, recall = 0.3367, F1 score = 0.3339
# Query set metrics: Loss = 1.1749, accuracy = 0.5000, precision = 0.4905, recall = 0.6133, F1 score = 0.5032
# Query ID 69/475
# Support set metrics: Loss = 0.9901, accuracy = 0.3500, precision = 0.3157, recall = 0.3233, F1 score = 0.3146
# Query set metrics: Loss = 0.9333, accuracy = 0.6875, precision = 0.7333, recall = 0.6833, F1 score = 0.6714
# Query ID 70/475
# Support set metrics: Loss = 1.0425, accuracy = 0.3625, precision = 0.3363, recall = 0.3333, F1 score = 0.3326
# Query set metrics: Loss = 1.3797, accuracy = 0.3750, precision = 0.4067, recall = 0.3867, F1 score = 0.3476
# Query ID 71/475
# Support set metrics: Loss = 0.9726, accuracy = 0.3875, precision = 0.3844, recall = 0.3600, F1 score = 0.3690
# Query set metrics: Loss = 0.8838, accuracy = 0.5625, precision = 0.3833, recall = 0.4833, F1 score = 0.4243
# Query ID 72/475
# Support set metrics: Loss = 1.0032, accuracy = 0.4250, precision = 0.4228, recall = 0.4067, F1 score = 0.4103
# Query set metrics: Loss = 0.7992, accuracy = 0.5625, precision = 0.4750, recall = 0.5500, F1 score = 0.4683
# Query ID 73/475
# Support set metrics: Loss = 0.9862, accuracy = 0.4250, precision = 0.4325, recall = 0.4033, F1 score = 0.4135
# Query set metrics: Loss = 0.9467, accuracy = 0.6250, precision = 0.5400, recall = 0.5367, F1 score = 0.5133
# Query ID 74/475
# Support set metrics: Loss = 1.0511, accuracy = 0.3250, precision = 0.3128, recall = 0.3000, F1 score = 0.3037
# Query set metrics: Loss = 0.8894, accuracy = 0.5625, precision = 0.4333, recall = 0.5333, F1 score = 0.4600
# Query ID 75/475
# Support set metrics: Loss = 1.0587, accuracy = 0.3875, precision = 0.3895, recall = 0.3633, F1 score = 0.3735
# Query set metrics: Loss = 0.9446, accuracy = 0.5625, precision = 0.4400, recall = 0.5000, F1 score = 0.4314
# Query ID 76/475
# Support set metrics: Loss = 1.0455, accuracy = 0.3750, precision = 0.3365, recall = 0.3533, F1 score = 0.3398
# Query set metrics: Loss = 0.9823, accuracy = 0.5625, precision = 0.6643, recall = 0.6400, F1 score = 0.5321
# Query ID 77/475
# Support set metrics: Loss = 1.0463, accuracy = 0.3750, precision = 0.3844, recall = 0.3500, F1 score = 0.3647
# Query set metrics: Loss = 1.6436, accuracy = 0.3125, precision = 0.2833, recall = 0.3333, F1 score = 0.2861
# Query ID 78/475
# Support set metrics: Loss = 0.9915, accuracy = 0.3500, precision = 0.3603, recall = 0.3233, F1 score = 0.3398
# Query set metrics: Loss = 1.0321, accuracy = 0.6875, precision = 0.6033, recall = 0.6700, F1 score = 0.6100
# Query ID 79/475
# Support set metrics: Loss = 1.0136, accuracy = 0.3125, precision = 0.3223, recall = 0.2833, F1 score = 0.2987
# Query set metrics: Loss = 1.1970, accuracy = 0.3750, precision = 0.5208, recall = 0.4357, F1 score = 0.3542
# Query ID 80/475
# Support set metrics: Loss = 0.9762, accuracy = 0.4250, precision = 0.4429, recall = 0.4033, F1 score = 0.4168
# Query set metrics: Loss = 0.7377, accuracy = 0.6250, precision = 0.6633, recall = 0.6500, F1 score = 0.6443
# Query ID 81/475
# Support set metrics: Loss = 1.0003, accuracy = 0.3750, precision = 0.3756, recall = 0.3500, F1 score = 0.3599
# Query set metrics: Loss = 0.7777, accuracy = 0.5000, precision = 0.3429, recall = 0.4000, F1 score = 0.3610
# Query ID 82/475
# Support set metrics: Loss = 1.0242, accuracy = 0.3000, precision = 0.2975, recall = 0.2767, F1 score = 0.2845
# Query set metrics: Loss = 0.6662, accuracy = 0.6250, precision = 0.5893, recall = 0.5583, F1 score = 0.5641
# Query ID 83/475
# Support set metrics: Loss = 1.0053, accuracy = 0.4375, precision = 0.4579, recall = 0.4233, F1 score = 0.4306
# Query set metrics: Loss = 1.4794, accuracy = 0.3125, precision = 0.2524, recall = 0.3067, F1 score = 0.2500
# Query ID 84/475
# Support set metrics: Loss = 0.9830, accuracy = 0.4000, precision = 0.4037, recall = 0.3767, F1 score = 0.3883
# Query set metrics: Loss = 1.1830, accuracy = 0.4375, precision = 0.5533, recall = 0.4867, F1 score = 0.4105
# Query ID 85/475
# Support set metrics: Loss = 1.0313, accuracy = 0.4500, precision = 0.4439, recall = 0.4233, F1 score = 0.4297
# Query set metrics: Loss = 0.8384, accuracy = 0.6250, precision = 0.6533, recall = 0.6667, F1 score = 0.5933
# Query ID 86/475
# Support set metrics: Loss = 0.9960, accuracy = 0.3875, precision = 0.3785, recall = 0.3600, F1 score = 0.3659
# Query set metrics: Loss = 0.6997, accuracy = 0.6250, precision = 0.3700, recall = 0.4500, F1 score = 0.3881
# Query ID 87/475
# Support set metrics: Loss = 1.0441, accuracy = 0.3500, precision = 0.3387, recall = 0.3267, F1 score = 0.3294
# Query set metrics: Loss = 0.9337, accuracy = 0.6250, precision = 0.6200, recall = 0.6167, F1 score = 0.5714
# Query ID 88/475
# Support set metrics: Loss = 1.0245, accuracy = 0.3375, precision = 0.3379, recall = 0.3100, F1 score = 0.3205
# Query set metrics: Loss = 0.6641, accuracy = 0.7500, precision = 0.6533, recall = 0.6500, F1 score = 0.6352
# Query ID 89/475
# Support set metrics: Loss = 1.0452, accuracy = 0.4125, precision = 0.3976, recall = 0.3833, F1 score = 0.3808
# Query set metrics: Loss = 0.9463, accuracy = 0.6250, precision = 0.6333, recall = 0.8057, F1 score = 0.6033
# Query ID 90/475
# Support set metrics: Loss = 0.9530, accuracy = 0.4250, precision = 0.4380, recall = 0.4000, F1 score = 0.4127
# Query set metrics: Loss = 1.1351, accuracy = 0.4375, precision = 0.3133, recall = 0.4333, F1 score = 0.3556
# Query ID 91/475
# Support set metrics: Loss = 1.0122, accuracy = 0.3625, precision = 0.3367, recall = 0.3333, F1 score = 0.3308
# Query set metrics: Loss = 0.6471, accuracy = 0.6250, precision = 0.5000, recall = 0.5733, F1 score = 0.5277
# Query ID 92/475
# Support set metrics: Loss = 1.0260, accuracy = 0.3625, precision = 0.3406, recall = 0.3367, F1 score = 0.3351
# Query set metrics: Loss = 0.8964, accuracy = 0.6250, precision = 0.5667, recall = 0.5800, F1 score = 0.5267
# Query ID 93/475
# Support set metrics: Loss = 1.0351, accuracy = 0.4000, precision = 0.3949, recall = 0.3733, F1 score = 0.3791
# Query set metrics: Loss = 0.8525, accuracy = 0.5625, precision = 0.5000, recall = 0.4900, F1 score = 0.4619
# Query ID 94/475
# Support set metrics: Loss = 1.0043, accuracy = 0.3625, precision = 0.3699, recall = 0.3333, F1 score = 0.3451
# Query set metrics: Loss = 1.4254, accuracy = 0.4375, precision = 0.3133, recall = 0.3333, F1 score = 0.3133
# Query ID 95/475
# Support set metrics: Loss = 0.9675, accuracy = 0.4125, precision = 0.4095, recall = 0.3800, F1 score = 0.3851
# Query set metrics: Loss = 0.5657, accuracy = 0.8750, precision = 0.8600, recall = 0.8667, F1 score = 0.8311
# Query ID 96/475
# Support set metrics: Loss = 1.0193, accuracy = 0.3250, precision = 0.3139, recall = 0.2967, F1 score = 0.3000
# Query set metrics: Loss = 0.8904, accuracy = 0.6875, precision = 0.7667, recall = 0.7167, F1 score = 0.6743
# Query ID 97/475
# Support set metrics: Loss = 0.9773, accuracy = 0.4250, precision = 0.4239, recall = 0.4000, F1 score = 0.4092
# Query set metrics: Loss = 1.1653, accuracy = 0.6250, precision = 0.6250, recall = 0.4851, F1 score = 0.5451
# Query ID 98/475
# Support set metrics: Loss = 0.9948, accuracy = 0.4000, precision = 0.4044, recall = 0.3733, F1 score = 0.3852
# Query set metrics: Loss = 1.0172, accuracy = 0.6250, precision = 0.5917, recall = 0.5667, F1 score = 0.5538
# Query ID 99/475
# Support set metrics: Loss = 1.0527, accuracy = 0.3375, precision = 0.3621, recall = 0.3167, F1 score = 0.3349
# Query set metrics: Loss = 0.7052, accuracy = 0.6875, precision = 0.5267, recall = 0.6600, F1 score = 0.5829
# Query ID 100/475
# Support set metrics: Loss = 1.0138, accuracy = 0.4000, precision = 0.3912, recall = 0.3733, F1 score = 0.3764
# Query set metrics: Loss = 0.7284, accuracy = 0.8125, precision = 0.8929, recall = 0.8000, F1 score = 0.7981
# Query ID 101/475
# Support set metrics: Loss = 1.0375, accuracy = 0.3625, precision = 0.3598, recall = 0.3333, F1 score = 0.3418
# Query set metrics: Loss = 1.1954, accuracy = 0.4375, precision = 0.4000, recall = 0.4300, F1 score = 0.4060
# Query ID 102/475
# Support set metrics: Loss = 0.9933, accuracy = 0.4500, precision = 0.4602, recall = 0.4267, F1 score = 0.4405
# Query set metrics: Loss = 1.0942, accuracy = 0.4375, precision = 0.4333, recall = 0.4333, F1 score = 0.4133
# Query ID 103/475
# Support set metrics: Loss = 1.0136, accuracy = 0.3875, precision = 0.3730, recall = 0.3600, F1 score = 0.3633
# Query set metrics: Loss = 1.2596, accuracy = 0.5000, precision = 0.4357, recall = 0.4700, F1 score = 0.4258
# Query ID 104/475
# Support set metrics: Loss = 0.9976, accuracy = 0.3750, precision = 0.3626, recall = 0.3500, F1 score = 0.3524
# Query set metrics: Loss = 0.7488, accuracy = 0.6250, precision = 0.5000, recall = 0.6833, F1 score = 0.5690
# Query ID 105/475
# Support set metrics: Loss = 1.0563, accuracy = 0.3625, precision = 0.3612, recall = 0.3367, F1 score = 0.3470
# Query set metrics: Loss = 0.6872, accuracy = 0.5625, precision = 0.6000, recall = 0.5500, F1 score = 0.5210
# Query ID 106/475
# Support set metrics: Loss = 1.0280, accuracy = 0.3750, precision = 0.3855, recall = 0.3467, F1 score = 0.3605
# Query set metrics: Loss = 1.3043, accuracy = 0.4375, precision = 0.4524, recall = 0.5667, F1 score = 0.3994
# Query ID 107/475
# Support set metrics: Loss = 1.0656, accuracy = 0.3500, precision = 0.3487, recall = 0.3167, F1 score = 0.3303
# Query set metrics: Loss = 0.8818, accuracy = 0.6250, precision = 0.6333, recall = 0.6000, F1 score = 0.5867
# Query ID 108/475
# Support set metrics: Loss = 0.9762, accuracy = 0.4125, precision = 0.4303, recall = 0.3867, F1 score = 0.4057
# Query set metrics: Loss = 1.2688, accuracy = 0.3125, precision = 0.3524, recall = 0.2900, F1 score = 0.2438
# Query ID 109/475
# Support set metrics: Loss = 0.9599, accuracy = 0.4750, precision = 0.4720, recall = 0.4433, F1 score = 0.4468
# Query set metrics: Loss = 1.1461, accuracy = 0.3750, precision = 0.3400, recall = 0.4467, F1 score = 0.3722
# Query ID 110/475
# Support set metrics: Loss = 0.9955, accuracy = 0.3625, precision = 0.3493, recall = 0.3367, F1 score = 0.3391
# Query set metrics: Loss = 1.3081, accuracy = 0.4375, precision = 0.3367, recall = 0.4667, F1 score = 0.3871
# Query ID 111/475
# Support set metrics: Loss = 0.9444, accuracy = 0.4250, precision = 0.4329, recall = 0.4000, F1 score = 0.4100
# Query set metrics: Loss = 0.8436, accuracy = 0.4375, precision = 0.3067, recall = 0.3067, F1 score = 0.3067
# Query ID 112/475
# Support set metrics: Loss = 1.0289, accuracy = 0.3500, precision = 0.3368, recall = 0.3267, F1 score = 0.3274
# Query set metrics: Loss = 0.6922, accuracy = 0.6250, precision = 0.3848, recall = 0.5333, F1 score = 0.4322
# Query ID 113/475
# Support set metrics: Loss = 1.0044, accuracy = 0.4500, precision = 0.4549, recall = 0.4233, F1 score = 0.4368
# Query set metrics: Loss = 1.1968, accuracy = 0.5625, precision = 0.4000, recall = 0.4667, F1 score = 0.4076
# Query ID 114/475
# Support set metrics: Loss = 1.0168, accuracy = 0.3625, precision = 0.3526, recall = 0.3367, F1 score = 0.3371
# Query set metrics: Loss = 1.0117, accuracy = 0.4375, precision = 0.5000, recall = 0.5233, F1 score = 0.4367
# Query ID 115/475
# Support set metrics: Loss = 0.9612, accuracy = 0.4000, precision = 0.3723, recall = 0.3700, F1 score = 0.3637
# Query set metrics: Loss = 1.0926, accuracy = 0.5000, precision = 0.4100, recall = 0.3833, F1 score = 0.3955
# Query ID 116/475
# Support set metrics: Loss = 1.0763, accuracy = 0.3250, precision = 0.3384, recall = 0.3067, F1 score = 0.3191
# Query set metrics: Loss = 1.1814, accuracy = 0.5000, precision = 0.5667, recall = 0.6500, F1 score = 0.5381
# Query ID 117/475
# Support set metrics: Loss = 0.9954, accuracy = 0.3875, precision = 0.3699, recall = 0.3600, F1 score = 0.3600
# Query set metrics: Loss = 0.9411, accuracy = 0.6250, precision = 0.5000, recall = 0.6429, F1 score = 0.5000
# Query ID 118/475
# Support set metrics: Loss = 1.0521, accuracy = 0.3750, precision = 0.3631, recall = 0.3467, F1 score = 0.3515
# Query set metrics: Loss = 0.9760, accuracy = 0.6250, precision = 0.6367, recall = 0.6667, F1 score = 0.6014
# Query ID 119/475
# Support set metrics: Loss = 1.0584, accuracy = 0.3500, precision = 0.3240, recall = 0.3167, F1 score = 0.3168
# Query set metrics: Loss = 0.8709, accuracy = 0.5625, precision = 0.6800, recall = 0.7333, F1 score = 0.5714
# Query ID 120/475
# Support set metrics: Loss = 1.0288, accuracy = 0.3750, precision = 0.3425, recall = 0.3567, F1 score = 0.3462
# Query set metrics: Loss = 0.7708, accuracy = 0.6875, precision = 0.6700, recall = 0.7500, F1 score = 0.6762
# Query ID 121/475
# Support set metrics: Loss = 0.9725, accuracy = 0.4500, precision = 0.4420, recall = 0.4233, F1 score = 0.4214
# Query set metrics: Loss = 1.0968, accuracy = 0.6250, precision = 0.5676, recall = 0.6833, F1 score = 0.6121
# Query ID 122/475
# Support set metrics: Loss = 1.0829, accuracy = 0.3500, precision = 0.3241, recall = 0.3267, F1 score = 0.3222
# Query set metrics: Loss = 0.9855, accuracy = 0.5000, precision = 0.4000, recall = 0.5000, F1 score = 0.4389
# Query ID 123/475
# Support set metrics: Loss = 1.0176, accuracy = 0.3500, precision = 0.3472, recall = 0.3233, F1 score = 0.3310
# Query set metrics: Loss = 0.8734, accuracy = 0.6875, precision = 0.7700, recall = 0.6267, F1 score = 0.6378
# Query ID 124/475
# Support set metrics: Loss = 1.0243, accuracy = 0.3625, precision = 0.3629, recall = 0.3400, F1 score = 0.3487
# Query set metrics: Loss = 0.9136, accuracy = 0.5625, precision = 0.6750, recall = 0.6167, F1 score = 0.5679
# Query ID 125/475
# Support set metrics: Loss = 1.0200, accuracy = 0.3875, precision = 0.3980, recall = 0.3567, F1 score = 0.3728
# Query set metrics: Loss = 1.3021, accuracy = 0.4375, precision = 0.4071, recall = 0.4625, F1 score = 0.3953
# Query ID 126/475
# Support set metrics: Loss = 1.0275, accuracy = 0.4125, precision = 0.3653, recall = 0.3867, F1 score = 0.3684
# Query set metrics: Loss = 0.7589, accuracy = 0.6250, precision = 0.6600, recall = 0.6000, F1 score = 0.6054
# Query ID 127/475
# Support set metrics: Loss = 0.9592, accuracy = 0.4500, precision = 0.4491, recall = 0.4267, F1 score = 0.4331
# Query set metrics: Loss = 0.8195, accuracy = 0.6250, precision = 0.5533, recall = 0.6500, F1 score = 0.5843
# Query ID 128/475
# Support set metrics: Loss = 1.0510, accuracy = 0.3375, precision = 0.3378, recall = 0.3100, F1 score = 0.3229
# Query set metrics: Loss = 0.9023, accuracy = 0.5000, precision = 0.5000, recall = 0.4967, F1 score = 0.4610
# Query ID 129/475
# Support set metrics: Loss = 0.9947, accuracy = 0.3875, precision = 0.4051, recall = 0.3600, F1 score = 0.3762
# Query set metrics: Loss = 0.6725, accuracy = 0.6250, precision = 0.5700, recall = 0.6400, F1 score = 0.5214
# Query ID 130/475
# Support set metrics: Loss = 0.9618, accuracy = 0.4375, precision = 0.4411, recall = 0.4167, F1 score = 0.4248
# Query set metrics: Loss = 0.7873, accuracy = 0.7500, precision = 0.8095, recall = 0.7333, F1 score = 0.6667
# Query ID 131/475
# Support set metrics: Loss = 1.0687, accuracy = 0.3625, precision = 0.3671, recall = 0.3433, F1 score = 0.3538
# Query set metrics: Loss = 1.1031, accuracy = 0.5625, precision = 0.6933, recall = 0.6667, F1 score = 0.5619
# Query ID 132/475
# Support set metrics: Loss = 0.9394, accuracy = 0.4500, precision = 0.4683, recall = 0.4267, F1 score = 0.4431
# Query set metrics: Loss = 1.3967, accuracy = 0.4375, precision = 0.3667, recall = 0.4467, F1 score = 0.3822
# Query ID 133/475
# Support set metrics: Loss = 1.1019, accuracy = 0.3125, precision = 0.2977, recall = 0.2833, F1 score = 0.2882
# Query set metrics: Loss = 0.8942, accuracy = 0.4375, precision = 0.2833, recall = 0.4000, F1 score = 0.3285
# Query ID 134/475
# Support set metrics: Loss = 1.0052, accuracy = 0.3875, precision = 0.4011, recall = 0.3633, F1 score = 0.3796
# Query set metrics: Loss = 1.0981, accuracy = 0.4375, precision = 0.3333, recall = 0.5200, F1 score = 0.3867
# Query ID 135/475
# Support set metrics: Loss = 0.9223, accuracy = 0.4875, precision = 0.4871, recall = 0.4633, F1 score = 0.4662
# Query set metrics: Loss = 0.5721, accuracy = 0.7500, precision = 0.6833, recall = 0.6833, F1 score = 0.6700
# Query ID 136/475
# Support set metrics: Loss = 1.0037, accuracy = 0.3625, precision = 0.3515, recall = 0.3400, F1 score = 0.3418
# Query set metrics: Loss = 1.2375, accuracy = 0.5625, precision = 0.4667, recall = 0.4857, F1 score = 0.4352
# Query ID 137/475
# Support set metrics: Loss = 1.0423, accuracy = 0.3375, precision = 0.3398, recall = 0.3100, F1 score = 0.3209
# Query set metrics: Loss = 1.0982, accuracy = 0.4375, precision = 0.3643, recall = 0.5000, F1 score = 0.3588
# Query ID 138/475
# Support set metrics: Loss = 1.0205, accuracy = 0.3500, precision = 0.3227, recall = 0.3233, F1 score = 0.3205
# Query set metrics: Loss = 0.8658, accuracy = 0.7500, precision = 0.8133, recall = 0.7500, F1 score = 0.7444
# Query ID 139/475
# Support set metrics: Loss = 1.0697, accuracy = 0.3875, precision = 0.3854, recall = 0.3700, F1 score = 0.3761
# Query set metrics: Loss = 0.6888, accuracy = 0.5625, precision = 0.5417, recall = 0.5417, F1 score = 0.5125
# Query ID 140/475
# Support set metrics: Loss = 0.9563, accuracy = 0.5125, precision = 0.5315, recall = 0.4900, F1 score = 0.5047
# Query set metrics: Loss = 0.6401, accuracy = 0.7500, precision = 0.8857, recall = 0.8400, F1 score = 0.7867
# Query ID 141/475
# Support set metrics: Loss = 1.1017, accuracy = 0.3375, precision = 0.3117, recall = 0.3033, F1 score = 0.3055
# Query set metrics: Loss = 0.7346, accuracy = 0.6875, precision = 0.5300, recall = 0.6000, F1 score = 0.5611
# Query ID 142/475
# Support set metrics: Loss = 1.0663, accuracy = 0.2750, precision = 0.2808, recall = 0.2533, F1 score = 0.2653
# Query set metrics: Loss = 0.8257, accuracy = 0.6250, precision = 0.7400, recall = 0.6800, F1 score = 0.6714
# Query ID 143/475
# Support set metrics: Loss = 1.0739, accuracy = 0.3250, precision = 0.3094, recall = 0.2967, F1 score = 0.3001
# Query set metrics: Loss = 0.5802, accuracy = 0.7500, precision = 0.8300, recall = 0.7700, F1 score = 0.7476
# Query ID 144/475
# Support set metrics: Loss = 1.0692, accuracy = 0.3375, precision = 0.3207, recall = 0.3033, F1 score = 0.3090
# Query set metrics: Loss = 1.1091, accuracy = 0.5625, precision = 0.4667, recall = 0.6500, F1 score = 0.4810
# Query ID 145/475
# Support set metrics: Loss = 1.0668, accuracy = 0.3625, precision = 0.3347, recall = 0.3300, F1 score = 0.3295
# Query set metrics: Loss = 1.0863, accuracy = 0.5625, precision = 0.4333, recall = 0.5167, F1 score = 0.4638
# Query ID 146/475
# Support set metrics: Loss = 0.9363, accuracy = 0.5125, precision = 0.4850, recall = 0.4900, F1 score = 0.4783
# Query set metrics: Loss = 0.9798, accuracy = 0.6250, precision = 0.6429, recall = 0.5095, F1 score = 0.5485
# Query ID 147/475
# Support set metrics: Loss = 1.0325, accuracy = 0.3375, precision = 0.3591, recall = 0.3167, F1 score = 0.3337
# Query set metrics: Loss = 0.7769, accuracy = 0.6875, precision = 0.6867, recall = 0.6867, F1 score = 0.6667
# Query ID 148/475
# Support set metrics: Loss = 0.8942, accuracy = 0.5125, precision = 0.4794, recall = 0.4900, F1 score = 0.4714
# Query set metrics: Loss = 1.0463, accuracy = 0.5625, precision = 0.5633, recall = 0.5800, F1 score = 0.5648
# Query ID 149/475
# Support set metrics: Loss = 1.0176, accuracy = 0.4125, precision = 0.4184, recall = 0.3867, F1 score = 0.3940
# Query set metrics: Loss = 0.9231, accuracy = 0.6875, precision = 0.8667, recall = 0.6750, F1 score = 0.7136
# Query ID 150/475
# Support set metrics: Loss = 1.0532, accuracy = 0.3375, precision = 0.3218, recall = 0.3033, F1 score = 0.3104
# Query set metrics: Loss = 0.8265, accuracy = 0.6250, precision = 0.5417, recall = 0.6458, F1 score = 0.5476
# Query ID 151/475
# Support set metrics: Loss = 1.0178, accuracy = 0.4000, precision = 0.3868, recall = 0.3767, F1 score = 0.3771
# Query set metrics: Loss = 0.7543, accuracy = 0.5625, precision = 0.5400, recall = 0.5733, F1 score = 0.4778
# Query ID 152/475
# Support set metrics: Loss = 0.9685, accuracy = 0.4000, precision = 0.4199, recall = 0.3767, F1 score = 0.3944
# Query set metrics: Loss = 0.8799, accuracy = 0.5000, precision = 0.3810, recall = 0.4433, F1 score = 0.4038
# Query ID 153/475
# Support set metrics: Loss = 1.0329, accuracy = 0.3625, precision = 0.3674, recall = 0.3400, F1 score = 0.3500
# Query set metrics: Loss = 0.4792, accuracy = 0.8125, precision = 0.9583, recall = 0.7667, F1 score = 0.8296
# Query ID 154/475
# Support set metrics: Loss = 0.9842, accuracy = 0.4250, precision = 0.4237, recall = 0.3967, F1 score = 0.4063
# Query set metrics: Loss = 1.0097, accuracy = 0.5000, precision = 0.3857, recall = 0.5000, F1 score = 0.3867
# Query ID 155/475
# Support set metrics: Loss = 1.0296, accuracy = 0.3500, precision = 0.3656, recall = 0.3233, F1 score = 0.3425
# Query set metrics: Loss = 0.6797, accuracy = 0.7500, precision = 0.8467, recall = 0.7833, F1 score = 0.7361
# Query ID 156/475
# Support set metrics: Loss = 1.0239, accuracy = 0.4500, precision = 0.4412, recall = 0.4300, F1 score = 0.4303
# Query set metrics: Loss = 0.6011, accuracy = 0.7500, precision = 0.7429, recall = 0.7500, F1 score = 0.7114
# Query ID 157/475
# Support set metrics: Loss = 1.0970, accuracy = 0.3000, precision = 0.2903, recall = 0.2767, F1 score = 0.2806
# Query set metrics: Loss = 0.7303, accuracy = 0.7500, precision = 0.7167, recall = 0.7267, F1 score = 0.7159
# Query ID 158/475
# Support set metrics: Loss = 0.9969, accuracy = 0.3375, precision = 0.3076, recall = 0.3100, F1 score = 0.3045
# Query set metrics: Loss = 0.7529, accuracy = 0.5625, precision = 0.3667, recall = 0.5500, F1 score = 0.4400
# Query ID 159/475
# Support set metrics: Loss = 0.9683, accuracy = 0.3875, precision = 0.3628, recall = 0.3633, F1 score = 0.3583
# Query set metrics: Loss = 0.8540, accuracy = 0.5625, precision = 0.5500, recall = 0.6900, F1 score = 0.5467
# Query ID 160/475
# Support set metrics: Loss = 1.0641, accuracy = 0.3750, precision = 0.3603, recall = 0.3500, F1 score = 0.3530
# Query set metrics: Loss = 1.1064, accuracy = 0.4375, precision = 0.5571, recall = 0.4733, F1 score = 0.4537
# Query ID 161/475
# Support set metrics: Loss = 0.9829, accuracy = 0.4000, precision = 0.3990, recall = 0.3800, F1 score = 0.3838
# Query set metrics: Loss = 1.3898, accuracy = 0.3750, precision = 0.2533, recall = 0.2700, F1 score = 0.2600
# Query ID 162/475
# Support set metrics: Loss = 1.0230, accuracy = 0.3375, precision = 0.3115, recall = 0.3100, F1 score = 0.3066
# Query set metrics: Loss = 0.6819, accuracy = 0.8125, precision = 0.8167, recall = 0.8333, F1 score = 0.7648
# Query ID 163/475
# Support set metrics: Loss = 1.0647, accuracy = 0.2875, precision = 0.2804, recall = 0.2700, F1 score = 0.2742
# Query set metrics: Loss = 1.4041, accuracy = 0.5625, precision = 0.5119, recall = 0.4750, F1 score = 0.4762
# Query ID 164/475
# Support set metrics: Loss = 1.0209, accuracy = 0.3125, precision = 0.3223, recall = 0.2900, F1 score = 0.3040
# Query set metrics: Loss = 1.0837, accuracy = 0.6250, precision = 0.5600, recall = 0.5333, F1 score = 0.5056
# Query ID 165/475
# Support set metrics: Loss = 1.0907, accuracy = 0.3250, precision = 0.3291, recall = 0.2967, F1 score = 0.3099
# Query set metrics: Loss = 0.7474, accuracy = 0.6875, precision = 0.5800, recall = 0.5700, F1 score = 0.5611
# Query ID 166/475
# Support set metrics: Loss = 1.0424, accuracy = 0.3875, precision = 0.3757, recall = 0.3600, F1 score = 0.3661
# Query set metrics: Loss = 0.9378, accuracy = 0.6875, precision = 0.4183, recall = 0.5333, F1 score = 0.4593
# Query ID 167/475
# Support set metrics: Loss = 1.0176, accuracy = 0.4250, precision = 0.3766, recall = 0.4000, F1 score = 0.3833
# Query set metrics: Loss = 1.1229, accuracy = 0.5625, precision = 0.5690, recall = 0.5333, F1 score = 0.5258
# Query ID 168/475
# Support set metrics: Loss = 0.9999, accuracy = 0.3875, precision = 0.3956, recall = 0.3633, F1 score = 0.3742
# Query set metrics: Loss = 0.9860, accuracy = 0.5625, precision = 0.5333, recall = 0.5333, F1 score = 0.4667
# Query ID 169/475
# Support set metrics: Loss = 1.0169, accuracy = 0.3250, precision = 0.3199, recall = 0.2967, F1 score = 0.3050
# Query set metrics: Loss = 0.7413, accuracy = 0.6875, precision = 0.7095, recall = 0.6333, F1 score = 0.6476
# Query ID 170/475
# Support set metrics: Loss = 0.9577, accuracy = 0.4125, precision = 0.3820, recall = 0.3833, F1 score = 0.3753
# Query set metrics: Loss = 1.2074, accuracy = 0.4375, precision = 0.4667, recall = 0.4833, F1 score = 0.4200
# Query ID 171/475
# Support set metrics: Loss = 1.0572, accuracy = 0.3750, precision = 0.3357, recall = 0.3533, F1 score = 0.3401
# Query set metrics: Loss = 1.3284, accuracy = 0.4375, precision = 0.3167, recall = 0.4095, F1 score = 0.3238
# Query ID 172/475
# Support set metrics: Loss = 0.9831, accuracy = 0.4125, precision = 0.4203, recall = 0.3867, F1 score = 0.3961
# Query set metrics: Loss = 0.9383, accuracy = 0.5000, precision = 0.4500, recall = 0.4200, F1 score = 0.4333
# Query ID 173/475
# Support set metrics: Loss = 1.0404, accuracy = 0.3375, precision = 0.3140, recall = 0.3067, F1 score = 0.3069
# Query set metrics: Loss = 1.3278, accuracy = 0.5625, precision = 0.4667, recall = 0.5467, F1 score = 0.4810
# Query ID 174/475
# Support set metrics: Loss = 1.0545, accuracy = 0.3750, precision = 0.3531, recall = 0.3467, F1 score = 0.3464
# Query set metrics: Loss = 0.7914, accuracy = 0.6875, precision = 0.7639, recall = 0.7708, F1 score = 0.6845
# Query ID 175/475
# Support set metrics: Loss = 1.0216, accuracy = 0.3625, precision = 0.3545, recall = 0.3400, F1 score = 0.3428
# Query set metrics: Loss = 1.0714, accuracy = 0.4375, precision = 0.6024, recall = 0.4733, F1 score = 0.4200
# Query ID 176/475
# Support set metrics: Loss = 0.9999, accuracy = 0.4000, precision = 0.4017, recall = 0.3767, F1 score = 0.3852
# Query set metrics: Loss = 0.9761, accuracy = 0.5625, precision = 0.6200, recall = 0.5667, F1 score = 0.5333
# Query ID 177/475
# Support set metrics: Loss = 0.9623, accuracy = 0.3750, precision = 0.3480, recall = 0.3467, F1 score = 0.3417
# Query set metrics: Loss = 0.7395, accuracy = 0.6250, precision = 0.7917, recall = 0.7333, F1 score = 0.6792
# Query ID 178/475
# Support set metrics: Loss = 0.9859, accuracy = 0.3625, precision = 0.3623, recall = 0.3467, F1 score = 0.3471
# Query set metrics: Loss = 1.2803, accuracy = 0.4375, precision = 0.4400, recall = 0.4700, F1 score = 0.4533
# Query ID 179/475
# Support set metrics: Loss = 1.0585, accuracy = 0.3500, precision = 0.3410, recall = 0.3333, F1 score = 0.3344
# Query set metrics: Loss = 0.8289, accuracy = 0.5000, precision = 0.5167, recall = 0.6000, F1 score = 0.4965
# Query ID 180/475
# Support set metrics: Loss = 1.0183, accuracy = 0.4125, precision = 0.4040, recall = 0.3867, F1 score = 0.3919
# Query set metrics: Loss = 0.9373, accuracy = 0.5625, precision = 0.4867, recall = 0.6200, F1 score = 0.5133
# Query ID 181/475
# Support set metrics: Loss = 0.9826, accuracy = 0.3750, precision = 0.3639, recall = 0.3500, F1 score = 0.3521
# Query set metrics: Loss = 1.0826, accuracy = 0.3750, precision = 0.4000, recall = 0.5500, F1 score = 0.3871
# Query ID 182/475
# Support set metrics: Loss = 1.0033, accuracy = 0.4000, precision = 0.3985, recall = 0.3733, F1 score = 0.3814
# Query set metrics: Loss = 0.9512, accuracy = 0.6250, precision = 0.5333, recall = 0.7000, F1 score = 0.5576
# Query ID 183/475
# Support set metrics: Loss = 1.0237, accuracy = 0.3750, precision = 0.3885, recall = 0.3567, F1 score = 0.3697
# Query set metrics: Loss = 0.9135, accuracy = 0.7500, precision = 0.7933, recall = 0.7600, F1 score = 0.7365
# Query ID 184/475
# Support set metrics: Loss = 1.0314, accuracy = 0.4000, precision = 0.3635, recall = 0.3667, F1 score = 0.3575
# Query set metrics: Loss = 0.9057, accuracy = 0.5000, precision = 0.5167, recall = 0.5900, F1 score = 0.4500
# Query ID 185/475
# Support set metrics: Loss = 1.0403, accuracy = 0.3625, precision = 0.3665, recall = 0.3367, F1 score = 0.3496
# Query set metrics: Loss = 1.0476, accuracy = 0.5000, precision = 0.5800, recall = 0.6467, F1 score = 0.5356
# Query ID 186/475
# Support set metrics: Loss = 1.0545, accuracy = 0.3750, precision = 0.3680, recall = 0.3433, F1 score = 0.3501
# Query set metrics: Loss = 0.9022, accuracy = 0.6875, precision = 0.6833, recall = 0.6667, F1 score = 0.6181
# Query ID 187/475
# Support set metrics: Loss = 0.9788, accuracy = 0.4125, precision = 0.3886, recall = 0.3833, F1 score = 0.3778
# Query set metrics: Loss = 0.9287, accuracy = 0.5000, precision = 0.4833, recall = 0.5167, F1 score = 0.4305
# Query ID 188/475
# Support set metrics: Loss = 1.0093, accuracy = 0.3500, precision = 0.3558, recall = 0.3267, F1 score = 0.3344
# Query set metrics: Loss = 1.5193, accuracy = 0.3750, precision = 0.2933, recall = 0.3167, F1 score = 0.2794
# Query ID 189/475
# Support set metrics: Loss = 0.9729, accuracy = 0.4125, precision = 0.4032, recall = 0.3867, F1 score = 0.3916
# Query set metrics: Loss = 0.8840, accuracy = 0.6250, precision = 0.3606, recall = 0.6000, F1 score = 0.4489
# Query ID 190/475
# Support set metrics: Loss = 0.9934, accuracy = 0.3750, precision = 0.3842, recall = 0.3500, F1 score = 0.3640
# Query set metrics: Loss = 0.9814, accuracy = 0.6250, precision = 0.6786, recall = 0.4917, F1 score = 0.5395
# Query ID 191/475
# Support set metrics: Loss = 0.9655, accuracy = 0.4375, precision = 0.4328, recall = 0.4100, F1 score = 0.4141
# Query set metrics: Loss = 1.3586, accuracy = 0.3750, precision = 0.4867, recall = 0.3417, F1 score = 0.3723
# Query ID 192/475
# Support set metrics: Loss = 0.9963, accuracy = 0.4375, precision = 0.4410, recall = 0.4167, F1 score = 0.4240
# Query set metrics: Loss = 0.4784, accuracy = 0.8125, precision = 0.6778, recall = 0.6500, F1 score = 0.6263
# Query ID 193/475
# Support set metrics: Loss = 1.0312, accuracy = 0.3250, precision = 0.3138, recall = 0.2933, F1 score = 0.3012
# Query set metrics: Loss = 1.0854, accuracy = 0.5625, precision = 0.5400, recall = 0.6600, F1 score = 0.5444
# Query ID 194/475
# Support set metrics: Loss = 1.0000, accuracy = 0.3875, precision = 0.3377, recall = 0.3633, F1 score = 0.3454
# Query set metrics: Loss = 0.9810, accuracy = 0.6250, precision = 0.8133, recall = 0.6167, F1 score = 0.6333
# Query ID 195/475
# Support set metrics: Loss = 1.0185, accuracy = 0.3875, precision = 0.3689, recall = 0.3633, F1 score = 0.3634
# Query set metrics: Loss = 0.8947, accuracy = 0.6250, precision = 0.5200, recall = 0.6667, F1 score = 0.5433
# Query ID 196/475
# Support set metrics: Loss = 1.0072, accuracy = 0.3750, precision = 0.3712, recall = 0.3500, F1 score = 0.3574
# Query set metrics: Loss = 1.0757, accuracy = 0.6875, precision = 0.8000, recall = 0.7250, F1 score = 0.6970
# Query ID 197/475
# Support set metrics: Loss = 0.9604, accuracy = 0.4125, precision = 0.4152, recall = 0.3933, F1 score = 0.3998
# Query set metrics: Loss = 1.0043, accuracy = 0.6250, precision = 0.6000, recall = 0.6600, F1 score = 0.5788
# Query ID 198/475
# Support set metrics: Loss = 1.0035, accuracy = 0.3875, precision = 0.3633, recall = 0.3600, F1 score = 0.3586
# Query set metrics: Loss = 0.7407, accuracy = 0.6250, precision = 0.5333, recall = 0.5367, F1 score = 0.5310
# Query ID 199/475
# Support set metrics: Loss = 1.0940, accuracy = 0.3125, precision = 0.2750, recall = 0.2867, F1 score = 0.2802
# Query set metrics: Loss = 0.7932, accuracy = 0.7500, precision = 0.8600, recall = 0.7767, F1 score = 0.8057
# Query ID 200/475
# Support set metrics: Loss = 1.0021, accuracy = 0.4125, precision = 0.4138, recall = 0.3900, F1 score = 0.3965
# Query set metrics: Loss = 1.0957, accuracy = 0.5000, precision = 0.4667, recall = 0.4800, F1 score = 0.4267
# Query ID 201/475
# Support set metrics: Loss = 0.9822, accuracy = 0.4000, precision = 0.3837, recall = 0.3700, F1 score = 0.3740
# Query set metrics: Loss = 0.9970, accuracy = 0.4375, precision = 0.4667, recall = 0.5133, F1 score = 0.4286
# Query ID 202/475
# Support set metrics: Loss = 1.1060, accuracy = 0.3250, precision = 0.3214, recall = 0.2967, F1 score = 0.3077
# Query set metrics: Loss = 1.4192, accuracy = 0.5625, precision = 0.4095, recall = 0.5667, F1 score = 0.4538
# Query ID 203/475
# Support set metrics: Loss = 1.0770, accuracy = 0.3500, precision = 0.3207, recall = 0.3133, F1 score = 0.3126
# Query set metrics: Loss = 0.8673, accuracy = 0.6875, precision = 0.4457, recall = 0.5143, F1 score = 0.4432
# Query ID 204/475
# ...
# Query set metrics: Loss = 0.8242, accuracy = 0.6875, precision = 0.8400, recall = 0.7800, F1 score = 0.7476
# Query ID 409/475
# Support set metrics: Loss = 1.2332, accuracy = 0.5125, precision = 0.5148, recall = 0.4900, F1 score = 0.4896
# Query set metrics: Loss = 0.9414, accuracy = 0.6875, precision = 0.7375, recall = 0.8750, F1 score = 0.7798
# Query ID 410/475
# Support set metrics: Loss = 1.2881, accuracy = 0.5125, precision = 0.5214, recall = 0.4700, F1 score = 0.4877
# Query set metrics: Loss = 0.5847, accuracy = 0.8125, precision = 0.8704, recall = 0.8981, F1 score = 0.8360
# Query ID 411/475
# Support set metrics: Loss = 1.1119, accuracy = 0.5500, precision = 0.5546, recall = 0.5000, F1 score = 0.5087
# Query set metrics: Loss = 0.8827, accuracy = 0.8750, precision = 0.9524, recall = 0.8929, F1 score = 0.9034
# Query ID 412/475
# Support set metrics: Loss = 1.2816, accuracy = 0.4500, precision = 0.4215, recall = 0.3900, F1 score = 0.4000
# Query set metrics: Loss = 0.9251, accuracy = 0.6875, precision = 0.5667, recall = 0.6531, F1 score = 0.5905
# Query ID 413/475
# Support set metrics: Loss = 1.0596, accuracy = 0.5875, precision = 0.6064, recall = 0.5700, F1 score = 0.5565
# Query set metrics: Loss = 0.6683, accuracy = 0.6875, precision = 0.6667, recall = 0.7222, F1 score = 0.6852
# Query ID 414/475
# Support set metrics: Loss = 1.1977, accuracy = 0.4750, precision = 0.4367, recall = 0.4300, F1 score = 0.4253
# Query set metrics: Loss = 0.3962, accuracy = 0.8125, precision = 0.7292, recall = 0.7500, F1 score = 0.7375
# Query ID 415/475
# Support set metrics: Loss = 1.2322, accuracy = 0.5000, precision = 0.5002, recall = 0.4700, F1 score = 0.4709
# Query set metrics: Loss = 0.1887, accuracy = 0.9375, precision = 0.9630, recall = 0.9444, F1 score = 0.9407
# Query ID 416/475
# Support set metrics: Loss = 1.2237, accuracy = 0.4250, precision = 0.4492, recall = 0.3800, F1 score = 0.3944
# Query set metrics: Loss = 0.9653, accuracy = 0.6875, precision = 0.7143, recall = 0.7857, F1 score = 0.7190
# Query ID 417/475
# Support set metrics: Loss = 1.1482, accuracy = 0.5500, precision = 0.5362, recall = 0.5200, F1 score = 0.5205
# Query set metrics: Loss = 0.7456, accuracy = 0.6875, precision = 0.6833, recall = 0.7000, F1 score = 0.6705
# Query ID 418/475
# Support set metrics: Loss = 1.2905, accuracy = 0.4500, precision = 0.4921, recall = 0.4300, F1 score = 0.4356
# Query set metrics: Loss = 0.8725, accuracy = 0.7500, precision = 0.6875, recall = 0.8125, F1 score = 0.7292
# Query ID 419/475
# Support set metrics: Loss = 1.2330, accuracy = 0.5375, precision = 0.5868, recall = 0.5100, F1 score = 0.5248
# Query set metrics: Loss = 1.1944, accuracy = 0.5625, precision = 0.6806, recall = 0.6250, F1 score = 0.5873
# Query ID 420/475
# Support set metrics: Loss = 1.1920, accuracy = 0.4500, precision = 0.4192, recall = 0.4200, F1 score = 0.4072
# Query set metrics: Loss = 0.9904, accuracy = 0.6875, precision = 0.4630, recall = 0.6111, F1 score = 0.5111
# Query ID 421/475
# Support set metrics: Loss = 1.2072, accuracy = 0.4375, precision = 0.4402, recall = 0.4000, F1 score = 0.4103
# Query set metrics: Loss = 0.9225, accuracy = 0.6875, precision = 0.8292, recall = 0.7250, F1 score = 0.7333
# Query ID 422/475
# Support set metrics: Loss = 1.1990, accuracy = 0.4500, precision = 0.4709, recall = 0.4400, F1 score = 0.4399
# Query set metrics: Loss = 1.3663, accuracy = 0.5625, precision = 0.5625, recall = 0.5729, F1 score = 0.5530
# Query ID 423/475
# Support set metrics: Loss = 1.0946, accuracy = 0.5375, precision = 0.4792, recall = 0.5100, F1 score = 0.4820
# Query set metrics: Loss = 0.5344, accuracy = 0.8125, precision = 0.7500, recall = 0.7708, F1 score = 0.7417
# Query ID 424/475
# Support set metrics: Loss = 1.2306, accuracy = 0.4375, precision = 0.4875, recall = 0.4500, F1 score = 0.4498
# Query set metrics: Loss = 1.1490, accuracy = 0.6875, precision = 0.5000, recall = 0.5556, F1 score = 0.5074
# Query ID 425/475
# Support set metrics: Loss = 1.2404, accuracy = 0.4500, precision = 0.4606, recall = 0.4100, F1 score = 0.4096
# Query set metrics: Loss = 0.4885, accuracy = 0.8750, precision = 0.9167, recall = 0.9062, F1 score = 0.8905
# Query ID 426/475
# Support set metrics: Loss = 1.3103, accuracy = 0.5250, precision = 0.5239, recall = 0.4900, F1 score = 0.4955
# Query set metrics: Loss = 0.9035, accuracy = 0.6875, precision = 0.7708, recall = 0.8313, F1 score = 0.7202
# Query ID 427/475
# Support set metrics: Loss = 1.1138, accuracy = 0.5250, precision = 0.4774, recall = 0.4800, F1 score = 0.4685
# Query set metrics: Loss = 0.9063, accuracy = 0.7500, precision = 0.8438, recall = 0.8438, F1 score = 0.7821
# Query ID 428/475
# Support set metrics: Loss = 1.3199, accuracy = 0.4875, precision = 0.5402, recall = 0.4600, F1 score = 0.4565
# Query set metrics: Loss = 0.4118, accuracy = 0.8750, precision = 0.9375, recall = 0.9271, F1 score = 0.9155
# Query ID 429/475
# Support set metrics: Loss = 1.1189, accuracy = 0.5125, precision = 0.4967, recall = 0.5000, F1 score = 0.4893
# Query set metrics: Loss = 0.7576, accuracy = 0.7500, precision = 0.7381, recall = 0.6905, F1 score = 0.6857
# Query ID 430/475
# Support set metrics: Loss = 1.0952, accuracy = 0.5875, precision = 0.5341, recall = 0.5400, F1 score = 0.5274
# Query set metrics: Loss = 0.7731, accuracy = 0.7500, precision = 0.8714, recall = 0.8214, F1 score = 0.8381
# Query ID 431/475
# Support set metrics: Loss = 1.1952, accuracy = 0.4750, precision = 0.5265, recall = 0.4600, F1 score = 0.4665
# Query set metrics: Loss = 1.2099, accuracy = 0.6250, precision = 0.7500, recall = 0.6083, F1 score = 0.6270
# Query ID 432/475
# Support set metrics: Loss = 1.2100, accuracy = 0.4500, precision = 0.4197, recall = 0.4300, F1 score = 0.4105
# Query set metrics: Loss = 1.0268, accuracy = 0.6875, precision = 0.6667, recall = 0.6381, F1 score = 0.6468
# Query ID 433/475
# Support set metrics: Loss = 1.1797, accuracy = 0.4750, precision = 0.4671, recall = 0.4500, F1 score = 0.4371
# Query set metrics: Loss = 1.5209, accuracy = 0.5000, precision = 0.6042, recall = 0.5625, F1 score = 0.5774
# Query ID 434/475
# Support set metrics: Loss = 1.2347, accuracy = 0.5125, precision = 0.5173, recall = 0.4800, F1 score = 0.4878
# Query set metrics: Loss = 0.7983, accuracy = 0.7500, precision = 0.6354, recall = 0.6875, F1 score = 0.6280
# Query ID 435/475
# Support set metrics: Loss = 1.1869, accuracy = 0.5375, precision = 0.5425, recall = 0.5100, F1 score = 0.5131
# Query set metrics: Loss = 0.7631, accuracy = 0.8750, precision = 0.9583, recall = 0.8750, F1 score = 0.8917
# Query ID 436/475
# Support set metrics: Loss = 1.1421, accuracy = 0.5125, precision = 0.5600, recall = 0.5200, F1 score = 0.5225
# Query set metrics: Loss = 0.5927, accuracy = 0.8125, precision = 0.6481, recall = 0.7222, F1 score = 0.6778
# Query ID 437/475
# Support set metrics: Loss = 1.2319, accuracy = 0.5125, precision = 0.4906, recall = 0.4800, F1 score = 0.4813
# Query set metrics: Loss = 0.7423, accuracy = 0.8125, precision = 0.8125, recall = 0.7500, F1 score = 0.7500
# Query ID 438/475
# Support set metrics: Loss = 1.1670, accuracy = 0.5000, precision = 0.5255, recall = 0.5000, F1 score = 0.4953
# Query set metrics: Loss = 1.2339, accuracy = 0.6250, precision = 0.7375, recall = 0.7292, F1 score = 0.6756
# Query ID 439/475
# Support set metrics: Loss = 1.2081, accuracy = 0.4875, precision = 0.5529, recall = 0.4600, F1 score = 0.4686
# Query set metrics: Loss = 0.6628, accuracy = 0.7500, precision = 0.8095, recall = 0.6905, F1 score = 0.7095
# Query ID 440/475
# Support set metrics: Loss = 1.1798, accuracy = 0.5000, precision = 0.4631, recall = 0.4600, F1 score = 0.4504
# Query set metrics: Loss = 0.4936, accuracy = 0.8125, precision = 0.7917, recall = 0.8021, F1 score = 0.7696
# Query ID 441/475
# Support set metrics: Loss = 1.1379, accuracy = 0.4500, precision = 0.4766, recall = 0.4400, F1 score = 0.4450
# Query set metrics: Loss = 1.0847, accuracy = 0.8125, precision = 0.6786, recall = 0.6786, F1 score = 0.6735
# Query ID 442/475
# Support set metrics: Loss = 1.1790, accuracy = 0.5125, precision = 0.4924, recall = 0.4600, F1 score = 0.4675
# Query set metrics: Loss = 1.1091, accuracy = 0.6875, precision = 0.7143, recall = 0.6190, F1 score = 0.6429
# Query ID 443/475
# Support set metrics: Loss = 1.0993, accuracy = 0.5625, precision = 0.5496, recall = 0.5500, F1 score = 0.5434
# Query set metrics: Loss = 0.5596, accuracy = 0.7500, precision = 0.7708, recall = 0.7292, F1 score = 0.7333
# Query ID 444/475
# Support set metrics: Loss = 1.2272, accuracy = 0.4500, precision = 0.4203, recall = 0.4000, F1 score = 0.4007
# Query set metrics: Loss = 0.9836, accuracy = 0.7500, precision = 0.7500, recall = 0.7870, F1 score = 0.7315
# Query ID 445/475
# Support set metrics: Loss = 1.2795, accuracy = 0.5000, precision = 0.5017, recall = 0.4500, F1 score = 0.4522
# Query set metrics: Loss = 1.3377, accuracy = 0.6250, precision = 0.6037, recall = 0.6667, F1 score = 0.6019
# Query ID 446/475
# Support set metrics: Loss = 1.1968, accuracy = 0.5125, precision = 0.5337, recall = 0.5000, F1 score = 0.5059
# Query set metrics: Loss = 0.9715, accuracy = 0.6250, precision = 0.7037, recall = 0.6296, F1 score = 0.6444
# Query ID 447/475
# Support set metrics: Loss = 1.2070, accuracy = 0.4750, precision = 0.4873, recall = 0.4600, F1 score = 0.4618
# Query set metrics: Loss = 0.8123, accuracy = 0.7500, precision = 0.7083, recall = 0.7292, F1 score = 0.7042
# Query ID 448/475
# Support set metrics: Loss = 1.2278, accuracy = 0.4750, precision = 0.4578, recall = 0.4300, F1 score = 0.4411
# Query set metrics: Loss = 0.9943, accuracy = 0.6875, precision = 0.7292, recall = 0.6667, F1 score = 0.6845
# Query ID 449/475
# Support set metrics: Loss = 1.2027, accuracy = 0.4875, precision = 0.5146, recall = 0.4700, F1 score = 0.4830
# Query set metrics: Loss = 1.2365, accuracy = 0.6875, precision = 0.7188, recall = 0.6875, F1 score = 0.6625
# Query ID 450/475
# Support set metrics: Loss = 1.3072, accuracy = 0.4500, precision = 0.3980, recall = 0.4000, F1 score = 0.3889
# Query set metrics: Loss = 1.2873, accuracy = 0.5625, precision = 0.5833, recall = 0.7000, F1 score = 0.6167
# Query ID 451/475
# Support set metrics: Loss = 1.0832, accuracy = 0.5625, precision = 0.5779, recall = 0.5400, F1 score = 0.5386
# Query set metrics: Loss = 0.8832, accuracy = 0.6250, precision = 0.4762, recall = 0.5714, F1 score = 0.5000
# Query ID 452/475
# Support set metrics: Loss = 1.2465, accuracy = 0.4875, precision = 0.4841, recall = 0.4600, F1 score = 0.4645
# Query set metrics: Loss = 0.5279, accuracy = 0.8125, precision = 0.9286, recall = 0.8333, F1 score = 0.8476
# Query ID 453/475
# Support set metrics: Loss = 1.1986, accuracy = 0.4875, precision = 0.5138, recall = 0.4700, F1 score = 0.4718
# Query set metrics: Loss = 0.7968, accuracy = 0.6875, precision = 0.7250, recall = 0.7083, F1 score = 0.6903
# Query ID 454/475
# Support set metrics: Loss = 1.1375, accuracy = 0.5125, precision = 0.5919, recall = 0.5100, F1 score = 0.4935
# Query set metrics: Loss = 0.7141, accuracy = 0.8125, precision = 0.7000, recall = 0.8000, F1 score = 0.7333
# Query ID 455/475
# Support set metrics: Loss = 1.1063, accuracy = 0.5500, precision = 0.5020, recall = 0.5300, F1 score = 0.5003
# Query set metrics: Loss = 0.5530, accuracy = 0.8750, precision = 0.8611, recall = 0.8519, F1 score = 0.8508
# Query ID 456/475
# Support set metrics: Loss = 1.1684, accuracy = 0.4875, precision = 0.4840, recall = 0.4600, F1 score = 0.4589
# Query set metrics: Loss = 1.4371, accuracy = 0.6875, precision = 0.7222, recall = 0.8222, F1 score = 0.7265
# Query ID 457/475
# Support set metrics: Loss = 1.2977, accuracy = 0.4750, precision = 0.5097, recall = 0.4400, F1 score = 0.4598
# Query set metrics: Loss = 1.7643, accuracy = 0.3750, precision = 0.2667, recall = 0.4074, F1 score = 0.3122
# Query ID 458/475
# Support set metrics: Loss = 1.1008, accuracy = 0.5875, precision = 0.5603, recall = 0.5700, F1 score = 0.5536
# Query set metrics: Loss = 0.4514, accuracy = 0.8125, precision = 0.7292, recall = 0.8438, F1 score = 0.7655
# Query ID 459/475
# Support set metrics: Loss = 0.9787, accuracy = 0.5875, precision = 0.5451, recall = 0.5600, F1 score = 0.5426
# Query set metrics: Loss = 0.7369, accuracy = 0.8125, precision = 0.6667, recall = 0.7778, F1 score = 0.7111
# Query ID 460/475
# Support set metrics: Loss = 1.3191, accuracy = 0.5250, precision = 0.4687, recall = 0.4800, F1 score = 0.4681
# Query set metrics: Loss = 0.7925, accuracy = 0.8125, precision = 0.6481, recall = 0.7778, F1 score = 0.6852
# Query ID 461/475
# Support set metrics: Loss = 1.2066, accuracy = 0.4750, precision = 0.4761, recall = 0.4600, F1 score = 0.4568
# Query set metrics: Loss = 0.6176, accuracy = 0.7500, precision = 0.6667, recall = 0.7500, F1 score = 0.6667
# Query ID 462/475
# Support set metrics: Loss = 1.2364, accuracy = 0.4750, precision = 0.4762, recall = 0.4500, F1 score = 0.4496
# Query set metrics: Loss = 0.4810, accuracy = 0.8125, precision = 0.7685, recall = 0.8333, F1 score = 0.7952
# Query ID 463/475
# Support set metrics: Loss = 1.2695, accuracy = 0.5125, precision = 0.5132, recall = 0.4800, F1 score = 0.4876
# Query set metrics: Loss = 0.5563, accuracy = 0.8125, precision = 0.9167, recall = 0.8542, F1 score = 0.8625
# Query ID 464/475
# Support set metrics: Loss = 1.0486, accuracy = 0.5750, precision = 0.5667, recall = 0.5600, F1 score = 0.5461
# Query set metrics: Loss = 0.6082, accuracy = 0.8750, precision = 0.7222, recall = 0.7778, F1 score = 0.7407
# Query ID 465/475
# Support set metrics: Loss = 1.1782, accuracy = 0.4750, precision = 0.5062, recall = 0.4700, F1 score = 0.4703
# Query set metrics: Loss = 0.2678, accuracy = 0.8750, precision = 0.9062, recall = 0.8750, F1 score = 0.8571
# Query ID 466/475
# Support set metrics: Loss = 1.1075, accuracy = 0.5625, precision = 0.4853, recall = 0.5100, F1 score = 0.4900
# Query set metrics: Loss = 0.8456, accuracy = 0.8125, precision = 0.7963, recall = 0.7778, F1 score = 0.7556
# Query ID 467/475
# Support set metrics: Loss = 1.1863, accuracy = 0.5250, precision = 0.5629, recall = 0.5300, F1 score = 0.5192
# Query set metrics: Loss = 0.9765, accuracy = 0.7500, precision = 0.7333, recall = 0.7667, F1 score = 0.7300
# Query ID 468/475
# Support set metrics: Loss = 1.0941, accuracy = 0.5250, precision = 0.5766, recall = 0.4900, F1 score = 0.4988
# Query set metrics: Loss = 1.0361, accuracy = 0.7500, precision = 0.8958, recall = 0.7708, F1 score = 0.8042
# Query ID 469/475
# Support set metrics: Loss = 1.0736, accuracy = 0.6000, precision = 0.6101, recall = 0.5800, F1 score = 0.5731
# Query set metrics: Loss = 1.2193, accuracy = 0.6250, precision = 0.5583, recall = 0.6944, F1 score = 0.5956
# Query ID 470/475
# Support set metrics: Loss = 1.2763, accuracy = 0.4375, precision = 0.4042, recall = 0.4200, F1 score = 0.4006
# Query set metrics: Loss = 1.1170, accuracy = 0.6875, precision = 0.7188, recall = 0.6250, F1 score = 0.6488
# Query ID 471/475
# Support set metrics: Loss = 1.2607, accuracy = 0.5125, precision = 0.4623, recall = 0.4700, F1 score = 0.4542
# Query set metrics: Loss = 1.2188, accuracy = 0.6875, precision = 0.5093, recall = 0.5926, F1 score = 0.5323
# Query ID 472/475
# Support set metrics: Loss = 1.1088, accuracy = 0.5125, precision = 0.5153, recall = 0.4800, F1 score = 0.4856
# Query set metrics: Loss = 0.8597, accuracy = 0.7500, precision = 0.7262, recall = 0.7619, F1 score = 0.6939
# Query ID 473/475
# Support set metrics: Loss = 1.2309, accuracy = 0.4750, precision = 0.4494, recall = 0.4600, F1 score = 0.4447
# Query set metrics: Loss = 1.3635, accuracy = 0.5000, precision = 0.6429, recall = 0.5476, F1 score = 0.5531
# Query ID 474/475
# Support set metrics: Loss = 1.2848, accuracy = 0.5000, precision = 0.5136, recall = 0.4600, F1 score = 0.4760
# Query set metrics: Loss = 0.9441, accuracy = 0.8125, precision = 0.8095, recall = 0.7381, F1 score = 0.7524
# Test metrics: Loss = 0.9302, accuracy = 0.7239, precision = 0.7336, recall = 0.7241, F1 score = 0.7204
#
# COPY PASTA - not really but ok
# 0.5906578947368422
# 0.9152631578947369
# 0.9881578947368421
# 0.5371052631578948
# 0.7239473684210527
#
# Overall test metrics: Accuracy = 0.7510, precision = 0.7596, recall = 0.7517, F1 score = 0.7447
# Total Time used: 45.0 minutes

# %%
_model_path0 = os.path.splitext(model_path)[0]
csv_filename = _model_path0 + "_update"+ str(updates) +"_results_sr_ta_ss4.csv" # for selective replay
with open(csv_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["data_idx", "label", "label_conf", "pred"])
    csv_writer.writerows(data_for_visual)
print(f"Done writing CSV File at {csv_filename}")
# Out:
# Done writing CSV File at /data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228_update5_results_sr_ta_ss4.csv

# %%
# Log Time for Inference
_model_path0 = os.path.splitext(model_path)[0]
time_txt_filename = _model_path0 + "_update"+ str(updates) +"_time_inference_sr_ta_ss4.csv" 
with open(time_txt_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["time_id", "time"])
    csv_writer.writerow(["Total Time", f"{toc//60} minutes"])
    csv_writer.writerow(["mean Adapt Time", f"{np.mean(all_adapt_time)} s"])
print(f"Done writing Time CSV File at {time_txt_filename}")
# Out:
# Done writing Time CSV File at /data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228_update5_time_inference_sr_ta_ss4.csv
