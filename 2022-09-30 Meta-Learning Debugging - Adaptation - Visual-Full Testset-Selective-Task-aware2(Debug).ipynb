# %%
import random, gc, os, pickle, csv, time

import datasets.utils
import models.utils
from models.cls_oml_ori_v2 import OML
from models.base_models_ori import LabelAwareReplayMemory

import numpy as np

import higher
import torch
import torch.nn.functional as F
from torch.utils import data

# %% [markdown]
# # Constants

# %%
dataset_order_mapping = {
    1: [2, 0, 3, 1, 4],
    2: [3, 4, 0, 1, 2],
    3: [2, 4, 1, 3, 0],
    4: [0, 2, 1, 4, 3]
}
n_classes = 33
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
# model_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518612.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456804.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477968.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869765.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241546.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424113.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167637.pt"

# v. SR 
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695669.pt"
# v. SR Query
model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228.pt"

# memory_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518639_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456828_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477992_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869797_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241572_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424139_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167666_memory.pickle"
# v. SR 
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695692_memory.pickle"
# v. SR Query
memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854254_memory.pickle"


# new_memory_path, ext = os.path.splitext(memory_path)
# new_memory_path = new_memory_path + "_label" + ext

use_db_cache = True
cache_dir = 'tmp'

# %%
args = {
    "order": 1,
    "n_epochs": 1,
    "lr": 3e-5,
    "inner_lr": 0.001*10,
    "meta_lr": 3e-5,
    "model": "bert",
    "learner": "oml",
    "mini_batch_size": 16,
    "updates": 5*1,
    "write_prob": 1.0,
    "max_length": 448,
    "seed": 42,
    "replay_rate": 0.01,
    "replay_every": 9600
}
updates = args["updates"]
mini_batch_size = args["mini_batch_size"]
order = args["order"]

# %%
torch.manual_seed(args["seed"])
random.seed(args["seed"])
np.random.seed(args["seed"])

# %% [markdown]
# # Load Dataset

# %%
print('Loading the datasets')
test_datasets = []
for dataset_id in dataset_order_mapping[order]:
    test_dataset_file = os.path.join(cache_dir, f"{dataset_id}.cache")
    if os.path.exists(test_dataset_file):
        with open(test_dataset_file, 'rb') as f:
            test_dataset = pickle.load(f)
    else:
        test_dataset = datasets.utils.get_dataset_test("", dataset_id)
        print('Loaded {}'.format(test_dataset.__class__.__name__))
        test_dataset = datasets.utils.offset_labels(test_dataset)
        pickle.dump(test_dataset, open( test_dataset_file, "wb" ), protocol=pickle.HIGHEST_PROTOCOL)
        print(f"Pickle saved at {test_dataset_file}")
    test_datasets.append(test_dataset)
print('Finished loading all the datasets')
# Out:
# Loading the datasets
# Finished loading all the datasets

# %% [markdown]
# # Load Model

# %%
learner = OML(device=device, n_classes=n_classes, **args)
print('Using {} as learner'.format(learner.__class__.__name__))
learner.load_model(model_path)
with open(memory_path, 'rb') as f:
#     learner.memory = pickle.load(f)
    memory_buffer = pickle.load(f)
# Out:
# 2022-09-10 09:10:02,186 - transformers.tokenization_utils_base - INFO - loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2022-09-10 09:10:03,347 - transformers.configuration_utils - INFO - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2022-09-10 09:10:03,351 - transformers.configuration_utils - INFO - Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2022-09-10 09:10:03,405 - transformers.modeling_utils - INFO - loading weights file https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2022-09-10 09:10:06,077 - transformers.modeling_utils - INFO - All model checkpoint weights were used when initializing BertModel.
#
# 2022-09-10 09:10:06,081 - transformers.modeling_utils - INFO - All the weights of BertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use BertModel for predictions without further training.
# 2022-09-10 09:10:10,289 - OML-Log - INFO - Loaded TransformerRLN as RLN
# 2022-09-10 09:10:10,292 - OML-Log - INFO - Loaded LinearPLN as PLN
# Using OML as learner

# %%
# Setting up task dict for task-aware
memory_buffer.task_dict = {
    0: list(range(5, 9)), # AG
    1: list(range(0, 5)), # Amazon
    2: list(range(0, 5)), # Yelp
    3: list(range(9, 23)), # DBPedia
    4: list(range(23, 33)), # Yahoo
}

# %%
# label to task converter - hack, since normally we would just use the task token/identifier
def get_task_from_label(label_idx, task_dict):
    for task_idx, class_list in task_dict.items():
        if label_idx in class_list: return task_idx
    return -1
print(get_task_from_label(8, memory_buffer.task_dict))
# Find mode: https://stackoverflow.com/questions/10797819/finding-the-mode-of-a-list
def mode(array):
    return max(array, key = array.count)
# label list to task id
def get_task_from_label_list(label_list, task_dict):
    return mode([get_task_from_label(label, task_dict) for label in label_list])
print(get_task_from_label_list([1,2,32,1,4,2,0], memory_buffer.task_dict))
# Out:
# 0
# 1

# %%
dataclass_mapper = {
    "AGNewsDataset": 0,
    "AmazonDataset": 1,
    "YelpDataset": 2,
    "DBPediaDataset": 3,
    "YahooAnswersDataset": 4
}
dataclass_mapper["AGNewsDataset"]
# Out:
# 0

# %% [markdown]
# # Testing
#
# Select specific column index per row
# https://stackoverflow.com/questions/23435782/numpy-selecting-specific-column-index-per-row-by-using-a-list-of-indexes

# %%
def evaluate(dataloader, updates, mini_batch_size, dataname=""):
    learner.rln.eval()
    learner.pln.train()
    
    all_losses, all_predictions, all_labels, all_label_conf = [], [], [], []
    all_adaptation_time = []
    # Get Query set first. and then find supporting support set
    for query_idx, (query_text, query_labels) in enumerate(dataloader):
        print(f"Query ID {query_idx}/{len(dataloader)}")
        # The task id to optimize to for support set
        # task_idx = get_task_from_label_list(query_labels, memory_buffer.task_dict)
        task_idx = dataclass_mapper[dataname]
        
    
        support_set = []
        for _ in range(updates):
            text, labels = memory_buffer.read_batch_task(batch_size=mini_batch_size, task_idx=task_idx)
            support_set.append((text, labels))

        with higher.innerloop_ctx(learner.pln, learner.inner_optimizer,
                                  copy_initial_weights=False, track_higher_grads=False) as (fpln, diffopt):
            
            INNER_tic = time.time()
            # Inner loop
            task_predictions, task_labels = [], []
            support_loss = []
            for text, labels in support_set:
                labels = torch.tensor(labels).to(device)
                input_dict = learner.rln.encode_text(text)
                _repr = learner.rln(input_dict)
                output = fpln(_repr)
                loss = learner.loss_fn(output, labels)
                diffopt.step(loss)
                pred = models.utils.make_prediction(output.detach())
                support_loss.append(loss.item())
                task_predictions.extend(pred.tolist())
                task_labels.extend(labels.tolist())
            INNER_toc = time.time() - INNER_tic
            all_adaptation_time.append(INNER_toc)

            acc, prec, rec, f1 = models.utils.calculate_metrics(task_predictions, task_labels)

            print('Support set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                        'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(support_loss), acc, prec, rec, f1))

            # Query set is now here!
            query_labels = torch.tensor(query_labels).to(device)
            query_input_dict = learner.rln.encode_text(query_text)
            with torch.no_grad():
                query_repr = learner.rln(query_input_dict)
                query_output = fpln(query_repr) # Output has size of torch.Size([16, 33]) [BATCH, CLASSES]
                query_loss = learner.loss_fn(query_output, query_labels)
            query_loss = query_loss.item()
            # print(output.detach().size())
            # output.detach().max(-1) max on each Batch, which will return [0] max, [1] indices
            query_output_softmax = F.softmax(query_output, -1)
            query_label_conf = query_output_softmax[np.arange(len(query_output_softmax)), query_labels] # Select labels in the softmax of 33 classes

            query_pred = models.utils.make_prediction(query_output.detach())
            query_acc, query_prec, query_rec, query_f1 = models.utils.calculate_metrics(query_pred.tolist(), query_labels.tolist())
            
            print('Query set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(query_loss), query_acc, query_prec, query_rec, query_f1))

            all_losses.append(query_loss)
            all_predictions.extend(query_pred.tolist())
            all_labels.extend(query_labels.tolist())
            all_label_conf.extend(query_label_conf.tolist())

    acc, prec, rec, f1 = models.utils.calculate_metrics(all_predictions, all_labels)
    print('Test metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
                'F1 score = {:.4f}'.format(np.mean(all_losses), acc, prec, rec, f1))
    return acc, prec, rec, f1, all_predictions, all_labels, all_label_conf, all_adaptation_time

# %%
tic = time.time()
print('----------Testing on test set starts here----------')

accuracies, precisions, recalls, f1s = [], [], [], []
all_adapt_time = []
# Data for Visualization: [data_idx, label, label_conf, pred]
data_for_visual = []

for test_dataset in test_datasets:
    print('Testing on {}'.format(test_dataset.__class__.__name__))
    test_dataloader = data.DataLoader(test_dataset, batch_size=mini_batch_size, shuffle=False,
                                      collate_fn=datasets.utils.batch_encode)
    acc, prec, rec, f1, all_pred, all_label, all_label_conf, all_adaptation_time = evaluate(dataloader=test_dataloader, updates=updates, 
                                                mini_batch_size=mini_batch_size, dataname=test_dataset.__class__.__name__)
    
    data_ids = [test_dataset.__class__.__name__ + str(i) for i in range(len(all_label))]
    data_for_visual.extend(list(zip(data_ids, all_label, all_label_conf, all_pred)))
    all_adapt_time.extend(all_adaptation_time)
#     print(data_ids)
#     print(all_label)
#     raise Exception("BREAKPOINT")
    
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1s.append(f1)


print()
print("COPY PASTA - not really but ok")
for row in accuracies:
    print(row)
print()
print('Overall test metrics: Accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
            'F1 score = {:.4f}'.format(np.mean(accuracies), np.mean(precisions), np.mean(recalls), np.mean(f1s)))

toc = time.time() - tic
print(f"Total Time used: {toc//60} minutes")
# Out:
# ----------Testing on test set starts here----------
# Testing on YelpDataset
# Query ID 0/475
# Support set metrics: Loss = 1.0140, accuracy = 0.6250, precision = 0.6529, recall = 0.6233, F1 score = 0.6345
# Query set metrics: Loss = 0.6118, accuracy = 0.6875, precision = 0.7800, recall = 0.6933, F1 score = 0.6900
# Query ID 1/475
# Support set metrics: Loss = 1.0684, accuracy = 0.5250, precision = 0.5283, recall = 0.5233, F1 score = 0.5191
# Query set metrics: Loss = 0.6789, accuracy = 0.7500, precision = 0.7267, recall = 0.7933, F1 score = 0.7200
# Query ID 2/475
# Support set metrics: Loss = 0.8462, accuracy = 0.6125, precision = 0.6007, recall = 0.6000, F1 score = 0.5938
# Query set metrics: Loss = 0.9035, accuracy = 0.4375, precision = 0.4733, recall = 0.4667, F1 score = 0.4538
# Query ID 3/475
# Support set metrics: Loss = 0.8568, accuracy = 0.6125, precision = 0.6152, recall = 0.6033, F1 score = 0.6053
# Query set metrics: Loss = 0.8478, accuracy = 0.6250, precision = 0.6033, recall = 0.6000, F1 score = 0.5967
# Query ID 4/475
# Support set metrics: Loss = 0.8467, accuracy = 0.6250, precision = 0.6249, recall = 0.6133, F1 score = 0.6180
# Query set metrics: Loss = 0.9548, accuracy = 0.6875, precision = 0.7400, recall = 0.6600, F1 score = 0.6733
# Query ID 5/475
# Support set metrics: Loss = 1.0089, accuracy = 0.5875, precision = 0.5983, recall = 0.5733, F1 score = 0.5851
# Query set metrics: Loss = 1.0105, accuracy = 0.6875, precision = 0.6667, recall = 0.6867, F1 score = 0.6648
# Query ID 6/475
# Support set metrics: Loss = 0.9121, accuracy = 0.6000, precision = 0.5748, recall = 0.5833, F1 score = 0.5750
# Query set metrics: Loss = 1.0188, accuracy = 0.6875, precision = 0.6400, recall = 0.6333, F1 score = 0.6111
# Query ID 7/475
# Support set metrics: Loss = 0.7786, accuracy = 0.6625, precision = 0.6581, recall = 0.6467, F1 score = 0.6494
# Query set metrics: Loss = 1.0472, accuracy = 0.6250, precision = 0.7667, recall = 0.7000, F1 score = 0.6943
# Query ID 8/475
# Support set metrics: Loss = 1.0598, accuracy = 0.5750, precision = 0.5777, recall = 0.5667, F1 score = 0.5688
# Query set metrics: Loss = 1.1900, accuracy = 0.5000, precision = 0.5667, recall = 0.6233, F1 score = 0.5400
# Query ID 9/475
# Support set metrics: Loss = 0.9913, accuracy = 0.5750, precision = 0.5823, recall = 0.5633, F1 score = 0.5701
# Query set metrics: Loss = 1.1754, accuracy = 0.4375, precision = 0.6238, recall = 0.6583, F1 score = 0.4810
# Query ID 10/475
# Support set metrics: Loss = 0.8149, accuracy = 0.6375, precision = 0.6407, recall = 0.6333, F1 score = 0.6345
# Query set metrics: Loss = 1.3427, accuracy = 0.5000, precision = 0.4133, recall = 0.5190, F1 score = 0.4358
# Query ID 11/475
# Support set metrics: Loss = 1.0686, accuracy = 0.5875, precision = 0.6133, recall = 0.5833, F1 score = 0.5924
# Query set metrics: Loss = 0.6539, accuracy = 0.8125, precision = 0.7000, recall = 0.6667, F1 score = 0.6818
# Query ID 12/475
# Support set metrics: Loss = 0.9554, accuracy = 0.6125, precision = 0.6058, recall = 0.6033, F1 score = 0.5988
# Query set metrics: Loss = 0.9267, accuracy = 0.5625, precision = 0.4667, recall = 0.4600, F1 score = 0.4597
# Query ID 13/475
# Support set metrics: Loss = 0.9784, accuracy = 0.5750, precision = 0.5671, recall = 0.5633, F1 score = 0.5624
# Query set metrics: Loss = 0.9986, accuracy = 0.5000, precision = 0.5833, recall = 0.5000, F1 score = 0.5100
# Query ID 14/475
# Support set metrics: Loss = 0.8362, accuracy = 0.6625, precision = 0.6592, recall = 0.6567, F1 score = 0.6564
# Query set metrics: Loss = 0.9319, accuracy = 0.5000, precision = 0.4917, recall = 0.4250, F1 score = 0.4540
# Query ID 15/475
# Support set metrics: Loss = 1.0567, accuracy = 0.5500, precision = 0.5350, recall = 0.5367, F1 score = 0.5323
# Query set metrics: Loss = 1.3546, accuracy = 0.5000, precision = 0.5967, recall = 0.5367, F1 score = 0.4876
# Query ID 16/475
# Support set metrics: Loss = 1.0168, accuracy = 0.5875, precision = 0.6033, recall = 0.5833, F1 score = 0.5891
# Query set metrics: Loss = 0.6853, accuracy = 0.7500, precision = 0.7867, recall = 0.7667, F1 score = 0.7581
# Query ID 17/475
# Support set metrics: Loss = 0.7719, accuracy = 0.7125, precision = 0.7366, recall = 0.7100, F1 score = 0.7175
# Query set metrics: Loss = 0.7529, accuracy = 0.6875, precision = 0.7100, recall = 0.6767, F1 score = 0.6700
# Query ID 18/475
# Support set metrics: Loss = 0.9793, accuracy = 0.6625, precision = 0.6491, recall = 0.6467, F1 score = 0.6435
# Query set metrics: Loss = 0.4695, accuracy = 0.8750, precision = 0.7667, recall = 0.7667, F1 score = 0.7636
# Query ID 19/475
# Support set metrics: Loss = 0.8609, accuracy = 0.6250, precision = 0.6200, recall = 0.6200, F1 score = 0.6171
# Query set metrics: Loss = 1.4707, accuracy = 0.3125, precision = 0.2833, recall = 0.2500, F1 score = 0.2532
# Query ID 20/475
# Support set metrics: Loss = 0.9262, accuracy = 0.6625, precision = 0.6557, recall = 0.6533, F1 score = 0.6535
# Query set metrics: Loss = 0.7296, accuracy = 0.6875, precision = 0.7267, recall = 0.7000, F1 score = 0.6854
# Query ID 21/475
# Support set metrics: Loss = 1.0283, accuracy = 0.5500, precision = 0.5609, recall = 0.5367, F1 score = 0.5471
# Query set metrics: Loss = 1.0373, accuracy = 0.3750, precision = 0.3000, recall = 0.3000, F1 score = 0.2826
# Query ID 22/475
# Support set metrics: Loss = 1.0489, accuracy = 0.6250, precision = 0.6348, recall = 0.6167, F1 score = 0.6229
# Query set metrics: Loss = 0.7687, accuracy = 0.6875, precision = 0.6933, recall = 0.7800, F1 score = 0.6910
# Query ID 23/475
# Support set metrics: Loss = 1.0546, accuracy = 0.5875, precision = 0.5902, recall = 0.5767, F1 score = 0.5823
# Query set metrics: Loss = 0.6461, accuracy = 0.6250, precision = 0.5833, recall = 0.5767, F1 score = 0.5678
# Query ID 24/475
# Support set metrics: Loss = 0.8877, accuracy = 0.6625, precision = 0.6967, recall = 0.6600, F1 score = 0.6746
# Query set metrics: Loss = 0.6184, accuracy = 0.7500, precision = 0.6533, recall = 0.6933, F1 score = 0.6655
# Query ID 25/475
# Support set metrics: Loss = 0.9606, accuracy = 0.5875, precision = 0.5988, recall = 0.5833, F1 score = 0.5900
# Query set metrics: Loss = 0.9495, accuracy = 0.6250, precision = 0.6733, recall = 0.6810, F1 score = 0.6076
# Query ID 26/475
# Support set metrics: Loss = 0.9888, accuracy = 0.6125, precision = 0.6133, recall = 0.6000, F1 score = 0.6054
# Query set metrics: Loss = 0.9186, accuracy = 0.6250, precision = 0.6367, recall = 0.7167, F1 score = 0.6533
# Query ID 27/475
# Support set metrics: Loss = 0.9853, accuracy = 0.6125, precision = 0.6310, recall = 0.6100, F1 score = 0.6157
# Query set metrics: Loss = 0.9978, accuracy = 0.6250, precision = 0.6100, recall = 0.6467, F1 score = 0.6067
# Query ID 28/475
# Support set metrics: Loss = 0.9398, accuracy = 0.6000, precision = 0.6066, recall = 0.5867, F1 score = 0.5933
# Query set metrics: Loss = 1.1119, accuracy = 0.5000, precision = 0.4467, recall = 0.5643, F1 score = 0.4264
# Query ID 29/475
# Support set metrics: Loss = 0.8623, accuracy = 0.6750, precision = 0.6725, recall = 0.6667, F1 score = 0.6647
# Query set metrics: Loss = 0.6941, accuracy = 0.6250, precision = 0.6667, recall = 0.6700, F1 score = 0.6033
# Query ID 30/475
# Support set metrics: Loss = 0.8267, accuracy = 0.6500, precision = 0.6691, recall = 0.6400, F1 score = 0.6495
# Query set metrics: Loss = 1.0621, accuracy = 0.4375, precision = 0.5417, recall = 0.4375, F1 score = 0.4583
# Query ID 31/475
# Support set metrics: Loss = 0.8430, accuracy = 0.6625, precision = 0.6739, recall = 0.6600, F1 score = 0.6612
# Query set metrics: Loss = 1.0939, accuracy = 0.5625, precision = 0.5633, recall = 0.5000, F1 score = 0.5079
# Query ID 32/475
# Support set metrics: Loss = 0.9411, accuracy = 0.6375, precision = 0.6204, recall = 0.6300, F1 score = 0.6181
# Query set metrics: Loss = 0.7039, accuracy = 0.6875, precision = 0.7367, recall = 0.7500, F1 score = 0.7214
# Query ID 33/475
# Support set metrics: Loss = 0.9599, accuracy = 0.5750, precision = 0.5813, recall = 0.5733, F1 score = 0.5758
# Query set metrics: Loss = 0.7380, accuracy = 0.7500, precision = 0.6133, recall = 0.6833, F1 score = 0.6388
# Query ID 34/475
# Support set metrics: Loss = 0.9313, accuracy = 0.5875, precision = 0.5747, recall = 0.5800, F1 score = 0.5729
# Query set metrics: Loss = 0.9736, accuracy = 0.5000, precision = 0.5500, recall = 0.4300, F1 score = 0.4643
# Query ID 35/475
# Support set metrics: Loss = 0.9176, accuracy = 0.6000, precision = 0.6328, recall = 0.6000, F1 score = 0.6126
# Query set metrics: Loss = 0.6832, accuracy = 0.7500, precision = 0.8250, recall = 0.7625, F1 score = 0.7667
# Query ID 36/475
# Support set metrics: Loss = 0.7069, accuracy = 0.7500, precision = 0.7605, recall = 0.7467, F1 score = 0.7523
# Query set metrics: Loss = 0.8782, accuracy = 0.6875, precision = 0.6600, recall = 0.7167, F1 score = 0.6502
# Query ID 37/475
# Support set metrics: Loss = 0.9647, accuracy = 0.5750, precision = 0.5916, recall = 0.5700, F1 score = 0.5747
# Query set metrics: Loss = 0.6858, accuracy = 0.7500, precision = 0.6333, recall = 0.6433, F1 score = 0.6325
# Query ID 38/475
# Support set metrics: Loss = 0.9136, accuracy = 0.6625, precision = 0.6578, recall = 0.6467, F1 score = 0.6472
# Query set metrics: Loss = 0.8557, accuracy = 0.6250, precision = 0.6000, recall = 0.6367, F1 score = 0.6033
# Query ID 39/475
# Support set metrics: Loss = 0.7527, accuracy = 0.6500, precision = 0.6383, recall = 0.6400, F1 score = 0.6350
# Query set metrics: Loss = 0.8347, accuracy = 0.6250, precision = 0.6200, recall = 0.6000, F1 score = 0.5990
# Query ID 40/475
# Support set metrics: Loss = 0.8486, accuracy = 0.6875, precision = 0.7035, recall = 0.6867, F1 score = 0.6897
# Query set metrics: Loss = 0.7496, accuracy = 0.6875, precision = 0.8267, recall = 0.8190, F1 score = 0.7867
# Query ID 41/475
# Support set metrics: Loss = 0.9977, accuracy = 0.6000, precision = 0.6327, recall = 0.5967, F1 score = 0.6124
# Query set metrics: Loss = 0.9659, accuracy = 0.6250, precision = 0.6667, recall = 0.5667, F1 score = 0.5800
# Query ID 42/475
# Support set metrics: Loss = 0.9275, accuracy = 0.5875, precision = 0.5921, recall = 0.5867, F1 score = 0.5877
# Query set metrics: Loss = 0.9698, accuracy = 0.5625, precision = 0.6667, recall = 0.6750, F1 score = 0.5891
# Query ID 43/475
# Support set metrics: Loss = 0.9517, accuracy = 0.6125, precision = 0.6148, recall = 0.6133, F1 score = 0.6123
# Query set metrics: Loss = 1.4075, accuracy = 0.4375, precision = 0.4467, recall = 0.4300, F1 score = 0.3857
# Query ID 44/475
# Support set metrics: Loss = 0.9921, accuracy = 0.5750, precision = 0.5800, recall = 0.5600, F1 score = 0.5653
# Query set metrics: Loss = 0.6634, accuracy = 0.6875, precision = 0.8333, recall = 0.7310, F1 score = 0.7625
# Query ID 45/475
# Support set metrics: Loss = 0.8690, accuracy = 0.6500, precision = 0.6570, recall = 0.6467, F1 score = 0.6477
# Query set metrics: Loss = 0.6317, accuracy = 0.6875, precision = 0.7417, recall = 0.7292, F1 score = 0.7211
# Query ID 46/475
# Support set metrics: Loss = 1.0459, accuracy = 0.6125, precision = 0.6599, recall = 0.6100, F1 score = 0.6306
# Query set metrics: Loss = 1.1764, accuracy = 0.3125, precision = 0.2667, recall = 0.2333, F1 score = 0.2467
# Query ID 47/475
# Support set metrics: Loss = 0.7475, accuracy = 0.6250, precision = 0.6185, recall = 0.6133, F1 score = 0.6132
# Query set metrics: Loss = 0.8955, accuracy = 0.6875, precision = 0.8200, recall = 0.6867, F1 score = 0.7067
# Query ID 48/475
# Support set metrics: Loss = 0.8544, accuracy = 0.6375, precision = 0.6765, recall = 0.6433, F1 score = 0.6536
# Query set metrics: Loss = 0.8592, accuracy = 0.3750, precision = 0.4667, recall = 0.3667, F1 score = 0.3800
# Query ID 49/475
# Support set metrics: Loss = 0.7729, accuracy = 0.6000, precision = 0.5992, recall = 0.5900, F1 score = 0.5936
# Query set metrics: Loss = 1.3680, accuracy = 0.4375, precision = 0.5500, recall = 0.4833, F1 score = 0.5100
# Query ID 50/475
# Support set metrics: Loss = 0.9015, accuracy = 0.6375, precision = 0.6362, recall = 0.6267, F1 score = 0.6273
# Query set metrics: Loss = 1.0223, accuracy = 0.6250, precision = 0.5714, recall = 0.5167, F1 score = 0.5400
# Query ID 51/475
# Support set metrics: Loss = 1.0057, accuracy = 0.6625, precision = 0.6786, recall = 0.6567, F1 score = 0.6655
# Query set metrics: Loss = 0.9192, accuracy = 0.5625, precision = 0.6200, recall = 0.6000, F1 score = 0.5667
# Query ID 52/475
# Support set metrics: Loss = 0.8668, accuracy = 0.6625, precision = 0.6594, recall = 0.6533, F1 score = 0.6557
# Query set metrics: Loss = 0.7345, accuracy = 0.5625, precision = 0.5533, recall = 0.5200, F1 score = 0.5276
# Query ID 53/475
# Support set metrics: Loss = 0.8685, accuracy = 0.6625, precision = 0.6739, recall = 0.6533, F1 score = 0.6594
# Query set metrics: Loss = 1.4880, accuracy = 0.5625, precision = 0.6900, recall = 0.5800, F1 score = 0.5571
# Query ID 54/475
# Support set metrics: Loss = 1.0692, accuracy = 0.5625, precision = 0.5640, recall = 0.5533, F1 score = 0.5573
# Query set metrics: Loss = 1.1737, accuracy = 0.6250, precision = 0.7524, recall = 0.6200, F1 score = 0.6600
# Query ID 55/475
# Support set metrics: Loss = 0.8179, accuracy = 0.6375, precision = 0.6348, recall = 0.6200, F1 score = 0.6206
# Query set metrics: Loss = 0.8902, accuracy = 0.6250, precision = 0.4000, recall = 0.3833, F1 score = 0.3810
# Query ID 56/475
# Support set metrics: Loss = 0.8621, accuracy = 0.6750, precision = 0.6729, recall = 0.6667, F1 score = 0.6693
# Query set metrics: Loss = 1.0696, accuracy = 0.5625, precision = 0.4467, recall = 0.4667, F1 score = 0.4467
# Query ID 57/475
# Support set metrics: Loss = 1.0439, accuracy = 0.6250, precision = 0.6291, recall = 0.6200, F1 score = 0.6213
# Query set metrics: Loss = 1.4530, accuracy = 0.5000, precision = 0.6000, recall = 0.5733, F1 score = 0.5705
# Query ID 58/475
# Support set metrics: Loss = 0.8854, accuracy = 0.6500, precision = 0.6521, recall = 0.6400, F1 score = 0.6425
# Query set metrics: Loss = 0.8489, accuracy = 0.5625, precision = 0.5000, recall = 0.5000, F1 score = 0.4733
# Query ID 59/475
# Support set metrics: Loss = 0.8223, accuracy = 0.7375, precision = 0.7458, recall = 0.7367, F1 score = 0.7366
# Query set metrics: Loss = 0.9264, accuracy = 0.7500, precision = 0.8583, recall = 0.7333, F1 score = 0.7405
# Query ID 60/475
# Support set metrics: Loss = 0.9599, accuracy = 0.5875, precision = 0.5868, recall = 0.5833, F1 score = 0.5835
# Query set metrics: Loss = 0.7873, accuracy = 0.6875, precision = 0.5900, recall = 0.6167, F1 score = 0.5697
# Query ID 61/475
# Support set metrics: Loss = 0.9607, accuracy = 0.6000, precision = 0.5973, recall = 0.5867, F1 score = 0.5888
# Query set metrics: Loss = 1.0619, accuracy = 0.5000, precision = 0.4333, recall = 0.5333, F1 score = 0.4533
# Query ID 62/475
# Support set metrics: Loss = 0.9686, accuracy = 0.5750, precision = 0.5884, recall = 0.5700, F1 score = 0.5750
# Query set metrics: Loss = 0.9907, accuracy = 0.6250, precision = 0.7000, recall = 0.7133, F1 score = 0.6822
# Query ID 63/475
# Support set metrics: Loss = 1.1365, accuracy = 0.5875, precision = 0.5764, recall = 0.5767, F1 score = 0.5736
# Query set metrics: Loss = 0.7511, accuracy = 0.6250, precision = 0.8125, recall = 0.6125, F1 score = 0.6708
# Query ID 64/475
# Support set metrics: Loss = 0.8827, accuracy = 0.6250, precision = 0.6416, recall = 0.6233, F1 score = 0.6269
# Query set metrics: Loss = 0.9069, accuracy = 0.6250, precision = 0.5000, recall = 0.5167, F1 score = 0.5071
# Query ID 65/475
# Support set metrics: Loss = 0.9394, accuracy = 0.6125, precision = 0.6020, recall = 0.6000, F1 score = 0.5958
# Query set metrics: Loss = 0.7991, accuracy = 0.7500, precision = 0.8100, recall = 0.7867, F1 score = 0.7854
# Query ID 66/475
# Support set metrics: Loss = 1.0135, accuracy = 0.6125, precision = 0.6050, recall = 0.6033, F1 score = 0.6021
# Query set metrics: Loss = 0.9386, accuracy = 0.6875, precision = 0.7700, recall = 0.7167, F1 score = 0.6714
# Query ID 67/475
# Support set metrics: Loss = 1.2023, accuracy = 0.5375, precision = 0.5563, recall = 0.5300, F1 score = 0.5397
# Query set metrics: Loss = 0.8774, accuracy = 0.6875, precision = 0.7679, recall = 0.6500, F1 score = 0.6806
# Query ID 68/475
# Support set metrics: Loss = 1.0235, accuracy = 0.5125, precision = 0.5178, recall = 0.5033, F1 score = 0.5093
# Query set metrics: Loss = 0.9457, accuracy = 0.5625, precision = 0.7000, recall = 0.6633, F1 score = 0.5943
# Query ID 69/475
# Support set metrics: Loss = 0.8817, accuracy = 0.6250, precision = 0.6165, recall = 0.6200, F1 score = 0.6171
# Query set metrics: Loss = 0.8790, accuracy = 0.5625, precision = 0.6367, recall = 0.5833, F1 score = 0.5443
# Query ID 70/475
# Support set metrics: Loss = 1.1255, accuracy = 0.5000, precision = 0.4937, recall = 0.4833, F1 score = 0.4866
# Query set metrics: Loss = 1.3701, accuracy = 0.4375, precision = 0.5167, recall = 0.5867, F1 score = 0.5071
# Query ID 71/475
# Support set metrics: Loss = 0.8392, accuracy = 0.6500, precision = 0.6812, recall = 0.6533, F1 score = 0.6642
# Query set metrics: Loss = 0.8921, accuracy = 0.5625, precision = 0.6033, recall = 0.4833, F1 score = 0.4967
# Query ID 72/475
# Support set metrics: Loss = 0.8179, accuracy = 0.6625, precision = 0.6677, recall = 0.6567, F1 score = 0.6557
# Query set metrics: Loss = 0.7228, accuracy = 0.6250, precision = 0.6800, recall = 0.7400, F1 score = 0.6889
# Query ID 73/475
# Support set metrics: Loss = 0.8694, accuracy = 0.6500, precision = 0.6784, recall = 0.6567, F1 score = 0.6612
# Query set metrics: Loss = 0.8577, accuracy = 0.7500, precision = 0.6600, recall = 0.6533, F1 score = 0.6425
# Query ID 74/475
# Support set metrics: Loss = 0.7934, accuracy = 0.7000, precision = 0.7083, recall = 0.6967, F1 score = 0.6984
# Query set metrics: Loss = 0.8737, accuracy = 0.5625, precision = 0.6300, recall = 0.6333, F1 score = 0.6222
# Query ID 75/475
# Support set metrics: Loss = 0.9175, accuracy = 0.6500, precision = 0.6487, recall = 0.6433, F1 score = 0.6447
# Query set metrics: Loss = 0.9224, accuracy = 0.5625, precision = 0.3067, recall = 0.4500, F1 score = 0.3552
# Query ID 76/475
# Support set metrics: Loss = 1.1598, accuracy = 0.5125, precision = 0.5121, recall = 0.5033, F1 score = 0.5073
# Query set metrics: Loss = 0.8377, accuracy = 0.5625, precision = 0.5533, recall = 0.4967, F1 score = 0.5076
# Query ID 77/475
# Support set metrics: Loss = 0.8604, accuracy = 0.6000, precision = 0.5875, recall = 0.5867, F1 score = 0.5864
# Query set metrics: Loss = 1.4570, accuracy = 0.5625, precision = 0.4800, recall = 0.4667, F1 score = 0.4543
# Query ID 78/475
# Support set metrics: Loss = 0.9797, accuracy = 0.5625, precision = 0.5609, recall = 0.5600, F1 score = 0.5585
# Query set metrics: Loss = 1.0009, accuracy = 0.7500, precision = 0.6800, recall = 0.7200, F1 score = 0.6778
# Query ID 79/475
# Support set metrics: Loss = 0.8938, accuracy = 0.6875, precision = 0.7163, recall = 0.6867, F1 score = 0.6983
# Query set metrics: Loss = 1.0344, accuracy = 0.4375, precision = 0.4250, recall = 0.4857, F1 score = 0.3984
# Query ID 80/475
# Support set metrics: Loss = 0.9184, accuracy = 0.5750, precision = 0.5743, recall = 0.5600, F1 score = 0.5648
# Query set metrics: Loss = 0.7339, accuracy = 0.6875, precision = 0.6767, recall = 0.6833, F1 score = 0.6744
# Query ID 81/475
# Support set metrics: Loss = 1.0692, accuracy = 0.5500, precision = 0.5540, recall = 0.5400, F1 score = 0.5431
# Query set metrics: Loss = 0.7158, accuracy = 0.6250, precision = 0.4500, recall = 0.5333, F1 score = 0.4857
# Query ID 82/475
# Support set metrics: Loss = 0.7879, accuracy = 0.7125, precision = 0.7075, recall = 0.7033, F1 score = 0.7017
# Query set metrics: Loss = 0.5991, accuracy = 0.7500, precision = 0.8250, recall = 0.6583, F1 score = 0.7000
# Query ID 83/475
# Support set metrics: Loss = 1.0252, accuracy = 0.5750, precision = 0.5819, recall = 0.5667, F1 score = 0.5740
# Query set metrics: Loss = 1.2364, accuracy = 0.5000, precision = 0.4033, recall = 0.4533, F1 score = 0.4167
# Query ID 84/475
# Support set metrics: Loss = 1.0144, accuracy = 0.6125, precision = 0.6410, recall = 0.6067, F1 score = 0.6194
# Query set metrics: Loss = 1.1630, accuracy = 0.4375, precision = 0.6533, recall = 0.5533, F1 score = 0.4676
# Query ID 85/475
# Support set metrics: Loss = 0.8148, accuracy = 0.7000, precision = 0.7105, recall = 0.6967, F1 score = 0.7016
# Query set metrics: Loss = 0.7729, accuracy = 0.6250, precision = 0.5933, recall = 0.6667, F1 score = 0.6054
# Query ID 86/475
# Support set metrics: Loss = 1.0255, accuracy = 0.6375, precision = 0.6494, recall = 0.6400, F1 score = 0.6397
# Query set metrics: Loss = 0.6247, accuracy = 0.6875, precision = 0.4248, recall = 0.5000, F1 score = 0.4489
# Query ID 87/475
# Support set metrics: Loss = 0.9489, accuracy = 0.5875, precision = 0.5685, recall = 0.5700, F1 score = 0.5670
# Query set metrics: Loss = 0.8974, accuracy = 0.5000, precision = 0.5367, recall = 0.4833, F1 score = 0.4667
# Query ID 88/475
# Support set metrics: Loss = 0.8933, accuracy = 0.5875, precision = 0.5808, recall = 0.5767, F1 score = 0.5784
# Query set metrics: Loss = 0.7575, accuracy = 0.6875, precision = 0.6833, recall = 0.7500, F1 score = 0.6485
# Query ID 89/475
# Support set metrics: Loss = 0.8752, accuracy = 0.6500, precision = 0.6427, recall = 0.6400, F1 score = 0.6392
# Query set metrics: Loss = 0.8221, accuracy = 0.5625, precision = 0.4767, recall = 0.5343, F1 score = 0.4800
# Query ID 90/475
# Support set metrics: Loss = 1.0803, accuracy = 0.5750, precision = 0.5756, recall = 0.5633, F1 score = 0.5677
# Query set metrics: Loss = 1.1711, accuracy = 0.4375, precision = 0.3000, recall = 0.4333, F1 score = 0.3467
# Query ID 91/475
# Support set metrics: Loss = 0.8878, accuracy = 0.5625, precision = 0.5643, recall = 0.5567, F1 score = 0.5574
# Query set metrics: Loss = 0.7187, accuracy = 0.7500, precision = 0.6167, recall = 0.6800, F1 score = 0.6269
# Query ID 92/475
# Support set metrics: Loss = 0.8783, accuracy = 0.6500, precision = 0.6463, recall = 0.6433, F1 score = 0.6439
# Query set metrics: Loss = 0.8606, accuracy = 0.5625, precision = 0.4533, recall = 0.5300, F1 score = 0.4667
# Query ID 93/475
# Support set metrics: Loss = 1.0518, accuracy = 0.5250, precision = 0.5051, recall = 0.5133, F1 score = 0.5063
# Query set metrics: Loss = 0.7564, accuracy = 0.7500, precision = 0.6429, recall = 0.6000, F1 score = 0.6095
# Query ID 94/475
# Support set metrics: Loss = 1.0156, accuracy = 0.5875, precision = 0.5922, recall = 0.5833, F1 score = 0.5849
# Query set metrics: Loss = 1.1793, accuracy = 0.5000, precision = 0.3600, recall = 0.4667, F1 score = 0.3931
# Query ID 95/475
# Support set metrics: Loss = 1.0160, accuracy = 0.5000, precision = 0.4835, recall = 0.4900, F1 score = 0.4818
# Query set metrics: Loss = 0.4898, accuracy = 0.8125, precision = 0.6833, recall = 0.6833, F1 score = 0.6762
# Query ID 96/475
# Support set metrics: Loss = 0.9554, accuracy = 0.6125, precision = 0.6292, recall = 0.6067, F1 score = 0.6138
# Query set metrics: Loss = 0.8863, accuracy = 0.7500, precision = 0.8000, recall = 0.7667, F1 score = 0.7467
# Query ID 97/475
# Support set metrics: Loss = 0.7991, accuracy = 0.6875, precision = 0.7002, recall = 0.6800, F1 score = 0.6867
# Query set metrics: Loss = 1.0510, accuracy = 0.6250, precision = 0.5625, recall = 0.4851, F1 score = 0.5183
# Query ID 98/475
# Support set metrics: Loss = 0.9070, accuracy = 0.6375, precision = 0.6326, recall = 0.6267, F1 score = 0.6276
# Query set metrics: Loss = 0.8228, accuracy = 0.6250, precision = 0.6143, recall = 0.6267, F1 score = 0.6133
# Query ID 99/475
# Support set metrics: Loss = 0.8668, accuracy = 0.7125, precision = 0.7327, recall = 0.7033, F1 score = 0.7131
# Query set metrics: Loss = 0.6433, accuracy = 0.7500, precision = 0.8262, recall = 0.7333, F1 score = 0.6981
# Query ID 100/475
# Support set metrics: Loss = 1.0265, accuracy = 0.6125, precision = 0.6082, recall = 0.5967, F1 score = 0.5909
# Query set metrics: Loss = 0.7491, accuracy = 0.6875, precision = 0.7167, recall = 0.6600, F1 score = 0.6635
# Query ID 101/475
# Support set metrics: Loss = 0.8598, accuracy = 0.6750, precision = 0.7143, recall = 0.6733, F1 score = 0.6874
# Query set metrics: Loss = 1.1695, accuracy = 0.5625, precision = 0.5133, recall = 0.4600, F1 score = 0.4677
# Query ID 102/475
# Support set metrics: Loss = 0.9078, accuracy = 0.6125, precision = 0.6186, recall = 0.6100, F1 score = 0.6073
# Query set metrics: Loss = 1.0663, accuracy = 0.6250, precision = 0.7000, recall = 0.6500, F1 score = 0.6324
# Query ID 103/475
# Support set metrics: Loss = 0.9355, accuracy = 0.6625, precision = 0.6771, recall = 0.6567, F1 score = 0.6628
# Query set metrics: Loss = 1.2117, accuracy = 0.5625, precision = 0.6500, recall = 0.5533, F1 score = 0.5643
# Query ID 104/475
# Support set metrics: Loss = 0.8884, accuracy = 0.6750, precision = 0.6741, recall = 0.6600, F1 score = 0.6588
# Query set metrics: Loss = 0.6397, accuracy = 0.6875, precision = 0.6667, recall = 0.7167, F1 score = 0.6757
# Query ID 105/475
# Support set metrics: Loss = 0.9915, accuracy = 0.6250, precision = 0.6338, recall = 0.6167, F1 score = 0.6192
# Query set metrics: Loss = 0.6818, accuracy = 0.5625, precision = 0.5500, recall = 0.5500, F1 score = 0.5452
# Query ID 106/475
# Support set metrics: Loss = 0.9915, accuracy = 0.5875, precision = 0.5744, recall = 0.5800, F1 score = 0.5766
# Query set metrics: Loss = 1.1959, accuracy = 0.3750, precision = 0.3500, recall = 0.4333, F1 score = 0.3705
# Query ID 107/475
# Support set metrics: Loss = 0.9823, accuracy = 0.6000, precision = 0.6078, recall = 0.5867, F1 score = 0.5932
# Query set metrics: Loss = 0.9474, accuracy = 0.4375, precision = 0.5000, recall = 0.4000, F1 score = 0.3943
# Query ID 108/475
# Support set metrics: Loss = 0.9843, accuracy = 0.6500, precision = 0.6900, recall = 0.6467, F1 score = 0.6556
# Query set metrics: Loss = 1.2025, accuracy = 0.3125, precision = 0.3524, recall = 0.2900, F1 score = 0.2438
# Query ID 109/475
# Support set metrics: Loss = 0.8028, accuracy = 0.6500, precision = 0.6443, recall = 0.6467, F1 score = 0.6418
# Query set metrics: Loss = 1.0253, accuracy = 0.5625, precision = 0.6133, recall = 0.5433, F1 score = 0.5455
# Query ID 110/475
# Support set metrics: Loss = 0.9181, accuracy = 0.5625, precision = 0.5604, recall = 0.5500, F1 score = 0.5537
# Query set metrics: Loss = 1.1505, accuracy = 0.5000, precision = 0.5533, recall = 0.5167, F1 score = 0.4767
# Query ID 111/475
# Support set metrics: Loss = 1.0600, accuracy = 0.5500, precision = 0.5505, recall = 0.5400, F1 score = 0.5411
# Query set metrics: Loss = 0.8891, accuracy = 0.6250, precision = 0.6800, recall = 0.6733, F1 score = 0.6711
# Query ID 112/475
# Support set metrics: Loss = 0.9090, accuracy = 0.7125, precision = 0.7151, recall = 0.7067, F1 score = 0.7081
# Query set metrics: Loss = 0.7310, accuracy = 0.6250, precision = 0.6500, recall = 0.7333, F1 score = 0.6210
# Query ID 113/475
# Support set metrics: Loss = 0.9302, accuracy = 0.6500, precision = 0.6649, recall = 0.6467, F1 score = 0.6542
# Query set metrics: Loss = 1.0909, accuracy = 0.5000, precision = 0.4000, recall = 0.4000, F1 score = 0.3943
# Query ID 114/475
# Support set metrics: Loss = 0.9602, accuracy = 0.6250, precision = 0.6257, recall = 0.6133, F1 score = 0.6115
# Query set metrics: Loss = 1.1703, accuracy = 0.5625, precision = 0.6143, recall = 0.5933, F1 score = 0.5276
# Query ID 115/475
# Support set metrics: Loss = 1.0070, accuracy = 0.5625, precision = 0.5606, recall = 0.5433, F1 score = 0.5483
# Query set metrics: Loss = 1.2329, accuracy = 0.5000, precision = 0.5500, recall = 0.4167, F1 score = 0.4714
# Query ID 116/475
# Support set metrics: Loss = 0.9729, accuracy = 0.6125, precision = 0.6286, recall = 0.6100, F1 score = 0.6154
# Query set metrics: Loss = 1.0034, accuracy = 0.5625, precision = 0.6524, recall = 0.6667, F1 score = 0.5667
# Query ID 117/475
# Support set metrics: Loss = 0.9257, accuracy = 0.6000, precision = 0.5865, recall = 0.5900, F1 score = 0.5875
# Query set metrics: Loss = 0.9908, accuracy = 0.5625, precision = 0.4000, recall = 0.4429, F1 score = 0.3667
# Query ID 118/475
# Support set metrics: Loss = 0.8859, accuracy = 0.6500, precision = 0.6313, recall = 0.6433, F1 score = 0.6346
# Query set metrics: Loss = 0.9373, accuracy = 0.6250, precision = 0.6167, recall = 0.6333, F1 score = 0.5981
# Query ID 119/475
# Support set metrics: Loss = 1.0339, accuracy = 0.5500, precision = 0.5600, recall = 0.5433, F1 score = 0.5459
# Query set metrics: Loss = 0.7651, accuracy = 0.6875, precision = 0.8000, recall = 0.8167, F1 score = 0.7357
# Query ID 120/475
# Support set metrics: Loss = 1.0258, accuracy = 0.5750, precision = 0.5849, recall = 0.5667, F1 score = 0.5740
# Query set metrics: Loss = 0.8398, accuracy = 0.7500, precision = 0.7667, recall = 0.7833, F1 score = 0.7390
# Query ID 121/475
# Support set metrics: Loss = 0.7148, accuracy = 0.7125, precision = 0.6808, recall = 0.6967, F1 score = 0.6798
# Query set metrics: Loss = 1.1572, accuracy = 0.5625, precision = 0.5533, recall = 0.6333, F1 score = 0.5476
# Query ID 122/475
# Support set metrics: Loss = 1.0228, accuracy = 0.5500, precision = 0.5531, recall = 0.5400, F1 score = 0.5459
# Query set metrics: Loss = 0.9655, accuracy = 0.5000, precision = 0.5833, recall = 0.5000, F1 score = 0.4981
# Query ID 123/475
# Support set metrics: Loss = 1.1255, accuracy = 0.5125, precision = 0.5353, recall = 0.5033, F1 score = 0.5142
# Query set metrics: Loss = 0.8477, accuracy = 0.6875, precision = 0.7743, recall = 0.6267, F1 score = 0.6444
# Query ID 124/475
# Support set metrics: Loss = 0.8825, accuracy = 0.6500, precision = 0.6681, recall = 0.6433, F1 score = 0.6442
# Query set metrics: Loss = 0.9610, accuracy = 0.5625, precision = 0.7125, recall = 0.6167, F1 score = 0.5645
# Query ID 125/475
# Support set metrics: Loss = 0.9285, accuracy = 0.7625, precision = 0.7801, recall = 0.7533, F1 score = 0.7620
# Query set metrics: Loss = 1.2138, accuracy = 0.4375, precision = 0.5667, recall = 0.4500, F1 score = 0.4571
# Query ID 126/475
# Support set metrics: Loss = 1.0000, accuracy = 0.5875, precision = 0.5803, recall = 0.5800, F1 score = 0.5792
# Query set metrics: Loss = 0.8100, accuracy = 0.7500, precision = 0.7933, recall = 0.7500, F1 score = 0.7425
# Query ID 127/475
# Support set metrics: Loss = 0.8409, accuracy = 0.7000, precision = 0.6994, recall = 0.6933, F1 score = 0.6884
# Query set metrics: Loss = 0.6193, accuracy = 0.8750, precision = 0.9000, recall = 0.9000, F1 score = 0.8929
# Query ID 128/475
# Support set metrics: Loss = 0.8516, accuracy = 0.5625, precision = 0.5621, recall = 0.5533, F1 score = 0.5550
# Query set metrics: Loss = 0.7952, accuracy = 0.5000, precision = 0.4633, recall = 0.4633, F1 score = 0.4500
# Query ID 129/475
# Support set metrics: Loss = 1.0460, accuracy = 0.5125, precision = 0.5131, recall = 0.5033, F1 score = 0.5076
# Query set metrics: Loss = 0.6618, accuracy = 0.7500, precision = 0.7833, recall = 0.7533, F1 score = 0.7429
# Query ID 130/475
# Support set metrics: Loss = 0.8171, accuracy = 0.7250, precision = 0.7249, recall = 0.7233, F1 score = 0.7221
# Query set metrics: Loss = 0.7202, accuracy = 0.6875, precision = 0.6429, recall = 0.5333, F1 score = 0.5467
# Query ID 131/475
# Support set metrics: Loss = 0.8771, accuracy = 0.6250, precision = 0.6105, recall = 0.6133, F1 score = 0.6065
# Query set metrics: Loss = 0.9285, accuracy = 0.6250, precision = 0.6000, recall = 0.6333, F1 score = 0.6067
# Query ID 132/475
# Support set metrics: Loss = 1.0708, accuracy = 0.5250, precision = 0.5348, recall = 0.5233, F1 score = 0.5281
# Query set metrics: Loss = 1.2096, accuracy = 0.5625, precision = 0.5700, recall = 0.5867, F1 score = 0.5167
# Query ID 133/475
# Support set metrics: Loss = 0.8958, accuracy = 0.6000, precision = 0.5915, recall = 0.5867, F1 score = 0.5875
# Query set metrics: Loss = 0.8359, accuracy = 0.5625, precision = 0.4867, recall = 0.5100, F1 score = 0.4849
# Query ID 134/475
# Support set metrics: Loss = 0.7935, accuracy = 0.6625, precision = 0.6489, recall = 0.6500, F1 score = 0.6489
# Query set metrics: Loss = 0.9637, accuracy = 0.5625, precision = 0.6067, recall = 0.6367, F1 score = 0.5300
# Query ID 135/475
# Support set metrics: Loss = 1.0062, accuracy = 0.6125, precision = 0.6387, recall = 0.6033, F1 score = 0.6144
# Query set metrics: Loss = 0.5623, accuracy = 0.8125, precision = 0.8800, recall = 0.8500, F1 score = 0.8190
# Query ID 136/475
# Support set metrics: Loss = 1.0908, accuracy = 0.5375, precision = 0.5420, recall = 0.5300, F1 score = 0.5317
# Query set metrics: Loss = 1.4818, accuracy = 0.3750, precision = 0.4500, recall = 0.3771, F1 score = 0.3189
# Query ID 137/475
# Support set metrics: Loss = 1.1142, accuracy = 0.5625, precision = 0.5737, recall = 0.5533, F1 score = 0.5621
# Query set metrics: Loss = 1.0636, accuracy = 0.5625, precision = 0.6643, recall = 0.6167, F1 score = 0.5188
# Query ID 138/475
# Support set metrics: Loss = 0.8206, accuracy = 0.6875, precision = 0.7103, recall = 0.6833, F1 score = 0.6964
# Query set metrics: Loss = 0.8551, accuracy = 0.6875, precision = 0.7133, recall = 0.6500, F1 score = 0.6578
# Query ID 139/475
# Support set metrics: Loss = 1.0118, accuracy = 0.5125, precision = 0.5119, recall = 0.5033, F1 score = 0.5063
# Query set metrics: Loss = 0.7044, accuracy = 0.6250, precision = 0.6429, recall = 0.5833, F1 score = 0.6038
# Query ID 140/475
# Support set metrics: Loss = 0.9179, accuracy = 0.6500, precision = 0.6371, recall = 0.6300, F1 score = 0.6313
# Query set metrics: Loss = 0.5191, accuracy = 0.8125, precision = 0.8500, recall = 0.8533, F1 score = 0.8267
# Query ID 141/475
# Support set metrics: Loss = 0.8407, accuracy = 0.7125, precision = 0.7089, recall = 0.7033, F1 score = 0.7015
# Query set metrics: Loss = 0.7784, accuracy = 0.6250, precision = 0.5133, recall = 0.5500, F1 score = 0.5254
# Query ID 142/475
# Support set metrics: Loss = 0.8067, accuracy = 0.6750, precision = 0.7066, recall = 0.6733, F1 score = 0.6835
# Query set metrics: Loss = 0.6619, accuracy = 0.8750, precision = 0.9100, recall = 0.8500, F1 score = 0.8611
# Query ID 143/475
# Support set metrics: Loss = 0.7769, accuracy = 0.6750, precision = 0.6901, recall = 0.6733, F1 score = 0.6794
# Query set metrics: Loss = 0.6048, accuracy = 0.6875, precision = 0.7133, recall = 0.6933, F1 score = 0.6663
# Query ID 144/475
# Support set metrics: Loss = 0.9612, accuracy = 0.5625, precision = 0.5521, recall = 0.5533, F1 score = 0.5486
# Query set metrics: Loss = 0.9686, accuracy = 0.6250, precision = 0.5200, recall = 0.6833, F1 score = 0.5600
# Query ID 145/475
# Support set metrics: Loss = 1.2052, accuracy = 0.5125, precision = 0.5084, recall = 0.5000, F1 score = 0.5025
# Query set metrics: Loss = 1.1735, accuracy = 0.5625, precision = 0.4095, recall = 0.5167, F1 score = 0.4510
# Query ID 146/475
# Support set metrics: Loss = 0.7305, accuracy = 0.7125, precision = 0.7686, recall = 0.7033, F1 score = 0.7193
# Query set metrics: Loss = 0.8908, accuracy = 0.6875, precision = 0.6167, recall = 0.5452, F1 score = 0.5750
# Query ID 147/475
# Support set metrics: Loss = 0.9451, accuracy = 0.6375, precision = 0.6434, recall = 0.6267, F1 score = 0.6337
# Query set metrics: Loss = 0.6846, accuracy = 0.8125, precision = 0.8533, recall = 0.8533, F1 score = 0.8200
# Query ID 148/475
# Support set metrics: Loss = 1.0025, accuracy = 0.5500, precision = 0.5475, recall = 0.5467, F1 score = 0.5423
# Query set metrics: Loss = 1.1164, accuracy = 0.6250, precision = 0.6200, recall = 0.6200, F1 score = 0.6143
# Query ID 149/475
# Support set metrics: Loss = 0.9524, accuracy = 0.6125, precision = 0.6279, recall = 0.6033, F1 score = 0.6123
# Query set metrics: Loss = 0.9485, accuracy = 0.6875, precision = 0.7500, recall = 0.7375, F1 score = 0.7211
# Query ID 150/475
# Support set metrics: Loss = 0.8891, accuracy = 0.6250, precision = 0.6213, recall = 0.6133, F1 score = 0.6129
# Query set metrics: Loss = 0.6984, accuracy = 0.8125, precision = 0.8250, recall = 0.8333, F1 score = 0.8234
# Query ID 151/475
# Support set metrics: Loss = 0.9635, accuracy = 0.5625, precision = 0.5741, recall = 0.5533, F1 score = 0.5627
# Query set metrics: Loss = 0.7325, accuracy = 0.6250, precision = 0.5733, recall = 0.6133, F1 score = 0.5521
# Query ID 152/475
# Support set metrics: Loss = 1.0865, accuracy = 0.5375, precision = 0.5678, recall = 0.5333, F1 score = 0.5495
# Query set metrics: Loss = 0.7956, accuracy = 0.6250, precision = 0.5167, recall = 0.5600, F1 score = 0.5312
# Query ID 153/475
# Support set metrics: Loss = 0.8662, accuracy = 0.7250, precision = 0.7332, recall = 0.7233, F1 score = 0.7278
# Query set metrics: Loss = 0.5363, accuracy = 0.8750, precision = 1.0000, recall = 0.8500, F1 score = 0.9153
# Query ID 154/475
# Support set metrics: Loss = 0.8088, accuracy = 0.7500, precision = 0.7493, recall = 0.7400, F1 score = 0.7438
# Query set metrics: Loss = 0.8742, accuracy = 0.5000, precision = 0.5000, recall = 0.4833, F1 score = 0.4105
# Query ID 155/475
# Support set metrics: Loss = 0.8259, accuracy = 0.6750, precision = 0.6761, recall = 0.6700, F1 score = 0.6719
# Query set metrics: Loss = 0.5738, accuracy = 0.7500, precision = 0.8467, recall = 0.7833, F1 score = 0.7361
# Query ID 156/475
# Support set metrics: Loss = 0.8913, accuracy = 0.6625, precision = 0.6589, recall = 0.6567, F1 score = 0.6535
# Query set metrics: Loss = 0.5474, accuracy = 0.7500, precision = 0.7833, recall = 0.7500, F1 score = 0.6848
# Query ID 157/475
# Support set metrics: Loss = 0.8150, accuracy = 0.7125, precision = 0.7225, recall = 0.6967, F1 score = 0.7005
# Query set metrics: Loss = 0.7124, accuracy = 0.7500, precision = 0.8000, recall = 0.7600, F1 score = 0.7588
# Query ID 158/475
# Support set metrics: Loss = 0.7703, accuracy = 0.6625, precision = 0.6697, recall = 0.6567, F1 score = 0.6623
# Query set metrics: Loss = 0.6693, accuracy = 0.6875, precision = 0.6433, recall = 0.6500, F1 score = 0.6411
# Query ID 159/475
# Support set metrics: Loss = 0.9053, accuracy = 0.6625, precision = 0.6658, recall = 0.6533, F1 score = 0.6556
# Query set metrics: Loss = 0.7262, accuracy = 0.6875, precision = 0.6600, recall = 0.7800, F1 score = 0.6767
# Query ID 160/475
# Support set metrics: Loss = 0.9015, accuracy = 0.6125, precision = 0.6004, recall = 0.5967, F1 score = 0.5940
# Query set metrics: Loss = 1.0105, accuracy = 0.3750, precision = 0.6571, recall = 0.4067, F1 score = 0.4394
# Query ID 161/475
# Support set metrics: Loss = 1.0049, accuracy = 0.6500, precision = 0.6582, recall = 0.6333, F1 score = 0.6393
# Query set metrics: Loss = 1.5764, accuracy = 0.3125, precision = 0.2333, recall = 0.2400, F1 score = 0.2066
# Query ID 162/475
# Support set metrics: Loss = 0.9598, accuracy = 0.5500, precision = 0.5812, recall = 0.5467, F1 score = 0.5604
# Query set metrics: Loss = 0.5814, accuracy = 0.7500, precision = 0.7333, recall = 0.7667, F1 score = 0.7000
# Query ID 163/475
# Support set metrics: Loss = 0.9170, accuracy = 0.5750, precision = 0.5779, recall = 0.5667, F1 score = 0.5697
# Query set metrics: Loss = 1.4979, accuracy = 0.5000, precision = 0.5536, recall = 0.4250, F1 score = 0.4464
# Query ID 164/475
# Support set metrics: Loss = 0.9425, accuracy = 0.6625, precision = 0.6564, recall = 0.6567, F1 score = 0.6545
# Query set metrics: Loss = 0.9771, accuracy = 0.6250, precision = 0.5600, recall = 0.5333, F1 score = 0.5056
# Query ID 165/475
# Support set metrics: Loss = 0.8274, accuracy = 0.6750, precision = 0.6804, recall = 0.6600, F1 score = 0.6650
# Query set metrics: Loss = 0.7598, accuracy = 0.6250, precision = 0.5800, recall = 0.5300, F1 score = 0.5254
# Query ID 166/475
# Support set metrics: Loss = 0.8126, accuracy = 0.7250, precision = 0.7400, recall = 0.7200, F1 score = 0.7297
# Query set metrics: Loss = 0.9443, accuracy = 0.7500, precision = 0.5600, recall = 0.6333, F1 score = 0.5873
# Query ID 167/475
# Support set metrics: Loss = 0.9181, accuracy = 0.6250, precision = 0.6222, recall = 0.6233, F1 score = 0.6212
# Query set metrics: Loss = 1.0469, accuracy = 0.5625, precision = 0.5690, recall = 0.5333, F1 score = 0.5258
# Query ID 168/475
# Support set metrics: Loss = 0.9055, accuracy = 0.6000, precision = 0.5980, recall = 0.5867, F1 score = 0.5887
# Query set metrics: Loss = 0.8956, accuracy = 0.6875, precision = 0.5267, recall = 0.6333, F1 score = 0.5587
# Query ID 169/475
# Support set metrics: Loss = 1.0171, accuracy = 0.6000, precision = 0.5928, recall = 0.5833, F1 score = 0.5848
# Query set metrics: Loss = 0.6947, accuracy = 0.8125, precision = 0.7833, recall = 0.7833, F1 score = 0.7700
# Query ID 170/475
# Support set metrics: Loss = 0.8169, accuracy = 0.6500, precision = 0.6718, recall = 0.6433, F1 score = 0.6535
# Query set metrics: Loss = 1.1822, accuracy = 0.5625, precision = 0.6500, recall = 0.5833, F1 score = 0.5643
# Query ID 171/475
# Support set metrics: Loss = 0.9270, accuracy = 0.6000, precision = 0.6040, recall = 0.5967, F1 score = 0.5952
# Query set metrics: Loss = 1.3162, accuracy = 0.3125, precision = 0.3133, recall = 0.3905, F1 score = 0.3133
# Query ID 172/475
# Support set metrics: Loss = 1.1940, accuracy = 0.5875, precision = 0.6103, recall = 0.5867, F1 score = 0.5960
# Query set metrics: Loss = 0.9714, accuracy = 0.6250, precision = 0.6167, recall = 0.5533, F1 score = 0.5556
# Query ID 173/475
# Support set metrics: Loss = 1.1967, accuracy = 0.5500, precision = 0.5749, recall = 0.5433, F1 score = 0.5560
# Query set metrics: Loss = 1.2604, accuracy = 0.5625, precision = 0.4467, recall = 0.5467, F1 score = 0.4800
# Query ID 174/475
# Support set metrics: Loss = 0.9634, accuracy = 0.5750, precision = 0.5712, recall = 0.5633, F1 score = 0.5596
# Query set metrics: Loss = 0.7129, accuracy = 0.6875, precision = 0.7000, recall = 0.7417, F1 score = 0.6553
# Query ID 175/475
# Support set metrics: Loss = 0.8687, accuracy = 0.6125, precision = 0.6081, recall = 0.6033, F1 score = 0.6008
# Query set metrics: Loss = 0.8521, accuracy = 0.5625, precision = 0.5200, recall = 0.5533, F1 score = 0.5133
# Query ID 176/475
# Support set metrics: Loss = 0.8111, accuracy = 0.7000, precision = 0.6979, recall = 0.6900, F1 score = 0.6889
# Query set metrics: Loss = 1.0040, accuracy = 0.4375, precision = 0.5000, recall = 0.3833, F1 score = 0.4071
# Query ID 177/475
# Support set metrics: Loss = 0.8129, accuracy = 0.6625, precision = 0.6650, recall = 0.6500, F1 score = 0.6567
# Query set metrics: Loss = 0.7716, accuracy = 0.6250, precision = 0.8167, recall = 0.7333, F1 score = 0.7000
# Query ID 178/475
# Support set metrics: Loss = 0.8538, accuracy = 0.6125, precision = 0.5898, recall = 0.5933, F1 score = 0.5838
# Query set metrics: Loss = 1.1714, accuracy = 0.5000, precision = 0.4429, recall = 0.5000, F1 score = 0.4667
# Query ID 179/475
# Support set metrics: Loss = 0.8317, accuracy = 0.6625, precision = 0.6577, recall = 0.6467, F1 score = 0.6499
# Query set metrics: Loss = 0.8823, accuracy = 0.4375, precision = 0.5167, recall = 0.5000, F1 score = 0.4238
# Query ID 180/475
# Support set metrics: Loss = 0.9055, accuracy = 0.6125, precision = 0.5956, recall = 0.6067, F1 score = 0.5999
# Query set metrics: Loss = 0.8566, accuracy = 0.4375, precision = 0.4524, recall = 0.4900, F1 score = 0.4238
# Query ID 181/475
# Support set metrics: Loss = 0.9633, accuracy = 0.6125, precision = 0.6147, recall = 0.6067, F1 score = 0.6093
# Query set metrics: Loss = 0.7949, accuracy = 0.6875, precision = 0.7200, recall = 0.7500, F1 score = 0.6533
# Query ID 182/475
# Support set metrics: Loss = 0.9471, accuracy = 0.5750, precision = 0.5663, recall = 0.5733, F1 score = 0.5651
# Query set metrics: Loss = 0.7958, accuracy = 0.7500, precision = 0.8033, recall = 0.8000, F1 score = 0.7481
# Query ID 183/475
# Support set metrics: Loss = 0.9219, accuracy = 0.5750, precision = 0.5692, recall = 0.5600, F1 score = 0.5609
# Query set metrics: Loss = 0.8384, accuracy = 0.6875, precision = 0.6600, recall = 0.5600, F1 score = 0.5889
# Query ID 184/475
# Support set metrics: Loss = 0.8940, accuracy = 0.6625, precision = 0.6938, recall = 0.6633, F1 score = 0.6762
# Query set metrics: Loss = 0.8143, accuracy = 0.5000, precision = 0.5667, recall = 0.5567, F1 score = 0.4833
# Query ID 185/475
# Support set metrics: Loss = 0.8239, accuracy = 0.6500, precision = 0.6449, recall = 0.6500, F1 score = 0.6434
# Query set metrics: Loss = 0.9352, accuracy = 0.6875, precision = 0.7000, recall = 0.7467, F1 score = 0.7000
# Query ID 186/475
# Support set metrics: Loss = 0.8955, accuracy = 0.6375, precision = 0.6580, recall = 0.6333, F1 score = 0.6418
# Query set metrics: Loss = 0.9185, accuracy = 0.6250, precision = 0.5500, recall = 0.6000, F1 score = 0.5190
# Query ID 187/475
# Support set metrics: Loss = 0.9416, accuracy = 0.6375, precision = 0.6580, recall = 0.6267, F1 score = 0.6364
# Query set metrics: Loss = 0.9423, accuracy = 0.5000, precision = 0.4700, recall = 0.5167, F1 score = 0.4571
# Query ID 188/475
# Support set metrics: Loss = 0.8735, accuracy = 0.6500, precision = 0.6582, recall = 0.6467, F1 score = 0.6462
# Query set metrics: Loss = 1.5409, accuracy = 0.3750, precision = 0.4267, recall = 0.3833, F1 score = 0.3276
# Query ID 189/475
# Support set metrics: Loss = 1.0431, accuracy = 0.5875, precision = 0.5715, recall = 0.5700, F1 score = 0.5679
# Query set metrics: Loss = 0.7259, accuracy = 0.7500, precision = 0.5889, recall = 0.7000, F1 score = 0.6017
# Query ID 190/475
# Support set metrics: Loss = 0.9915, accuracy = 0.6250, precision = 0.6299, recall = 0.6167, F1 score = 0.6198
# Query set metrics: Loss = 0.8820, accuracy = 0.5625, precision = 0.7125, recall = 0.5333, F1 score = 0.5669
# Query ID 191/475
# Support set metrics: Loss = 0.9218, accuracy = 0.5875, precision = 0.6075, recall = 0.5867, F1 score = 0.5954
# Query set metrics: Loss = 1.1135, accuracy = 0.5000, precision = 0.4600, recall = 0.4333, F1 score = 0.4364
# Query ID 192/475
# Support set metrics: Loss = 1.0853, accuracy = 0.5750, precision = 0.5996, recall = 0.5733, F1 score = 0.5853
# Query set metrics: Loss = 0.4771, accuracy = 0.7500, precision = 0.6778, recall = 0.6000, F1 score = 0.5882
# Query ID 193/475
# Support set metrics: Loss = 0.9961, accuracy = 0.5875, precision = 0.5727, recall = 0.5733, F1 score = 0.5674
# Query set metrics: Loss = 0.8588, accuracy = 0.6875, precision = 0.7433, recall = 0.8000, F1 score = 0.6667
# Query ID 194/475
# Support set metrics: Loss = 0.9128, accuracy = 0.6125, precision = 0.5908, recall = 0.5967, F1 score = 0.5906
# Query set metrics: Loss = 0.7704, accuracy = 0.8125, precision = 0.9333, recall = 0.7667, F1 score = 0.8133
# Query ID 195/475
# Support set metrics: Loss = 1.1531, accuracy = 0.4625, precision = 0.4599, recall = 0.4567, F1 score = 0.4555
# Query set metrics: Loss = 0.9186, accuracy = 0.6250, precision = 0.5200, recall = 0.6667, F1 score = 0.5433
# Query ID 196/475
# Support set metrics: Loss = 0.7565, accuracy = 0.6875, precision = 0.6919, recall = 0.6767, F1 score = 0.6781
# Query set metrics: Loss = 0.9698, accuracy = 0.6250, precision = 0.6292, recall = 0.6875, F1 score = 0.6292
# Query ID 197/475
# Support set metrics: Loss = 0.8798, accuracy = 0.6250, precision = 0.6408, recall = 0.6233, F1 score = 0.6298
# Query set metrics: Loss = 0.9556, accuracy = 0.6875, precision = 0.5667, recall = 0.5933, F1 score = 0.5655
# Query ID 198/475
# Support set metrics: Loss = 0.8057, accuracy = 0.6125, precision = 0.5959, recall = 0.6033, F1 score = 0.5980
# Query set metrics: Loss = 0.7950, accuracy = 0.6875, precision = 0.7333, recall = 0.7267, F1 score = 0.6721
# Query ID 199/475
# Support set metrics: Loss = 0.8363, accuracy = 0.6375, precision = 0.6217, recall = 0.6233, F1 score = 0.6219
# Query set metrics: Loss = 0.8760, accuracy = 0.7500, precision = 0.8200, recall = 0.7933, F1 score = 0.7544
# Query ID 200/475
# Support set metrics: Loss = 0.8254, accuracy = 0.6625, precision = 0.6669, recall = 0.6567, F1 score = 0.6546
# Query set metrics: Loss = 0.9446, accuracy = 0.5000, precision = 0.5333, recall = 0.5133, F1 score = 0.4810
# Query ID 201/475
# Support set metrics: Loss = 0.9033, accuracy = 0.6625, precision = 0.6842, recall = 0.6600, F1 score = 0.6655
# Query set metrics: Loss = 0.9493, accuracy = 0.4375, precision = 0.4667, recall = 0.5133, F1 score = 0.4286
# Query ID 202/475
# Support set metrics: Loss = 0.8741, accuracy = 0.6750, precision = 0.6690, recall = 0.6700, F1 score = 0.6656
# Query set metrics: Loss = 1.3545, accuracy = 0.5625, precision = 0.4500, recall = 0.5333, F1 score = 0.4733
# Query ID 203/475
# Support set metrics: Loss = 1.0367, accuracy = 0.5625, precision = 0.5871, recall = 0.5567, F1 score = 0.5706
# Query set metrics: Loss = 0.7756, accuracy = 0.7500, precision = 0.4767, recall = 0.5429, F1 score = 0.5031
# Query ID 204/475
# ...
# Query set metrics: Loss = 0.5912, accuracy = 0.7500, precision = 0.7867, recall = 0.8500, F1 score = 0.7667
# Query ID 332/475
# Support set metrics: Loss = 1.0913, accuracy = 0.5500, precision = 0.5660, recall = 0.5433, F1 score = 0.5529
# Query set metrics: Loss = 1.1479, accuracy = 0.4375, precision = 0.5500, recall = 0.5167, F1 score = 0.4238
# Query ID 333/475
# Support set metrics: Loss = 0.8630, accuracy = 0.6625, precision = 0.6621, recall = 0.6533, F1 score = 0.6573
# Query set metrics: Loss = 0.5738, accuracy = 0.7500, precision = 0.7167, recall = 0.7500, F1 score = 0.7052
# Query ID 334/475
# Support set metrics: Loss = 0.8754, accuracy = 0.6625, precision = 0.6964, recall = 0.6533, F1 score = 0.6674
# Query set metrics: Loss = 0.7504, accuracy = 0.6875, precision = 0.8000, recall = 0.7000, F1 score = 0.7026
# Query ID 335/475
# Support set metrics: Loss = 0.8259, accuracy = 0.6125, precision = 0.6111, recall = 0.6000, F1 score = 0.6037
# Query set metrics: Loss = 1.0076, accuracy = 0.5625, precision = 0.4700, recall = 0.5333, F1 score = 0.4833
# Query ID 336/475
# Support set metrics: Loss = 1.0358, accuracy = 0.5625, precision = 0.5701, recall = 0.5567, F1 score = 0.5590
# Query set metrics: Loss = 0.6270, accuracy = 0.7500, precision = 0.7667, recall = 0.7667, F1 score = 0.7333
# Query ID 337/475
# Support set metrics: Loss = 0.9421, accuracy = 0.6375, precision = 0.6546, recall = 0.6267, F1 score = 0.6386
# Query set metrics: Loss = 0.8266, accuracy = 0.6875, precision = 0.7200, recall = 0.6200, F1 score = 0.6533
# Query ID 338/475
# Support set metrics: Loss = 0.9073, accuracy = 0.5875, precision = 0.5969, recall = 0.5800, F1 score = 0.5870
# Query set metrics: Loss = 0.8596, accuracy = 0.6875, precision = 0.7300, recall = 0.8167, F1 score = 0.6905
# Query ID 339/475
# Support set metrics: Loss = 0.8799, accuracy = 0.6375, precision = 0.6681, recall = 0.6400, F1 score = 0.6456
# Query set metrics: Loss = 0.7680, accuracy = 0.8750, precision = 0.7333, recall = 0.8000, F1 score = 0.7600
# Query ID 340/475
# Support set metrics: Loss = 0.9211, accuracy = 0.5875, precision = 0.5985, recall = 0.5833, F1 score = 0.5875
# Query set metrics: Loss = 0.7383, accuracy = 0.6250, precision = 0.5000, recall = 0.4333, F1 score = 0.4476
# Query ID 341/475
# Support set metrics: Loss = 1.0080, accuracy = 0.6375, precision = 0.6424, recall = 0.6400, F1 score = 0.6387
# Query set metrics: Loss = 1.0201, accuracy = 0.6875, precision = 0.7933, recall = 0.7000, F1 score = 0.7244
# Query ID 342/475
# Support set metrics: Loss = 0.8840, accuracy = 0.6000, precision = 0.5827, recall = 0.5867, F1 score = 0.5828
# Query set metrics: Loss = 1.1003, accuracy = 0.4375, precision = 0.6714, recall = 0.4542, F1 score = 0.4540
# Query ID 343/475
# Support set metrics: Loss = 0.9521, accuracy = 0.5625, precision = 0.5515, recall = 0.5600, F1 score = 0.5518
# Query set metrics: Loss = 0.7354, accuracy = 0.5625, precision = 0.4500, recall = 0.5833, F1 score = 0.4610
# Query ID 344/475
# Support set metrics: Loss = 0.7957, accuracy = 0.7125, precision = 0.7385, recall = 0.7167, F1 score = 0.7247
# Query set metrics: Loss = 1.3874, accuracy = 0.3750, precision = 0.4400, recall = 0.4000, F1 score = 0.3927
# Query ID 345/475
# Support set metrics: Loss = 0.9643, accuracy = 0.6250, precision = 0.6567, recall = 0.6200, F1 score = 0.6295
# Query set metrics: Loss = 0.9073, accuracy = 0.5000, precision = 0.6067, recall = 0.6400, F1 score = 0.5167
# Query ID 346/475
# Support set metrics: Loss = 1.0519, accuracy = 0.5375, precision = 0.5455, recall = 0.5367, F1 score = 0.5402
# Query set metrics: Loss = 0.8565, accuracy = 0.6875, precision = 0.6667, recall = 0.7000, F1 score = 0.6743
# Query ID 347/475
# Support set metrics: Loss = 1.0533, accuracy = 0.5750, precision = 0.5768, recall = 0.5700, F1 score = 0.5713
# Query set metrics: Loss = 0.9823, accuracy = 0.5625, precision = 0.4967, recall = 0.5533, F1 score = 0.5014
# Query ID 348/475
# Support set metrics: Loss = 0.9391, accuracy = 0.5500, precision = 0.5711, recall = 0.5433, F1 score = 0.5530
# Query set metrics: Loss = 0.7068, accuracy = 0.8125, precision = 0.7500, recall = 0.6933, F1 score = 0.7092
# Query ID 349/475
# Support set metrics: Loss = 0.8920, accuracy = 0.6625, precision = 0.6915, recall = 0.6533, F1 score = 0.6713
# Query set metrics: Loss = 0.8110, accuracy = 0.6875, precision = 0.7200, recall = 0.6500, F1 score = 0.6467
# Query ID 350/475
# Support set metrics: Loss = 0.9205, accuracy = 0.6000, precision = 0.6094, recall = 0.5933, F1 score = 0.5951
# Query set metrics: Loss = 1.0219, accuracy = 0.5625, precision = 0.5667, recall = 0.6667, F1 score = 0.5333
# Query ID 351/475
# Support set metrics: Loss = 0.9874, accuracy = 0.6125, precision = 0.6027, recall = 0.6100, F1 score = 0.5999
# Query set metrics: Loss = 1.1214, accuracy = 0.6250, precision = 0.6800, recall = 0.6190, F1 score = 0.6200
# Query ID 352/475
# Support set metrics: Loss = 0.9512, accuracy = 0.5875, precision = 0.5874, recall = 0.5733, F1 score = 0.5759
# Query set metrics: Loss = 0.6870, accuracy = 0.7500, precision = 0.7381, recall = 0.7714, F1 score = 0.7124
# Query ID 353/475
# Support set metrics: Loss = 0.9564, accuracy = 0.5750, precision = 0.5802, recall = 0.5733, F1 score = 0.5754
# Query set metrics: Loss = 1.3969, accuracy = 0.3750, precision = 0.4300, recall = 0.2667, F1 score = 0.3089
# Query ID 354/475
# Support set metrics: Loss = 1.0781, accuracy = 0.5500, precision = 0.5857, recall = 0.5467, F1 score = 0.5522
# Query set metrics: Loss = 0.8561, accuracy = 0.5625, precision = 0.5833, recall = 0.6300, F1 score = 0.5443
# Query ID 355/475
# Support set metrics: Loss = 1.0475, accuracy = 0.6000, precision = 0.5835, recall = 0.5900, F1 score = 0.5823
# Query set metrics: Loss = 0.6584, accuracy = 0.8125, precision = 0.8600, recall = 0.8333, F1 score = 0.8378
# Query ID 356/475
# Support set metrics: Loss = 0.9658, accuracy = 0.5875, precision = 0.5790, recall = 0.5700, F1 score = 0.5704
# Query set metrics: Loss = 0.8671, accuracy = 0.5625, precision = 0.4667, recall = 0.4433, F1 score = 0.4444
# Query ID 357/475
# Support set metrics: Loss = 0.8371, accuracy = 0.6000, precision = 0.5772, recall = 0.5900, F1 score = 0.5764
# Query set metrics: Loss = 0.6183, accuracy = 0.8125, precision = 0.7750, recall = 0.8375, F1 score = 0.7708
# Query ID 358/475
# Support set metrics: Loss = 1.0530, accuracy = 0.5875, precision = 0.5924, recall = 0.5800, F1 score = 0.5837
# Query set metrics: Loss = 0.7497, accuracy = 0.7500, precision = 0.7833, recall = 0.8333, F1 score = 0.7333
# Query ID 359/475
# Support set metrics: Loss = 0.9939, accuracy = 0.5750, precision = 0.6057, recall = 0.5733, F1 score = 0.5869
# Query set metrics: Loss = 0.9215, accuracy = 0.5625, precision = 0.6200, recall = 0.5667, F1 score = 0.5643
# Query ID 360/475
# Support set metrics: Loss = 0.9606, accuracy = 0.6000, precision = 0.6457, recall = 0.6000, F1 score = 0.6205
# Query set metrics: Loss = 0.5196, accuracy = 0.7500, precision = 0.6267, recall = 0.6267, F1 score = 0.6267
# Query ID 361/475
# Support set metrics: Loss = 0.9700, accuracy = 0.5500, precision = 0.5733, recall = 0.5367, F1 score = 0.5471
# Query set metrics: Loss = 0.7542, accuracy = 0.7500, precision = 0.6600, recall = 0.6933, F1 score = 0.6489
# Query ID 362/475
# Support set metrics: Loss = 0.7986, accuracy = 0.6000, precision = 0.5930, recall = 0.5833, F1 score = 0.5868
# Query set metrics: Loss = 0.9436, accuracy = 0.3125, precision = 0.4000, recall = 0.2800, F1 score = 0.3203
# Query ID 363/475
# Support set metrics: Loss = 0.8468, accuracy = 0.6875, precision = 0.6944, recall = 0.6900, F1 score = 0.6859
# Query set metrics: Loss = 0.8625, accuracy = 0.6875, precision = 0.7167, recall = 0.7033, F1 score = 0.6781
# Query ID 364/475
# Support set metrics: Loss = 0.8966, accuracy = 0.6500, precision = 0.6599, recall = 0.6433, F1 score = 0.6511
# Query set metrics: Loss = 1.0019, accuracy = 0.6250, precision = 0.6286, recall = 0.5119, F1 score = 0.5258
# Query ID 365/475
# Support set metrics: Loss = 1.1902, accuracy = 0.5125, precision = 0.5202, recall = 0.5067, F1 score = 0.5108
# Query set metrics: Loss = 1.1926, accuracy = 0.5000, precision = 0.5833, recall = 0.4333, F1 score = 0.4586
# Query ID 366/475
# Support set metrics: Loss = 1.1338, accuracy = 0.5375, precision = 0.5435, recall = 0.5300, F1 score = 0.5363
# Query set metrics: Loss = 0.7648, accuracy = 0.6875, precision = 0.7000, recall = 0.7033, F1 score = 0.6967
# Query ID 367/475
# Support set metrics: Loss = 0.9012, accuracy = 0.6125, precision = 0.5987, recall = 0.6000, F1 score = 0.5979
# Query set metrics: Loss = 0.7927, accuracy = 0.6875, precision = 0.5667, recall = 0.7200, F1 score = 0.6166
# Query ID 368/475
# Support set metrics: Loss = 0.9657, accuracy = 0.5500, precision = 0.5469, recall = 0.5400, F1 score = 0.5419
# Query set metrics: Loss = 1.1090, accuracy = 0.6250, precision = 0.5667, recall = 0.5667, F1 score = 0.5561
# Query ID 369/475
# Support set metrics: Loss = 0.9458, accuracy = 0.6125, precision = 0.6300, recall = 0.6033, F1 score = 0.6151
# Query set metrics: Loss = 0.7446, accuracy = 0.6875, precision = 0.7000, recall = 0.7429, F1 score = 0.6476
# Query ID 370/475
# Support set metrics: Loss = 0.8120, accuracy = 0.6125, precision = 0.6187, recall = 0.6100, F1 score = 0.6118
# Query set metrics: Loss = 1.1134, accuracy = 0.5000, precision = 0.4917, recall = 0.4762, F1 score = 0.4762
# Query ID 371/475
# Support set metrics: Loss = 0.9593, accuracy = 0.6375, precision = 0.6278, recall = 0.6300, F1 score = 0.6259
# Query set metrics: Loss = 0.7564, accuracy = 0.6250, precision = 0.7036, recall = 0.5833, F1 score = 0.5833
# Query ID 372/475
# Support set metrics: Loss = 0.9502, accuracy = 0.6125, precision = 0.6044, recall = 0.6033, F1 score = 0.6031
# Query set metrics: Loss = 1.0081, accuracy = 0.5625, precision = 0.5500, recall = 0.5000, F1 score = 0.5200
# Query ID 373/475
# Support set metrics: Loss = 0.9701, accuracy = 0.5375, precision = 0.5414, recall = 0.5300, F1 score = 0.5341
# Query set metrics: Loss = 1.4141, accuracy = 0.3125, precision = 0.5500, recall = 0.3233, F1 score = 0.3643
# Query ID 374/475
# Support set metrics: Loss = 1.0505, accuracy = 0.5875, precision = 0.5949, recall = 0.5733, F1 score = 0.5826
# Query set metrics: Loss = 0.6811, accuracy = 0.5625, precision = 0.5000, recall = 0.4500, F1 score = 0.4381
# Query ID 375/475
# Support set metrics: Loss = 0.8413, accuracy = 0.6125, precision = 0.6037, recall = 0.6033, F1 score = 0.6006
# Query set metrics: Loss = 0.9166, accuracy = 0.5000, precision = 0.5733, recall = 0.6333, F1 score = 0.4800
# Query ID 376/475
# Support set metrics: Loss = 0.8466, accuracy = 0.6750, precision = 0.6728, recall = 0.6700, F1 score = 0.6680
# Query set metrics: Loss = 1.2770, accuracy = 0.4375, precision = 0.3967, recall = 0.4667, F1 score = 0.4010
# Query ID 377/475
# Support set metrics: Loss = 0.7487, accuracy = 0.7375, precision = 0.7417, recall = 0.7300, F1 score = 0.7319
# Query set metrics: Loss = 0.9047, accuracy = 0.5000, precision = 0.4000, recall = 0.4100, F1 score = 0.4026
# Query ID 378/475
# Support set metrics: Loss = 0.9872, accuracy = 0.5750, precision = 0.5412, recall = 0.5533, F1 score = 0.5465
# Query set metrics: Loss = 0.8035, accuracy = 0.4375, precision = 0.4167, recall = 0.3750, F1 score = 0.3833
# Query ID 379/475
# Support set metrics: Loss = 0.8068, accuracy = 0.6000, precision = 0.5985, recall = 0.5867, F1 score = 0.5893
# Query set metrics: Loss = 0.7453, accuracy = 0.6875, precision = 0.6933, recall = 0.7267, F1 score = 0.6676
# Query ID 380/475
# Support set metrics: Loss = 0.9767, accuracy = 0.5875, precision = 0.5860, recall = 0.5767, F1 score = 0.5808
# Query set metrics: Loss = 1.1049, accuracy = 0.5625, precision = 0.6833, recall = 0.5867, F1 score = 0.5933
# Query ID 381/475
# Support set metrics: Loss = 0.8306, accuracy = 0.7000, precision = 0.7310, recall = 0.6967, F1 score = 0.7116
# Query set metrics: Loss = 0.8395, accuracy = 0.7500, precision = 0.7933, recall = 0.7600, F1 score = 0.7676
# Query ID 382/475
# Support set metrics: Loss = 0.9165, accuracy = 0.6875, precision = 0.6951, recall = 0.6867, F1 score = 0.6893
# Query set metrics: Loss = 0.5665, accuracy = 0.7500, precision = 0.8100, recall = 0.7533, F1 score = 0.7587
# Query ID 383/475
# Support set metrics: Loss = 1.0322, accuracy = 0.6125, precision = 0.6100, recall = 0.6033, F1 score = 0.6035
# Query set metrics: Loss = 0.8198, accuracy = 0.5625, precision = 0.7417, recall = 0.6964, F1 score = 0.5714
# Query ID 384/475
# Support set metrics: Loss = 0.9688, accuracy = 0.5750, precision = 0.5923, recall = 0.5667, F1 score = 0.5759
# Query set metrics: Loss = 0.6981, accuracy = 0.7500, precision = 0.6500, recall = 0.6500, F1 score = 0.6500
# Query ID 385/475
# Support set metrics: Loss = 0.9792, accuracy = 0.5625, precision = 0.5593, recall = 0.5467, F1 score = 0.5506
# Query set metrics: Loss = 0.9094, accuracy = 0.7500, precision = 0.5933, recall = 0.6533, F1 score = 0.6121
# Query ID 386/475
# Support set metrics: Loss = 0.8662, accuracy = 0.7000, precision = 0.7310, recall = 0.7000, F1 score = 0.7139
# Query set metrics: Loss = 1.0037, accuracy = 0.5000, precision = 0.5800, recall = 0.5133, F1 score = 0.5032
# Query ID 387/475
# Support set metrics: Loss = 0.9853, accuracy = 0.7000, precision = 0.7187, recall = 0.7000, F1 score = 0.7066
# Query set metrics: Loss = 1.5303, accuracy = 0.5000, precision = 0.5167, recall = 0.4524, F1 score = 0.4514
# Query ID 388/475
# Support set metrics: Loss = 1.1670, accuracy = 0.5625, precision = 0.5991, recall = 0.5567, F1 score = 0.5702
# Query set metrics: Loss = 0.6792, accuracy = 0.7500, precision = 0.7933, recall = 0.7667, F1 score = 0.7378
# Query ID 389/475
# Support set metrics: Loss = 0.9831, accuracy = 0.6000, precision = 0.6119, recall = 0.5867, F1 score = 0.5968
# Query set metrics: Loss = 1.0246, accuracy = 0.5000, precision = 0.4933, recall = 0.5667, F1 score = 0.4310
# Query ID 390/475
# Support set metrics: Loss = 0.8303, accuracy = 0.6500, precision = 0.6321, recall = 0.6433, F1 score = 0.6358
# Query set metrics: Loss = 0.4827, accuracy = 0.8750, precision = 0.8667, recall = 0.9167, F1 score = 0.8532
# Query ID 391/475
# Support set metrics: Loss = 0.8659, accuracy = 0.6125, precision = 0.6147, recall = 0.6033, F1 score = 0.6070
# Query set metrics: Loss = 0.6515, accuracy = 0.8125, precision = 0.8333, recall = 0.8500, F1 score = 0.8190
# Query ID 392/475
# Support set metrics: Loss = 0.8949, accuracy = 0.5750, precision = 0.5804, recall = 0.5700, F1 score = 0.5713
# Query set metrics: Loss = 1.1824, accuracy = 0.5625, precision = 0.5600, recall = 0.4667, F1 score = 0.4959
# Query ID 393/475
# Support set metrics: Loss = 1.0260, accuracy = 0.5375, precision = 0.5377, recall = 0.5267, F1 score = 0.5309
# Query set metrics: Loss = 1.0230, accuracy = 0.5000, precision = 0.6250, recall = 0.5833, F1 score = 0.5825
# Query ID 394/475
# Support set metrics: Loss = 0.9435, accuracy = 0.6250, precision = 0.6095, recall = 0.6100, F1 score = 0.6069
# Query set metrics: Loss = 1.0131, accuracy = 0.5625, precision = 0.6000, recall = 0.6133, F1 score = 0.5610
# Query ID 395/475
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8715/3575811196.py in <module>
#      11                                       collate_fn=datasets.utils.batch_encode)
#      12     acc, prec, rec, f1, all_pred, all_label, all_label_conf = evaluate(dataloader=test_dataloader, updates=updates,
# ---> 13                                                                        mini_batch_size=mini_batch_size)
#      14
#      15     data_ids = [test_dataset.__class__.__name__ + str(i) for i in range(len(all_label))]
#
# /tmp/ipykernel_8715/3258089022.py in evaluate(dataloader, updates, mini_batch_size)
#      30                 diffopt.step(loss)
#      31                 pred = models.utils.make_prediction(output.detach())
# ---> 32                 support_loss.append(loss.item())
#      33                 task_predictions.extend(pred.tolist())
#      34                 task_labels.extend(labels.tolist())
#
# KeyboardInterrupt:

# %%
_model_path0 = os.path.splitext(model_path)[0]
csv_filename = _model_path0 + "_update"+ str(updates) +"_results_sr_ta2.csv" # for selective replay
with open(csv_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["data_idx", "label", "label_conf", "pred"])
    csv_writer.writerows(data_for_visual)
print(f"Done writing CSV File at {csv_filename}")

# %%
# Log Time for Inference
_model_path0 = os.path.splitext(model_path)[0]
time_txt_filename = _model_path0 + "_update"+ str(updates) +"_time_inference_sr_ta2.csv" 
with open(time_txt_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["time_id", "time"])
    csv_writer.writerow(["Total Time", f"{toc//60} minutes"])
    csv_writer.writerow(["mean Adapt Time", f"{np.mean(all_adapt_time)} s"])
print(f"Done writing Time CSV File at {time_txt_filename}")
