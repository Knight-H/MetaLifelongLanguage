# %%
import random, gc, os, pickle, csv, time

import datasets.utils
import models.utils
from models.cls_oml_ori_v2 import OML
from models.base_models_ori import LabelAwareReplayMemory

import numpy as np
import matplotlib.pyplot as plt

import higher
import torch
import torch.nn.functional as F
from torch.utils import data

# %% [markdown]
# # Constants

# %%
dataset_order_mapping = {
    1: [2, 0, 3, 1, 4],
    2: [3, 4, 0, 1, 2],
    3: [2, 4, 1, 3, 0],
    4: [0, 2, 1, 4, 3]
}
n_classes = 33
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
# model_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518612.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456804.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477968.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869765.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241546.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424113.pt"
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167637.pt"

# v. SR 
# model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695669.pt"
# v. SR Query
model_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228.pt"

# memory_path = "/data/model_runs/original_oml/aOML-order1-2022-07-18/OML-order1-id4-2022-07-18_17-53-13.518639_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr002-2022-07-31/OML-order1-id4-2022-07-31_14-53-46.456828_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-2022-07-31/OML-order1-id4-2022-07-31_18-47-41.477992_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr005-up20-2022-08-01/OML-order1-id4-2022-08-01_14-45-55.869797_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-07-31/OML-order1-id4-2022-07-31_21-18-36.241572_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr020-2022-08-16/OML-order1-id4-2022-08-16_11-37-19.424139_memory.pickle"
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr050-2022-08-16/OML-order1-id4-2022-08-16_14-16-12.167666_memory.pickle"
# v. SR 
# memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-29-sr/OML-order1-id4-2022-08-29_18-10-31.695692_memory.pickle"
# v. SR Query
memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854254_memory.pickle"

# For Sample Score
TRIM_ER = 500
TOTAL_EPOCH = 600
# new_memory_path, ext = os.path.splitext(memory_path)
# new_memory_path = new_memory_path + "_label" + ext

use_db_cache = True
cache_dir = 'tmp'

# %%
args = {
    "order": 1,
    "n_epochs": 1,
    "lr": 3e-5,
    "inner_lr": 0.001*10,
    "meta_lr": 3e-5,
    "model": "bert",
    "learner": "oml",
    "mini_batch_size": 16,
    "updates": 5*1,
    "write_prob": 1.0,
    "max_length": 448,
    "seed": 42,
    "replay_rate": 0.01,
    "replay_every": 9600
}
updates = args["updates"]
mini_batch_size = args["mini_batch_size"]
order = args["order"]

# %%
torch.manual_seed(args["seed"])
random.seed(args["seed"])
np.random.seed(args["seed"])

# %% [markdown]
# # Load Dataset

# %%
print('Loading the datasets')
test_datasets = []
for dataset_id in dataset_order_mapping[order]:
    test_dataset_file = os.path.join(cache_dir, f"{dataset_id}.cache")
    if os.path.exists(test_dataset_file):
        with open(test_dataset_file, 'rb') as f:
            test_dataset = pickle.load(f)
    else:
        test_dataset = datasets.utils.get_dataset_test("", dataset_id)
        print('Loaded {}'.format(test_dataset.__class__.__name__))
        test_dataset = datasets.utils.offset_labels(test_dataset)
        pickle.dump(test_dataset, open( test_dataset_file, "wb" ), protocol=pickle.HIGHEST_PROTOCOL)
        print(f"Pickle saved at {test_dataset_file}")
    test_datasets.append(test_dataset)
print('Finished loading all the datasets')
# Out:
# Loading the datasets
# Finished loading all the datasets

# %% [markdown]
# # Load Model

# %%
learner = OML(device=device, n_classes=n_classes, **args)
print('Using {} as learner'.format(learner.__class__.__name__))
learner.load_model(model_path)
with open(memory_path, 'rb') as f:
#     learner.memory = pickle.load(f)
    memory_buffer = pickle.load(f)
# Out:
# 2022-11-28 20:20:55,826 - transformers.tokenization_utils_base - INFO - loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 2022-11-28 20:20:57,074 - transformers.configuration_utils - INFO - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2022-11-28 20:20:57,077 - transformers.configuration_utils - INFO - Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2022-11-28 20:20:57,166 - transformers.modeling_utils - INFO - loading weights file https://cdn.huggingface.co/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/f2ee78bdd635b758cc0a12352586868bef80e47401abe4c4fcc3832421e7338b.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 2022-11-28 20:20:59,877 - transformers.modeling_utils - INFO - All model checkpoint weights were used when initializing BertModel.
#
# 2022-11-28 20:20:59,880 - transformers.modeling_utils - INFO - All the weights of BertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use BertModel for predictions without further training.
# 2022-11-28 20:21:03,839 - OML-Log - INFO - Loaded TransformerRLN as RLN
# 2022-11-28 20:21:03,841 - OML-Log - INFO - Loaded LinearPLN as PLN
# Using OML as learner

# %%
# Setting up task dict for task-aware
memory_buffer.task_dict = {
    0: list(range(5, 9)), # AG
    1: list(range(0, 5)), # Amazon
    2: list(range(0, 5)), # Yelp
    3: list(range(9, 23)), # DBPedia
    4: list(range(23, 33)), # Yahoo
}

# %%
# label to task converter - hack, since normally we would just use the task token/identifier
def get_task_from_label(label_idx, task_dict):
    for task_idx, class_list in task_dict.items():
        if label_idx in class_list: return task_idx
    return -1
print(get_task_from_label(8, memory_buffer.task_dict))
# Find mode: https://stackoverflow.com/questions/10797819/finding-the-mode-of-a-list
def mode(array):
    return max(array, key = array.count)
# label list to task id
def get_task_from_label_list(label_list, task_dict):
    return mode([get_task_from_label(label, task_dict) for label in label_list])
print(get_task_from_label_list([1,2,32,1,4,2,0], memory_buffer.task_dict))
# Out:
# 0
# 1

# %%
dataclass_mapper = {
    "AGNewsDataset": 0,
    "AmazonDataset": 1,
    "YelpDataset": 2,
    "DBPediaDataset": 3,
    "YahooAnswersDataset": 4
}
dataclass_mapper["AGNewsDataset"]
# Out:
# 0

# %%
# Trim buffer dict to 1000 per class
memory_buffer.meta_length = 4
memory_buffer.reset_meta()
memory_buffer.trim_buffer_dict(limit_n=TRIM_ER)

# %%
len(memory_buffer.buffer_dict[0])
# Out:
# 500

# %% [markdown]
# # Get Scores for each sample in ER

# %%
# Returns loss,preds,labels, labels_conf
def validate(fpln, validation_set):
    all_valid_preds, all_valid_labels, all_valid_label_conf = [], [], []
    
    for valid_text, valid_labels, _ in validation_set:        
        valid_labels = torch.tensor(valid_labels).to(device)
        valid_input_dict = learner.rln.encode_text(valid_text)
        valid_repr = learner.rln(valid_input_dict)
        valid_output = fpln(valid_repr) # Output has size of torch.Size([16, 33]) [BATCH, CLASSES]
        valid_loss = learner.loss_fn(valid_output, valid_labels)
        valid_loss = valid_loss.item()

        # output.detach().max(-1) max on each Batch, which will return [0] max, [1] indices
        valid_output_softmax = F.softmax(valid_output, -1)
        valid_label_conf = valid_output_softmax[np.arange(len(valid_output_softmax)), valid_labels] # Select labels in the softmax of 33 classes

        valid_pred = models.utils.make_prediction(valid_output.detach())
        
        
        # Put in things to return
        # all_valid_losses.extend(valid_loss)
        all_valid_preds.extend(valid_pred.tolist())
        all_valid_labels.extend(valid_labels.tolist())
        all_valid_label_conf.extend(valid_label_conf.tolist())
    return all_valid_preds, all_valid_labels, all_valid_label_conf # removed loss, since no need

# Compare diff results between the unadapted vs adapted
# Returns Dictionary of class_idx -> [ a - n, ...  ] for each i (300). Can np.sum() or np.mean() later
# validate_labels = The labels (Shared)
# validate_label_conf_0 = The label conf of validate_0
# validate_label_conf_n = The label conf of validate_n
def calculate_diff_class(validate_labels, validate_label_conf_0, validate_label_conf_n, initial_dict={}, return_dict=True): 
    # Adapted confs - NonAdapted Confs (a-n)
    validate_label_conf_diff = np.array(validate_label_conf_n) - np.array(validate_label_conf_0)
    
    if return_dict:
        # The dictionary to return  class_idx -> [ a - n, ...  ] 
        return_dict = initial_dict.copy()
        for i, class_idx in enumerate(validate_labels):
            # Filter conf_diff by class
            return_dict[class_idx] = return_dict.get(class_idx, []) + [validate_label_conf_diff[i]]
        return return_dict
    
    return validate_label_conf_diff

# %% [markdown]
# Every Task, we do `16*1 = 16` batch , there are 5 tasks so `16*5 = 80` per epoch (takes around 0.2s per task ~1s). So we need to do it 300 times so that it will be ~5 minutes (300s) and it means `80*300 = 24,000`, and hopefully support will be around  `16*300/300 ~ 16` per sample.
#
# ```
# Adapt Time: 0.165510892868042 s
# Support set metrics: Loss = 0.3509, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# ```
#
# ```
# For 600 Epoch
# Total Scoring Time: 29.0 m
# ```

# %%
TIC_score = time.time()
for epoch in range(TOTAL_EPOCH):
    print(f"This is epoch {epoch}/{TOTAL_EPOCH}")
    learner.rln.eval()
    learner.pln.train()
    
    for task_idx in memory_buffer.task_dict.keys():
        support_set = []
        #for _ in range(updates):
        for _ in range(1): # CHANGE THIS to 1 minibatch.
            text, labels, indexes = memory_buffer.read_batch_task(batch_size=mini_batch_size, task_idx=task_idx, \
                                                                  with_index=True)
            support_set.append((text, labels, indexes))
        
        with higher.innerloop_ctx(learner.pln, learner.inner_optimizer,
                                  copy_initial_weights=False, track_higher_grads=False) as (fpln, diffopt):
            
            # Test validation_set BEFORE the update (update=0)
            with torch.no_grad():
                all_valid_preds_0, all_valid_labels_0, all_valid_label_conf_0  = validate(fpln, support_set)
            
            INNER_tic = time.time()
            # Inner loop
            task_predictions, task_labels, task_indexes = [], [], []
            support_loss = []
            for text, labels, indexes in support_set:
                labels = torch.tensor(labels).to(device)
                input_dict = learner.rln.encode_text(text)
                _repr = learner.rln(input_dict)
                output = fpln(_repr)
                loss = learner.loss_fn(output, labels)
                diffopt.step(loss)
                pred = models.utils.make_prediction(output.detach())
                support_loss.append(loss.item())
                task_predictions.extend(pred.tolist())
                task_labels.extend(labels.tolist())
                task_indexes.extend(indexes)
            INNER_toc = time.time() - INNER_tic
            print("Adapt Time: "+ str(INNER_toc) +" s" )
            
            # Test validation_set AFTER ALL the update
            with torch.no_grad():
                all_valid_preds_n, all_valid_labels_n, all_valid_label_conf_n = validate(fpln, support_set)
                diff_list = calculate_diff_class(all_valid_labels_0, all_valid_label_conf_0, all_valid_label_conf_n, return_dict=False)
                memory_buffer.update_meta(all_valid_labels_0, task_indexes, \
                                          np.array(all_valid_label_conf_0), np.array(all_valid_label_conf_n), diff_list)

            acc, prec, rec, f1 = models.utils.calculate_metrics(task_predictions, task_labels)

            print('Support set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                        'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(support_loss), acc, prec, rec, f1))

TOC_score = time.time() - TIC_score 
print("Total Scoring Time: "+ str(TOC_score//60) +" m" )
# Out:
# This is epoch 0/600
# Adapt Time: 0.1683790683746338 s
# Support set metrics: Loss = 0.2438, accuracy = 0.8125, precision = 0.8375, recall = 0.8125, F1 score = 0.8185
# Adapt Time: 0.20820999145507812 s
# Support set metrics: Loss = 1.0968, accuracy = 0.5625, precision = 0.6333, recall = 0.5667, F1 score = 0.5571
# Adapt Time: 0.19322800636291504 s
# Support set metrics: Loss = 1.0571, accuracy = 0.6250, precision = 0.6700, recall = 0.6167, F1 score = 0.6048
# Adapt Time: 0.17128252983093262 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2116405963897705 s
# Support set metrics: Loss = 0.7671, accuracy = 0.7500, precision = 0.6167, recall = 0.7000, F1 score = 0.6300
# This is epoch 1/600
# Adapt Time: 0.16647052764892578 s
# Support set metrics: Loss = 0.2433, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19341707229614258 s
# Support set metrics: Loss = 1.2023, accuracy = 0.4375, precision = 0.4167, recall = 0.4500, F1 score = 0.4229
# Adapt Time: 0.19916701316833496 s
# Support set metrics: Loss = 1.3557, accuracy = 0.3750, precision = 0.3200, recall = 0.3833, F1 score = 0.3310
# Adapt Time: 0.17897462844848633 s
# Support set metrics: Loss = 0.0050, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19350886344909668 s
# Support set metrics: Loss = 1.0851, accuracy = 0.7500, precision = 0.6000, recall = 0.6500, F1 score = 0.5967
# This is epoch 2/600
# Adapt Time: 0.16549324989318848 s
# Support set metrics: Loss = 0.1540, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.18926119804382324 s
# Support set metrics: Loss = 0.9678, accuracy = 0.6250, precision = 0.6000, recall = 0.6000, F1 score = 0.5886
# Adapt Time: 0.2051539421081543 s
# Support set metrics: Loss = 0.6066, accuracy = 0.6875, precision = 0.7500, recall = 0.6833, F1 score = 0.6562
# Adapt Time: 0.17626953125 s
# Support set metrics: Loss = 0.5695, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.21506166458129883 s
# Support set metrics: Loss = 0.6704, accuracy = 0.7500, precision = 0.6333, recall = 0.7500, F1 score = 0.6767
# This is epoch 3/600
# Adapt Time: 0.16533184051513672 s
# Support set metrics: Loss = 0.2611, accuracy = 0.8125, precision = 0.8375, recall = 0.8125, F1 score = 0.8185
# Adapt Time: 0.17954468727111816 s
# Support set metrics: Loss = 0.7385, accuracy = 0.7500, precision = 0.8400, recall = 0.7500, F1 score = 0.7314
# Adapt Time: 0.20059776306152344 s
# Support set metrics: Loss = 1.1451, accuracy = 0.4375, precision = 0.4500, recall = 0.4500, F1 score = 0.4381
# Adapt Time: 0.16908478736877441 s
# Support set metrics: Loss = 0.5505, accuracy = 0.8750, precision = 0.8571, recall = 0.9286, F1 score = 0.8810
# Adapt Time: 0.19490575790405273 s
# Support set metrics: Loss = 0.4441, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8967
# This is epoch 4/600
# Adapt Time: 0.16572117805480957 s
# Support set metrics: Loss = 0.6196, accuracy = 0.8750, precision = 0.9375, recall = 0.8750, F1 score = 0.9018
# Adapt Time: 0.1993391513824463 s
# Support set metrics: Loss = 1.2164, accuracy = 0.5625, precision = 0.6333, recall = 0.5667, F1 score = 0.5886
# Adapt Time: 0.19236373901367188 s
# Support set metrics: Loss = 0.6547, accuracy = 0.6875, precision = 0.7700, recall = 0.6833, F1 score = 0.6743
# Adapt Time: 0.1691451072692871 s
# Support set metrics: Loss = 0.0058, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20916271209716797 s
# Support set metrics: Loss = 0.7187, accuracy = 0.7500, precision = 0.6500, recall = 0.7000, F1 score = 0.6533
# This is epoch 5/600
# Adapt Time: 0.16640925407409668 s
# Support set metrics: Loss = 0.0803, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2011253833770752 s
# Support set metrics: Loss = 1.1292, accuracy = 0.4375, precision = 0.4333, recall = 0.4167, F1 score = 0.4205
# Adapt Time: 0.20513343811035156 s
# Support set metrics: Loss = 0.8094, accuracy = 0.6250, precision = 0.6500, recall = 0.6167, F1 score = 0.6114
# Adapt Time: 0.17248940467834473 s
# Support set metrics: Loss = 0.0064, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1985635757446289 s
# Support set metrics: Loss = 0.4486, accuracy = 0.8750, precision = 0.7500, recall = 0.8000, F1 score = 0.7667
# This is epoch 6/600
# Adapt Time: 0.1639423370361328 s
# Support set metrics: Loss = 0.1838, accuracy = 0.9375, precision = 1.0000, recall = 0.9375, F1 score = 0.9643
# Adapt Time: 0.19247174263000488 s
# Support set metrics: Loss = 0.8782, accuracy = 0.5625, precision = 0.5667, recall = 0.5333, F1 score = 0.5467
# Adapt Time: 0.19933652877807617 s
# Support set metrics: Loss = 0.9019, accuracy = 0.6875, precision = 0.7167, recall = 0.6833, F1 score = 0.6895
# Adapt Time: 0.17881345748901367 s
# Support set metrics: Loss = 0.4334, accuracy = 0.8750, precision = 0.9286, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.20602154731750488 s
# Support set metrics: Loss = 0.6489, accuracy = 0.7500, precision = 0.6500, recall = 0.7000, F1 score = 0.6567
# This is epoch 7/600
# Adapt Time: 0.16451406478881836 s
# Support set metrics: Loss = 0.2831, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.17791342735290527 s
# Support set metrics: Loss = 1.4472, accuracy = 0.3125, precision = 0.2333, recall = 0.3000, F1 score = 0.2556
# Adapt Time: 0.2309119701385498 s
# Support set metrics: Loss = 0.5823, accuracy = 0.8750, precision = 0.9100, recall = 0.8667, F1 score = 0.8492
# Adapt Time: 0.1697690486907959 s
# Support set metrics: Loss = 0.0202, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19329094886779785 s
# Support set metrics: Loss = 1.2513, accuracy = 0.6875, precision = 0.6400, recall = 0.6500, F1 score = 0.6238
# This is epoch 8/600
# Adapt Time: 0.17084288597106934 s
# Support set metrics: Loss = 0.1733, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20091605186462402 s
# Support set metrics: Loss = 1.0935, accuracy = 0.5625, precision = 0.5833, recall = 0.5667, F1 score = 0.5714
# Adapt Time: 0.1979837417602539 s
# Support set metrics: Loss = 0.7640, accuracy = 0.6250, precision = 0.5933, recall = 0.6000, F1 score = 0.5911
# Adapt Time: 0.1796560287475586 s
# Support set metrics: Loss = 0.0907, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.20703864097595215 s
# Support set metrics: Loss = 0.6381, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7500
# This is epoch 9/600
# Adapt Time: 0.16591668128967285 s
# Support set metrics: Loss = 0.2284, accuracy = 0.8125, precision = 0.8667, recall = 0.8125, F1 score = 0.8032
# Adapt Time: 0.21292781829833984 s
# Support set metrics: Loss = 0.6567, accuracy = 0.8125, precision = 0.8267, recall = 0.8000, F1 score = 0.8044
# Adapt Time: 0.2135930061340332 s
# Support set metrics: Loss = 1.0561, accuracy = 0.6875, precision = 0.7533, recall = 0.6833, F1 score = 0.7067
# Adapt Time: 0.1726362705230713 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18986129760742188 s
# Support set metrics: Loss = 0.9353, accuracy = 0.7500, precision = 0.7667, recall = 0.7500, F1 score = 0.7100
# This is epoch 10/600
# Adapt Time: 0.16289925575256348 s
# Support set metrics: Loss = 0.3607, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20424842834472656 s
# Support set metrics: Loss = 0.8999, accuracy = 0.6875, precision = 0.7400, recall = 0.6667, F1 score = 0.6778
# Adapt Time: 0.1857302188873291 s
# Support set metrics: Loss = 0.9826, accuracy = 0.6250, precision = 0.6533, recall = 0.6333, F1 score = 0.6167
# Adapt Time: 0.17689228057861328 s
# Support set metrics: Loss = 0.0060, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19342947006225586 s
# Support set metrics: Loss = 0.4819, accuracy = 0.8125, precision = 0.7667, recall = 0.8000, F1 score = 0.7467
# This is epoch 11/600
# Adapt Time: 0.16580605506896973 s
# Support set metrics: Loss = 0.2787, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21056628227233887 s
# Support set metrics: Loss = 0.8190, accuracy = 0.7500, precision = 0.7833, recall = 0.7333, F1 score = 0.7190
# Adapt Time: 0.19951701164245605 s
# Support set metrics: Loss = 1.2495, accuracy = 0.5625, precision = 0.6400, recall = 0.5333, F1 score = 0.5378
# Adapt Time: 0.16719889640808105 s
# Support set metrics: Loss = 0.0955, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.185899019241333 s
# Support set metrics: Loss = 0.7900, accuracy = 0.8125, precision = 0.8167, recall = 0.8500, F1 score = 0.8300
# This is epoch 12/600
# Adapt Time: 0.17038464546203613 s
# Support set metrics: Loss = 0.1295, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19846367835998535 s
# Support set metrics: Loss = 0.6144, accuracy = 0.7500, precision = 0.7867, recall = 0.7333, F1 score = 0.7167
# Adapt Time: 0.2400650978088379 s
# Support set metrics: Loss = 1.1507, accuracy = 0.5000, precision = 0.5200, recall = 0.4833, F1 score = 0.4619
# Adapt Time: 0.17284417152404785 s
# Support set metrics: Loss = 0.0109, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19215822219848633 s
# Support set metrics: Loss = 1.3813, accuracy = 0.5625, precision = 0.4583, recall = 0.5500, F1 score = 0.4667
# This is epoch 13/600
# Adapt Time: 0.16462302207946777 s
# Support set metrics: Loss = 0.2231, accuracy = 0.9375, precision = 1.0000, recall = 0.9375, F1 score = 0.9643
# Adapt Time: 0.19726777076721191 s
# Support set metrics: Loss = 0.7159, accuracy = 0.6250, precision = 0.5733, recall = 0.6167, F1 score = 0.5767
# Adapt Time: 0.20725488662719727 s
# Support set metrics: Loss = 0.7442, accuracy = 0.6875, precision = 0.7167, recall = 0.7000, F1 score = 0.6857
# Adapt Time: 0.1710338592529297 s
# Support set metrics: Loss = 0.0064, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18346858024597168 s
# Support set metrics: Loss = 0.7112, accuracy = 0.8750, precision = 0.9500, recall = 0.9000, F1 score = 0.9000
# This is epoch 14/600
# Adapt Time: 0.16558837890625 s
# Support set metrics: Loss = 0.0320, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19493627548217773 s
# Support set metrics: Loss = 1.0215, accuracy = 0.4375, precision = 0.4133, recall = 0.4500, F1 score = 0.4143
# Adapt Time: 0.201857328414917 s
# Support set metrics: Loss = 0.4995, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7500
# Adapt Time: 0.17020821571350098 s
# Support set metrics: Loss = 0.0107, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22135114669799805 s
# Support set metrics: Loss = 1.3368, accuracy = 0.6250, precision = 0.6333, recall = 0.6500, F1 score = 0.6167
# This is epoch 15/600
# Adapt Time: 0.1659257411956787 s
# Support set metrics: Loss = 0.2356, accuracy = 0.8750, precision = 0.9500, recall = 0.8750, F1 score = 0.8889
# Adapt Time: 0.1891622543334961 s
# Support set metrics: Loss = 0.7786, accuracy = 0.6875, precision = 0.6933, recall = 0.6667, F1 score = 0.6711
# Adapt Time: 0.19028472900390625 s
# Support set metrics: Loss = 0.7125, accuracy = 0.6875, precision = 0.7167, recall = 0.7000, F1 score = 0.6933
# Adapt Time: 0.17557835578918457 s
# Support set metrics: Loss = 0.0063, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21844220161437988 s
# Support set metrics: Loss = 0.6527, accuracy = 0.7500, precision = 0.6833, recall = 0.7000, F1 score = 0.6733
# This is epoch 16/600
# Adapt Time: 0.16924262046813965 s
# Support set metrics: Loss = 0.2429, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.22167444229125977 s
# Support set metrics: Loss = 1.0958, accuracy = 0.6250, precision = 0.6800, recall = 0.6333, F1 score = 0.6333
# Adapt Time: 0.2025611400604248 s
# Support set metrics: Loss = 1.1075, accuracy = 0.6875, precision = 0.7000, recall = 0.6667, F1 score = 0.6743
# Adapt Time: 0.17238712310791016 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1977243423461914 s
# Support set metrics: Loss = 1.0642, accuracy = 0.7500, precision = 0.6833, recall = 0.7000, F1 score = 0.6733
# This is epoch 17/600
# Adapt Time: 0.16370368003845215 s
# Support set metrics: Loss = 0.2379, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8667
# Adapt Time: 0.19724321365356445 s
# Support set metrics: Loss = 0.8097, accuracy = 0.7500, precision = 0.7700, recall = 0.7500, F1 score = 0.7329
# Adapt Time: 0.18139100074768066 s
# Support set metrics: Loss = 1.2094, accuracy = 0.6875, precision = 0.8500, recall = 0.6833, F1 score = 0.7171
# Adapt Time: 0.17803192138671875 s
# Support set metrics: Loss = 0.1425, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.19592785835266113 s
# Support set metrics: Loss = 0.6328, accuracy = 0.7500, precision = 0.6000, recall = 0.6500, F1 score = 0.6167
# This is epoch 18/600
# Adapt Time: 0.16526126861572266 s
# Support set metrics: Loss = 0.2940, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2279043197631836 s
# Support set metrics: Loss = 0.9116, accuracy = 0.4375, precision = 0.4333, recall = 0.4333, F1 score = 0.4286
# Adapt Time: 0.1977541446685791 s
# Support set metrics: Loss = 0.9160, accuracy = 0.5625, precision = 0.6133, recall = 0.5667, F1 score = 0.5743
# Adapt Time: 0.17745685577392578 s
# Support set metrics: Loss = 0.0110, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1911299228668213 s
# Support set metrics: Loss = 1.6555, accuracy = 0.5000, precision = 0.5000, recall = 0.5000, F1 score = 0.4833
# This is epoch 19/600
# Adapt Time: 0.16566157341003418 s
# Support set metrics: Loss = 0.2078, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.2075333595275879 s
# Support set metrics: Loss = 1.4867, accuracy = 0.3125, precision = 0.2571, recall = 0.3333, F1 score = 0.2743
# Adapt Time: 0.20233392715454102 s
# Support set metrics: Loss = 0.6739, accuracy = 0.6875, precision = 0.6500, recall = 0.6667, F1 score = 0.6048
# Adapt Time: 0.17160892486572266 s
# Support set metrics: Loss = 0.5700, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.2404177188873291 s
# Support set metrics: Loss = 0.5871, accuracy = 0.8750, precision = 0.8333, recall = 0.8500, F1 score = 0.8267
# This is epoch 20/600
# Adapt Time: 0.1648719310760498 s
# Support set metrics: Loss = 0.1981, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19609737396240234 s
# Support set metrics: Loss = 0.4702, accuracy = 0.8750, precision = 0.9200, recall = 0.8667, F1 score = 0.8500
# Adapt Time: 0.20961594581604004 s
# Support set metrics: Loss = 0.6755, accuracy = 0.6875, precision = 0.6867, recall = 0.6667, F1 score = 0.6567
# Adapt Time: 0.16865229606628418 s
# Support set metrics: Loss = 0.1157, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.20431160926818848 s
# Support set metrics: Loss = 0.7100, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 21/600
# Adapt Time: 0.1706228256225586 s
# Support set metrics: Loss = 0.1602, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2272789478302002 s
# Support set metrics: Loss = 1.0366, accuracy = 0.6250, precision = 0.6190, recall = 0.6333, F1 score = 0.5943
# Adapt Time: 0.19641423225402832 s
# Support set metrics: Loss = 0.7600, accuracy = 0.6250, precision = 0.7000, recall = 0.6167, F1 score = 0.6157
# Adapt Time: 0.16707110404968262 s
# Support set metrics: Loss = 0.0182, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19518804550170898 s
# Support set metrics: Loss = 0.5156, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 22/600
# Adapt Time: 0.16373705863952637 s
# Support set metrics: Loss = 0.0573, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1913297176361084 s
# Support set metrics: Loss = 0.7430, accuracy = 0.7500, precision = 0.8033, recall = 0.7500, F1 score = 0.7533
# Adapt Time: 0.20836448669433594 s
# Support set metrics: Loss = 0.9955, accuracy = 0.5000, precision = 0.4800, recall = 0.4833, F1 score = 0.4671
# Adapt Time: 0.17590618133544922 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22094941139221191 s
# Support set metrics: Loss = 0.9305, accuracy = 0.6250, precision = 0.5917, recall = 0.6000, F1 score = 0.5800
# This is epoch 23/600
# Adapt Time: 0.1657707691192627 s
# Support set metrics: Loss = 0.3286, accuracy = 0.8125, precision = 0.8375, recall = 0.8125, F1 score = 0.7986
# Adapt Time: 0.19753646850585938 s
# Support set metrics: Loss = 1.0517, accuracy = 0.4375, precision = 0.5633, recall = 0.4333, F1 score = 0.4514
# Adapt Time: 0.18878674507141113 s
# Support set metrics: Loss = 1.4980, accuracy = 0.4375, precision = 0.5167, recall = 0.4667, F1 score = 0.4492
# Adapt Time: 0.1702558994293213 s
# Support set metrics: Loss = 0.0047, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19244647026062012 s
# Support set metrics: Loss = 0.8631, accuracy = 0.6875, precision = 0.6333, recall = 0.6500, F1 score = 0.6267
# This is epoch 24/600
# Adapt Time: 0.16527056694030762 s
# Support set metrics: Loss = 0.1111, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19667744636535645 s
# Support set metrics: Loss = 0.6974, accuracy = 0.8125, precision = 0.8600, recall = 0.8000, F1 score = 0.7806
# Adapt Time: 0.20276737213134766 s
# Support set metrics: Loss = 0.8660, accuracy = 0.6875, precision = 0.7700, recall = 0.6833, F1 score = 0.6743
# Adapt Time: 0.16791248321533203 s
# Support set metrics: Loss = 0.4464, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.19698429107666016 s
# Support set metrics: Loss = 0.9570, accuracy = 0.6250, precision = 0.5000, recall = 0.5500, F1 score = 0.4967
# This is epoch 25/600
# Adapt Time: 0.16746306419372559 s
# Support set metrics: Loss = 0.0495, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.17837786674499512 s
# Support set metrics: Loss = 0.8551, accuracy = 0.6250, precision = 0.6467, recall = 0.6167, F1 score = 0.6181
# Adapt Time: 0.2011091709136963 s
# Support set metrics: Loss = 0.6621, accuracy = 0.6250, precision = 0.6633, recall = 0.6167, F1 score = 0.6233
# Adapt Time: 0.16380095481872559 s
# Support set metrics: Loss = 0.2064, accuracy = 0.9375, precision = 0.8929, recall = 0.9286, F1 score = 0.9048
# Adapt Time: 0.1829211711883545 s
# Support set metrics: Loss = 0.9706, accuracy = 0.7500, precision = 0.7333, recall = 0.8000, F1 score = 0.7267
# This is epoch 26/600
# Adapt Time: 0.16755938529968262 s
# Support set metrics: Loss = 0.3192, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21906733512878418 s
# Support set metrics: Loss = 1.0505, accuracy = 0.5625, precision = 0.6467, recall = 0.5667, F1 score = 0.5743
# Adapt Time: 0.2069711685180664 s
# Support set metrics: Loss = 0.7080, accuracy = 0.8125, precision = 0.8700, recall = 0.8000, F1 score = 0.7814
# Adapt Time: 0.1687934398651123 s
# Support set metrics: Loss = 0.0182, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21168041229248047 s
# Support set metrics: Loss = 0.5163, accuracy = 0.8750, precision = 0.9000, recall = 0.9000, F1 score = 0.8833
# This is epoch 27/600
# Adapt Time: 0.16562843322753906 s
# Support set metrics: Loss = 0.1085, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19138240814208984 s
# Support set metrics: Loss = 0.8895, accuracy = 0.6250, precision = 0.6667, recall = 0.6000, F1 score = 0.5876
# Adapt Time: 0.18015098571777344 s
# Support set metrics: Loss = 1.0150, accuracy = 0.7500, precision = 0.7667, recall = 0.7667, F1 score = 0.7505
# Adapt Time: 0.1695690155029297 s
# Support set metrics: Loss = 0.0588, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.19374918937683105 s
# Support set metrics: Loss = 0.6035, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 28/600
# Adapt Time: 0.16507649421691895 s
# Support set metrics: Loss = 0.4932, accuracy = 0.8125, precision = 0.9000, recall = 0.8125, F1 score = 0.8254
# Adapt Time: 0.19024109840393066 s
# Support set metrics: Loss = 0.8918, accuracy = 0.6875, precision = 0.7000, recall = 0.6833, F1 score = 0.6757
# Adapt Time: 0.21610260009765625 s
# Support set metrics: Loss = 1.0376, accuracy = 0.6250, precision = 0.7167, recall = 0.6500, F1 score = 0.6324
# Adapt Time: 0.16727614402770996 s
# Support set metrics: Loss = 0.0104, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20561885833740234 s
# Support set metrics: Loss = 1.0002, accuracy = 0.7500, precision = 0.5833, recall = 0.6500, F1 score = 0.5933
# This is epoch 29/600
# Adapt Time: 0.16530799865722656 s
# Support set metrics: Loss = 0.0850, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18018174171447754 s
# Support set metrics: Loss = 0.9806, accuracy = 0.6875, precision = 0.6767, recall = 0.6667, F1 score = 0.6559
# Adapt Time: 0.19422698020935059 s
# Support set metrics: Loss = 0.6908, accuracy = 0.7500, precision = 0.8167, recall = 0.7333, F1 score = 0.7248
# Adapt Time: 0.1703474521636963 s
# Support set metrics: Loss = 0.0057, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22005486488342285 s
# Support set metrics: Loss = 0.6469, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 30/600
# Adapt Time: 0.16680216789245605 s
# Support set metrics: Loss = 0.3708, accuracy = 0.8125, precision = 0.8542, recall = 0.8125, F1 score = 0.8161
# Adapt Time: 0.23942136764526367 s
# Support set metrics: Loss = 1.2579, accuracy = 0.4375, precision = 0.4933, recall = 0.4500, F1 score = 0.4133
# Adapt Time: 0.19526076316833496 s
# Support set metrics: Loss = 0.9603, accuracy = 0.6250, precision = 0.6667, recall = 0.6000, F1 score = 0.5933
# Adapt Time: 0.1747298240661621 s
# Support set metrics: Loss = 0.0056, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1999070644378662 s
# Support set metrics: Loss = 0.9839, accuracy = 0.7500, precision = 0.7167, recall = 0.7500, F1 score = 0.7133
# This is epoch 31/600
# Adapt Time: 0.16893243789672852 s
# Support set metrics: Loss = 0.7159, accuracy = 0.8125, precision = 0.8542, recall = 0.8125, F1 score = 0.8161
# Adapt Time: 0.19075989723205566 s
# Support set metrics: Loss = 0.5499, accuracy = 0.8125, precision = 0.8000, recall = 0.8167, F1 score = 0.8014
# Adapt Time: 0.20499038696289062 s
# Support set metrics: Loss = 1.2306, accuracy = 0.5000, precision = 0.5800, recall = 0.5167, F1 score = 0.4886
# Adapt Time: 0.17264676094055176 s
# Support set metrics: Loss = 0.0142, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.195326566696167 s
# Support set metrics: Loss = 0.6773, accuracy = 0.7500, precision = 0.7333, recall = 0.7500, F1 score = 0.7233
# This is epoch 32/600
# Adapt Time: 0.16808581352233887 s
# Support set metrics: Loss = 0.0486, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2274320125579834 s
# Support set metrics: Loss = 0.4585, accuracy = 0.9375, precision = 0.9500, recall = 0.9333, F1 score = 0.9314
# Adapt Time: 0.19006991386413574 s
# Support set metrics: Loss = 0.6774, accuracy = 0.6875, precision = 0.6000, recall = 0.6667, F1 score = 0.6286
# Adapt Time: 0.17312169075012207 s
# Support set metrics: Loss = 0.3541, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.23916029930114746 s
# Support set metrics: Loss = 0.9865, accuracy = 0.6875, precision = 0.4833, recall = 0.6000, F1 score = 0.5267
# This is epoch 33/600
# Adapt Time: 0.166764497756958 s
# Support set metrics: Loss = 0.0492, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20354175567626953 s
# Support set metrics: Loss = 0.4297, accuracy = 0.8125, precision = 0.8600, recall = 0.8000, F1 score = 0.7806
# Adapt Time: 0.19094181060791016 s
# Support set metrics: Loss = 1.3041, accuracy = 0.5000, precision = 0.5167, recall = 0.4833, F1 score = 0.4910
# Adapt Time: 0.1761157512664795 s
# Support set metrics: Loss = 0.0063, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20282530784606934 s
# Support set metrics: Loss = 1.0842, accuracy = 0.6250, precision = 0.5067, recall = 0.6000, F1 score = 0.5371
# This is epoch 34/600
# Adapt Time: 0.16529273986816406 s
# Support set metrics: Loss = 0.4552, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20038914680480957 s
# Support set metrics: Loss = 0.6693, accuracy = 0.6875, precision = 0.5900, recall = 0.6667, F1 score = 0.6092
# Adapt Time: 0.18573665618896484 s
# Support set metrics: Loss = 0.8065, accuracy = 0.5625, precision = 0.6233, recall = 0.5833, F1 score = 0.5814
# Adapt Time: 0.1697525978088379 s
# Support set metrics: Loss = 0.0058, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21049976348876953 s
# Support set metrics: Loss = 0.3556, accuracy = 0.8750, precision = 0.9000, recall = 0.9000, F1 score = 0.8833
# This is epoch 35/600
# Adapt Time: 0.16506123542785645 s
# Support set metrics: Loss = 0.3195, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8667
# Adapt Time: 0.19529438018798828 s
# Support set metrics: Loss = 0.5655, accuracy = 0.8125, precision = 0.7000, recall = 0.8000, F1 score = 0.7333
# Adapt Time: 0.21785616874694824 s
# Support set metrics: Loss = 0.8104, accuracy = 0.6250, precision = 0.6500, recall = 0.6167, F1 score = 0.6186
# Adapt Time: 0.17836833000183105 s
# Support set metrics: Loss = 0.0044, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19481992721557617 s
# Support set metrics: Loss = 0.8865, accuracy = 0.6875, precision = 0.5733, recall = 0.6500, F1 score = 0.5838
# This is epoch 36/600
# Adapt Time: 0.167769193649292 s
# Support set metrics: Loss = 0.8078, accuracy = 0.7500, precision = 0.7875, recall = 0.7500, F1 score = 0.7431
# Adapt Time: 0.19761419296264648 s
# Support set metrics: Loss = 1.1548, accuracy = 0.5625, precision = 0.7133, recall = 0.5667, F1 score = 0.5476
# Adapt Time: 0.2050309181213379 s
# Support set metrics: Loss = 0.9359, accuracy = 0.5625, precision = 0.5867, recall = 0.5667, F1 score = 0.5567
# Adapt Time: 0.17493534088134766 s
# Support set metrics: Loss = 0.0202, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19706010818481445 s
# Support set metrics: Loss = 0.9239, accuracy = 0.6250, precision = 0.6167, recall = 0.6000, F1 score = 0.5800
# This is epoch 37/600
# Adapt Time: 0.1653134822845459 s
# Support set metrics: Loss = 0.5675, accuracy = 0.8125, precision = 0.8042, recall = 0.8125, F1 score = 0.8026
# Adapt Time: 0.18691754341125488 s
# Support set metrics: Loss = 1.2184, accuracy = 0.3750, precision = 0.4333, recall = 0.3833, F1 score = 0.3911
# Adapt Time: 0.20738983154296875 s
# Support set metrics: Loss = 0.8513, accuracy = 0.6875, precision = 0.8167, recall = 0.6667, F1 score = 0.6648
# Adapt Time: 0.17072534561157227 s
# Support set metrics: Loss = 0.0087, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19117331504821777 s
# Support set metrics: Loss = 1.2270, accuracy = 0.5625, precision = 0.3167, recall = 0.4500, F1 score = 0.3667
# This is epoch 38/600
# Adapt Time: 0.16524839401245117 s
# Support set metrics: Loss = 0.2074, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19513416290283203 s
# Support set metrics: Loss = 1.1040, accuracy = 0.6250, precision = 0.6633, recall = 0.6333, F1 score = 0.6181
# Adapt Time: 0.19244885444641113 s
# Support set metrics: Loss = 1.1193, accuracy = 0.5000, precision = 0.5000, recall = 0.5167, F1 score = 0.4895
# Adapt Time: 0.17332792282104492 s
# Support set metrics: Loss = 0.0054, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1971111297607422 s
# Support set metrics: Loss = 0.5476, accuracy = 0.8125, precision = 0.8333, recall = 0.8000, F1 score = 0.8067
# This is epoch 39/600
# Adapt Time: 0.16809821128845215 s
# Support set metrics: Loss = 0.0905, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19527411460876465 s
# Support set metrics: Loss = 0.9766, accuracy = 0.5625, precision = 0.6700, recall = 0.5833, F1 score = 0.5614
# Adapt Time: 0.18566060066223145 s
# Support set metrics: Loss = 1.1102, accuracy = 0.5625, precision = 0.5000, recall = 0.5500, F1 score = 0.5214
# Adapt Time: 0.1747603416442871 s
# Support set metrics: Loss = 0.0065, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19127488136291504 s
# Support set metrics: Loss = 1.3419, accuracy = 0.5000, precision = 0.4667, recall = 0.4500, F1 score = 0.4467
# This is epoch 40/600
# Adapt Time: 0.16804146766662598 s
# Support set metrics: Loss = 0.0691, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2072129249572754 s
# Support set metrics: Loss = 0.7653, accuracy = 0.6250, precision = 0.5167, recall = 0.6000, F1 score = 0.5524
# Adapt Time: 0.20801758766174316 s
# Support set metrics: Loss = 1.4773, accuracy = 0.3125, precision = 0.3333, recall = 0.3167, F1 score = 0.3143
# Adapt Time: 0.17683863639831543 s
# Support set metrics: Loss = 0.0154, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1966688632965088 s
# Support set metrics: Loss = 0.6441, accuracy = 0.7500, precision = 0.7333, recall = 0.7500, F1 score = 0.7233
# This is epoch 41/600
# Adapt Time: 0.1693592071533203 s
# Support set metrics: Loss = 0.0768, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21660614013671875 s
# Support set metrics: Loss = 1.0465, accuracy = 0.6250, precision = 0.6867, recall = 0.6167, F1 score = 0.6400
# Adapt Time: 0.19775152206420898 s
# Support set metrics: Loss = 1.2424, accuracy = 0.4375, precision = 0.3800, recall = 0.4333, F1 score = 0.3943
# Adapt Time: 0.17101621627807617 s
# Support set metrics: Loss = 0.0354, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.195939302444458 s
# Support set metrics: Loss = 0.8781, accuracy = 0.6250, precision = 0.5667, recall = 0.6500, F1 score = 0.5733
# This is epoch 42/600
# Adapt Time: 0.16550540924072266 s
# Support set metrics: Loss = 0.1055, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20368576049804688 s
# Support set metrics: Loss = 1.1565, accuracy = 0.4375, precision = 0.4333, recall = 0.4333, F1 score = 0.4032
# Adapt Time: 0.18805408477783203 s
# Support set metrics: Loss = 0.8465, accuracy = 0.6875, precision = 0.6433, recall = 0.6667, F1 score = 0.6425
# Adapt Time: 0.17528486251831055 s
# Support set metrics: Loss = 0.2741, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.20352864265441895 s
# Support set metrics: Loss = 0.6264, accuracy = 0.8125, precision = 0.7000, recall = 0.7500, F1 score = 0.7000
# This is epoch 43/600
# Adapt Time: 0.1668691635131836 s
# Support set metrics: Loss = 0.2985, accuracy = 0.9375, precision = 1.0000, recall = 0.9375, F1 score = 0.9643
# Adapt Time: 0.21370887756347656 s
# Support set metrics: Loss = 0.7161, accuracy = 0.8125, precision = 0.8333, recall = 0.8000, F1 score = 0.7762
# Adapt Time: 0.20125436782836914 s
# Support set metrics: Loss = 1.3549, accuracy = 0.5000, precision = 0.6000, recall = 0.5000, F1 score = 0.5352
# Adapt Time: 0.17643237113952637 s
# Support set metrics: Loss = 0.0442, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20815396308898926 s
# Support set metrics: Loss = 1.1200, accuracy = 0.6250, precision = 0.6500, recall = 0.7000, F1 score = 0.6500
# This is epoch 44/600
# Adapt Time: 0.16424965858459473 s
# Support set metrics: Loss = 0.2267, accuracy = 0.8125, precision = 0.8167, recall = 0.8125, F1 score = 0.8095
# Adapt Time: 0.2055072784423828 s
# Support set metrics: Loss = 0.9753, accuracy = 0.6250, precision = 0.6667, recall = 0.6500, F1 score = 0.6476
# Adapt Time: 0.20367789268493652 s
# Support set metrics: Loss = 0.7337, accuracy = 0.6875, precision = 0.7200, recall = 0.6833, F1 score = 0.6514
# Adapt Time: 0.17222237586975098 s
# Support set metrics: Loss = 0.0167, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19167184829711914 s
# Support set metrics: Loss = 0.7050, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 45/600
# Adapt Time: 0.16561245918273926 s
# Support set metrics: Loss = 0.3662, accuracy = 0.8125, precision = 0.8667, recall = 0.8125, F1 score = 0.8294
# Adapt Time: 0.19085216522216797 s
# Support set metrics: Loss = 0.7569, accuracy = 0.7500, precision = 0.7533, recall = 0.7500, F1 score = 0.7348
# Adapt Time: 0.18537259101867676 s
# Support set metrics: Loss = 0.7617, accuracy = 0.6875, precision = 0.7133, recall = 0.6833, F1 score = 0.6848
# Adapt Time: 0.17517566680908203 s
# Support set metrics: Loss = 0.0141, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.23413825035095215 s
# Support set metrics: Loss = 0.8318, accuracy = 0.8125, precision = 0.6833, recall = 0.7500, F1 score = 0.7000
# This is epoch 46/600
# Adapt Time: 0.16699814796447754 s
# Support set metrics: Loss = 0.3086, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8786
# Adapt Time: 0.19594860076904297 s
# Support set metrics: Loss = 0.8308, accuracy = 0.7500, precision = 0.7333, recall = 0.7333, F1 score = 0.7333
# Adapt Time: 0.20940518379211426 s
# Support set metrics: Loss = 1.0923, accuracy = 0.5000, precision = 0.6733, recall = 0.5167, F1 score = 0.5376
# Adapt Time: 0.17363214492797852 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19082236289978027 s
# Support set metrics: Loss = 0.8040, accuracy = 0.7500, precision = 0.6333, recall = 0.7000, F1 score = 0.6333
# This is epoch 47/600
# Adapt Time: 0.16628766059875488 s
# Support set metrics: Loss = 0.1188, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18368840217590332 s
# Support set metrics: Loss = 1.2206, accuracy = 0.3125, precision = 0.3467, recall = 0.3167, F1 score = 0.3171
# Adapt Time: 0.1930863857269287 s
# Support set metrics: Loss = 1.0312, accuracy = 0.6250, precision = 0.7333, recall = 0.6500, F1 score = 0.6233
# Adapt Time: 0.17146849632263184 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20722365379333496 s
# Support set metrics: Loss = 0.5920, accuracy = 0.8125, precision = 0.7000, recall = 0.8000, F1 score = 0.7333
# This is epoch 48/600
# Adapt Time: 0.1697065830230713 s
# Support set metrics: Loss = 0.0570, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19610834121704102 s
# Support set metrics: Loss = 1.1471, accuracy = 0.8125, precision = 0.8933, recall = 0.8000, F1 score = 0.8311
# Adapt Time: 0.20158123970031738 s
# Support set metrics: Loss = 0.6681, accuracy = 0.7500, precision = 0.7700, recall = 0.7500, F1 score = 0.7400
# Adapt Time: 0.17280101776123047 s
# Support set metrics: Loss = 0.0767, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.2083728313446045 s
# Support set metrics: Loss = 0.9086, accuracy = 0.6250, precision = 0.7000, recall = 0.6000, F1 score = 0.6333
# This is epoch 49/600
# Adapt Time: 0.1659107208251953 s
# Support set metrics: Loss = 0.1214, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19627642631530762 s
# Support set metrics: Loss = 0.6995, accuracy = 0.8125, precision = 0.8833, recall = 0.8000, F1 score = 0.7914
# Adapt Time: 0.19149374961853027 s
# Support set metrics: Loss = 0.7764, accuracy = 0.8125, precision = 0.8000, recall = 0.8167, F1 score = 0.8014
# Adapt Time: 0.17171335220336914 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19522404670715332 s
# Support set metrics: Loss = 1.1371, accuracy = 0.6250, precision = 0.5167, recall = 0.6000, F1 score = 0.5467
# This is epoch 50/600
# Adapt Time: 0.16709470748901367 s
# Support set metrics: Loss = 0.4108, accuracy = 0.8125, precision = 0.8042, recall = 0.8125, F1 score = 0.8026
# Adapt Time: 0.19588994979858398 s
# Support set metrics: Loss = 1.2641, accuracy = 0.5000, precision = 0.5367, recall = 0.5167, F1 score = 0.4786
# Adapt Time: 0.2034144401550293 s
# Support set metrics: Loss = 1.2187, accuracy = 0.3750, precision = 0.4800, recall = 0.3667, F1 score = 0.3800
# Adapt Time: 0.17374777793884277 s
# Support set metrics: Loss = 0.4438, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.21766042709350586 s
# Support set metrics: Loss = 0.3839, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 51/600
# Adapt Time: 0.1672382354736328 s
# Support set metrics: Loss = 0.2905, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.1802363395690918 s
# Support set metrics: Loss = 1.3328, accuracy = 0.4375, precision = 0.4833, recall = 0.4333, F1 score = 0.4457
# Adapt Time: 0.2048797607421875 s
# Support set metrics: Loss = 0.9485, accuracy = 0.6250, precision = 0.6667, recall = 0.6333, F1 score = 0.6362
# Adapt Time: 0.17235565185546875 s
# Support set metrics: Loss = 0.0054, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21119189262390137 s
# Support set metrics: Loss = 1.1703, accuracy = 0.6250, precision = 0.5500, recall = 0.6000, F1 score = 0.5300
# This is epoch 52/600
# Adapt Time: 0.1669464111328125 s
# Support set metrics: Loss = 0.5840, accuracy = 0.8125, precision = 0.8500, recall = 0.8125, F1 score = 0.8175
# Adapt Time: 0.20474028587341309 s
# Support set metrics: Loss = 1.1888, accuracy = 0.3750, precision = 0.4333, recall = 0.3667, F1 score = 0.3933
# Adapt Time: 0.18326091766357422 s
# Support set metrics: Loss = 0.8772, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7371
# Adapt Time: 0.18021225929260254 s
# Support set metrics: Loss = 0.0152, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.23202872276306152 s
# Support set metrics: Loss = 0.6582, accuracy = 0.8125, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 53/600
# Adapt Time: 0.17373156547546387 s
# Support set metrics: Loss = 0.2472, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8786
# Adapt Time: 0.17804408073425293 s
# Support set metrics: Loss = 1.4566, accuracy = 0.5000, precision = 0.5000, recall = 0.4833, F1 score = 0.4737
# Adapt Time: 0.2384486198425293 s
# Support set metrics: Loss = 1.0152, accuracy = 0.4375, precision = 0.3700, recall = 0.4667, F1 score = 0.4014
# Adapt Time: 0.17546558380126953 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22018122673034668 s
# Support set metrics: Loss = 0.8669, accuracy = 0.7500, precision = 0.8250, recall = 0.7500, F1 score = 0.7400
# This is epoch 54/600
# Adapt Time: 0.1682910919189453 s
# Support set metrics: Loss = 0.4816, accuracy = 0.8125, precision = 0.8167, recall = 0.8125, F1 score = 0.8095
# Adapt Time: 0.20397567749023438 s
# Support set metrics: Loss = 1.2886, accuracy = 0.3125, precision = 0.3167, recall = 0.3167, F1 score = 0.3048
# Adapt Time: 0.21310877799987793 s
# Support set metrics: Loss = 1.0527, accuracy = 0.4375, precision = 0.5700, recall = 0.4500, F1 score = 0.4600
# Adapt Time: 0.17139625549316406 s
# Support set metrics: Loss = 0.0049, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20903587341308594 s
# Support set metrics: Loss = 0.7193, accuracy = 0.8125, precision = 0.8667, recall = 0.8500, F1 score = 0.8300
# This is epoch 55/600
# Adapt Time: 0.1663825511932373 s
# Support set metrics: Loss = 0.0941, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19435620307922363 s
# Support set metrics: Loss = 1.0069, accuracy = 0.5625, precision = 0.6800, recall = 0.5667, F1 score = 0.6089
# Adapt Time: 0.1975541114807129 s
# Support set metrics: Loss = 1.4497, accuracy = 0.6250, precision = 0.8833, recall = 0.6333, F1 score = 0.6981
# Adapt Time: 0.17017865180969238 s
# Support set metrics: Loss = 0.0062, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19444942474365234 s
# Support set metrics: Loss = 0.8431, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7333
# This is epoch 56/600
# Adapt Time: 0.1645963191986084 s
# Support set metrics: Loss = 0.1960, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.1981372833251953 s
# Support set metrics: Loss = 1.2868, accuracy = 0.4375, precision = 0.4667, recall = 0.4333, F1 score = 0.4222
# Adapt Time: 0.20116662979125977 s
# Support set metrics: Loss = 1.0744, accuracy = 0.5000, precision = 0.5667, recall = 0.5000, F1 score = 0.5219
# Adapt Time: 0.1747589111328125 s
# Support set metrics: Loss = 0.0055, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1942131519317627 s
# Support set metrics: Loss = 0.6555, accuracy = 0.7500, precision = 0.7833, recall = 0.8000, F1 score = 0.7500
# This is epoch 57/600
# Adapt Time: 0.16799616813659668 s
# Support set metrics: Loss = 0.1539, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21863031387329102 s
# Support set metrics: Loss = 0.6273, accuracy = 0.7500, precision = 0.7500, recall = 0.7333, F1 score = 0.7257
# Adapt Time: 0.1862950325012207 s
# Support set metrics: Loss = 1.4265, accuracy = 0.6875, precision = 0.7433, recall = 0.6667, F1 score = 0.6625
# Adapt Time: 0.17465806007385254 s
# Support set metrics: Loss = 0.0050, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18570494651794434 s
# Support set metrics: Loss = 0.5038, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 58/600
# Adapt Time: 0.1653428077697754 s
# Support set metrics: Loss = 0.1004, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.20244741439819336 s
# Support set metrics: Loss = 0.8407, accuracy = 0.5625, precision = 0.6133, recall = 0.5667, F1 score = 0.5667
# Adapt Time: 0.1943197250366211 s
# Support set metrics: Loss = 1.3042, accuracy = 0.6875, precision = 0.7667, recall = 0.6667, F1 score = 0.6810
# Adapt Time: 0.17264151573181152 s
# Support set metrics: Loss = 0.0043, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20272135734558105 s
# Support set metrics: Loss = 0.7870, accuracy = 0.8125, precision = 0.8000, recall = 0.8000, F1 score = 0.7633
# This is epoch 59/600
# Adapt Time: 0.16738295555114746 s
# Support set metrics: Loss = 0.0386, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18369293212890625 s
# Support set metrics: Loss = 1.0098, accuracy = 0.6875, precision = 0.7833, recall = 0.6833, F1 score = 0.6905
# Adapt Time: 0.19361376762390137 s
# Support set metrics: Loss = 1.1333, accuracy = 0.5000, precision = 0.5133, recall = 0.5000, F1 score = 0.4886
# Adapt Time: 0.16822075843811035 s
# Support set metrics: Loss = 0.0068, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18742895126342773 s
# Support set metrics: Loss = 0.7886, accuracy = 0.6250, precision = 0.6333, recall = 0.6000, F1 score = 0.5900
# This is epoch 60/600
# Adapt Time: 0.16675162315368652 s
# Support set metrics: Loss = 0.6417, accuracy = 0.8125, precision = 0.8667, recall = 0.8125, F1 score = 0.8032
# Adapt Time: 0.19576811790466309 s
# Support set metrics: Loss = 0.8834, accuracy = 0.4375, precision = 0.3700, recall = 0.4333, F1 score = 0.3881
# Adapt Time: 0.22730231285095215 s
# Support set metrics: Loss = 0.8705, accuracy = 0.5000, precision = 0.4333, recall = 0.4833, F1 score = 0.4467
# Adapt Time: 0.1691591739654541 s
# Support set metrics: Loss = 0.0054, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19341492652893066 s
# Support set metrics: Loss = 0.7852, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7600
# This is epoch 61/600
# Adapt Time: 0.16890740394592285 s
# Support set metrics: Loss = 0.3152, accuracy = 0.8125, precision = 0.8500, recall = 0.8125, F1 score = 0.8056
# Adapt Time: 0.18196964263916016 s
# Support set metrics: Loss = 0.9208, accuracy = 0.7500, precision = 0.6700, recall = 0.7333, F1 score = 0.6814
# Adapt Time: 0.1887950897216797 s
# Support set metrics: Loss = 0.8290, accuracy = 0.5625, precision = 0.5533, recall = 0.5500, F1 score = 0.5000
# Adapt Time: 0.17498111724853516 s
# Support set metrics: Loss = 0.0045, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1995100975036621 s
# Support set metrics: Loss = 0.3481, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 62/600
# Adapt Time: 0.16598105430603027 s
# Support set metrics: Loss = 0.3706, accuracy = 0.7500, precision = 0.8125, recall = 0.7500, F1 score = 0.7542
# Adapt Time: 0.20760631561279297 s
# Support set metrics: Loss = 1.0783, accuracy = 0.6875, precision = 0.6600, recall = 0.6667, F1 score = 0.6578
# Adapt Time: 0.19983482360839844 s
# Support set metrics: Loss = 0.9100, accuracy = 0.6875, precision = 0.7633, recall = 0.6833, F1 score = 0.7033
# Adapt Time: 0.1745314598083496 s
# Support set metrics: Loss = 0.0309, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2393052577972412 s
# Support set metrics: Loss = 0.8150, accuracy = 0.6875, precision = 0.7000, recall = 0.7500, F1 score = 0.7000
# This is epoch 63/600
# Adapt Time: 0.1693708896636963 s
# Support set metrics: Loss = 0.0416, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19246411323547363 s
# Support set metrics: Loss = 1.0720, accuracy = 0.6250, precision = 0.6833, recall = 0.6333, F1 score = 0.6457
# Adapt Time: 0.19067120552062988 s
# Support set metrics: Loss = 0.6761, accuracy = 0.6875, precision = 0.7167, recall = 0.7000, F1 score = 0.6933
# Adapt Time: 0.17805719375610352 s
# Support set metrics: Loss = 0.0747, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19249606132507324 s
# Support set metrics: Loss = 1.0790, accuracy = 0.6875, precision = 0.7917, recall = 0.7000, F1 score = 0.7133
# This is epoch 64/600
# Adapt Time: 0.16978931427001953 s
# Support set metrics: Loss = 0.1012, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.1950228214263916 s
# Support set metrics: Loss = 0.9634, accuracy = 0.6875, precision = 0.7333, recall = 0.6833, F1 score = 0.6990
# Adapt Time: 0.19765591621398926 s
# Support set metrics: Loss = 0.7040, accuracy = 0.7500, precision = 0.7533, recall = 0.7333, F1 score = 0.7233
# Adapt Time: 0.1765596866607666 s
# Support set metrics: Loss = 0.0053, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18956470489501953 s
# ...
# This is epoch 412/600
# Adapt Time: 0.16520190238952637 s
# Support set metrics: Loss = 0.0513, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19734477996826172 s
# Support set metrics: Loss = 0.9279, accuracy = 0.6250, precision = 0.7000, recall = 0.6333, F1 score = 0.6486
# Adapt Time: 0.18923473358154297 s
# Support set metrics: Loss = 0.7624, accuracy = 0.5625, precision = 0.4467, recall = 0.5333, F1 score = 0.4733
# Adapt Time: 0.1776878833770752 s
# Support set metrics: Loss = 0.0256, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18410253524780273 s
# Support set metrics: Loss = 1.2562, accuracy = 0.7500, precision = 0.8000, recall = 0.7500, F1 score = 0.7300
# This is epoch 413/600
# Adapt Time: 0.17110037803649902 s
# Support set metrics: Loss = 0.4783, accuracy = 0.7500, precision = 0.7542, recall = 0.7500, F1 score = 0.7470
# Adapt Time: 0.20078563690185547 s
# Support set metrics: Loss = 0.7960, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7429
# Adapt Time: 0.19934868812561035 s
# Support set metrics: Loss = 0.8062, accuracy = 0.6875, precision = 0.7333, recall = 0.7000, F1 score = 0.6971
# Adapt Time: 0.17474699020385742 s
# Support set metrics: Loss = 0.0069, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1882946491241455 s
# Support set metrics: Loss = 0.8542, accuracy = 0.7500, precision = 0.7667, recall = 0.7500, F1 score = 0.7133
# This is epoch 414/600
# Adapt Time: 0.16658854484558105 s
# Support set metrics: Loss = 0.1447, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.1820693016052246 s
# Support set metrics: Loss = 0.9423, accuracy = 0.7500, precision = 0.8333, recall = 0.7500, F1 score = 0.7548
# Adapt Time: 0.20928144454956055 s
# Support set metrics: Loss = 0.9235, accuracy = 0.5000, precision = 0.4533, recall = 0.5000, F1 score = 0.4633
# Adapt Time: 0.17627382278442383 s
# Support set metrics: Loss = 0.0101, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18070626258850098 s
# Support set metrics: Loss = 0.6258, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7600
# This is epoch 415/600
# Adapt Time: 0.16610121726989746 s
# Support set metrics: Loss = 0.0837, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2535674571990967 s
# Support set metrics: Loss = 0.7894, accuracy = 0.7500, precision = 0.8100, recall = 0.7333, F1 score = 0.7235
# Adapt Time: 0.21556997299194336 s
# Support set metrics: Loss = 0.7141, accuracy = 0.7500, precision = 0.7500, recall = 0.7500, F1 score = 0.7329
# Adapt Time: 0.1662764549255371 s
# Support set metrics: Loss = 0.0086, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1700611114501953 s
# Support set metrics: Loss = 0.8404, accuracy = 0.6250, precision = 0.5167, recall = 0.6000, F1 score = 0.5267
# This is epoch 416/600
# Adapt Time: 0.16638875007629395 s
# Support set metrics: Loss = 0.1822, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21053719520568848 s
# Support set metrics: Loss = 1.6928, accuracy = 0.3125, precision = 0.2524, recall = 0.3167, F1 score = 0.2533
# Adapt Time: 0.19396519660949707 s
# Support set metrics: Loss = 0.9047, accuracy = 0.8125, precision = 0.9000, recall = 0.8000, F1 score = 0.8029
# Adapt Time: 0.17467641830444336 s
# Support set metrics: Loss = 0.3564, accuracy = 0.9375, precision = 0.9762, recall = 0.9643, F1 score = 0.9619
# Adapt Time: 0.19296979904174805 s
# Support set metrics: Loss = 0.9527, accuracy = 0.6250, precision = 0.6167, recall = 0.6500, F1 score = 0.5967
# This is epoch 417/600
# Adapt Time: 0.16569805145263672 s
# Support set metrics: Loss = 0.1079, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2086622714996338 s
# Support set metrics: Loss = 1.0351, accuracy = 0.6875, precision = 0.8167, recall = 0.7000, F1 score = 0.7390
# Adapt Time: 0.19056010246276855 s
# Support set metrics: Loss = 0.6779, accuracy = 0.7500, precision = 0.8300, recall = 0.7333, F1 score = 0.6992
# Adapt Time: 0.175337553024292 s
# Support set metrics: Loss = 0.0069, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2261958122253418 s
# Support set metrics: Loss = 1.1707, accuracy = 0.4375, precision = 0.4000, recall = 0.4500, F1 score = 0.3967
# This is epoch 418/600
# Adapt Time: 0.16659164428710938 s
# Support set metrics: Loss = 0.0644, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20965075492858887 s
# Support set metrics: Loss = 0.9477, accuracy = 0.5000, precision = 0.5300, recall = 0.4833, F1 score = 0.4643
# Adapt Time: 0.2069716453552246 s
# Support set metrics: Loss = 0.6278, accuracy = 0.8125, precision = 0.8700, recall = 0.8333, F1 score = 0.8148
# Adapt Time: 0.17386746406555176 s
# Support set metrics: Loss = 0.3160, accuracy = 0.9375, precision = 0.9643, recall = 0.9643, F1 score = 0.9524
# Adapt Time: 0.18346714973449707 s
# Support set metrics: Loss = 0.8940, accuracy = 0.6875, precision = 0.6067, recall = 0.6500, F1 score = 0.6038
# This is epoch 419/600
# Adapt Time: 0.16526508331298828 s
# Support set metrics: Loss = 0.1511, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.2006995677947998 s
# Support set metrics: Loss = 1.1726, accuracy = 0.6250, precision = 0.6500, recall = 0.6333, F1 score = 0.6324
# Adapt Time: 0.23478984832763672 s
# Support set metrics: Loss = 1.1850, accuracy = 0.3750, precision = 0.4733, recall = 0.3667, F1 score = 0.3967
# Adapt Time: 0.17358875274658203 s
# Support set metrics: Loss = 0.1784, accuracy = 0.9375, precision = 0.9048, recall = 0.9286, F1 score = 0.9143
# Adapt Time: 0.20157647132873535 s
# Support set metrics: Loss = 1.2249, accuracy = 0.6250, precision = 0.6500, recall = 0.7000, F1 score = 0.6533
# This is epoch 420/600
# Adapt Time: 0.1684401035308838 s
# Support set metrics: Loss = 0.5645, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.19156575202941895 s
# Support set metrics: Loss = 1.0833, accuracy = 0.5625, precision = 0.5267, recall = 0.5333, F1 score = 0.5187
# Adapt Time: 0.2258739471435547 s
# Support set metrics: Loss = 0.8618, accuracy = 0.5000, precision = 0.5533, recall = 0.4833, F1 score = 0.4810
# Adapt Time: 0.17820191383361816 s
# Support set metrics: Loss = 0.0044, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.2341156005859375 s
# Support set metrics: Loss = 0.3758, accuracy = 0.9375, precision = 0.9667, recall = 0.9500, F1 score = 0.9467
# This is epoch 421/600
# Adapt Time: 0.16713619232177734 s
# Support set metrics: Loss = 0.0706, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20025420188903809 s
# Support set metrics: Loss = 0.9112, accuracy = 0.6250, precision = 0.6533, recall = 0.6167, F1 score = 0.6148
# Adapt Time: 0.18904519081115723 s
# Support set metrics: Loss = 0.9379, accuracy = 0.6250, precision = 0.6200, recall = 0.6167, F1 score = 0.6014
# Adapt Time: 0.17135834693908691 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20531129837036133 s
# Support set metrics: Loss = 0.9650, accuracy = 0.8125, precision = 0.8000, recall = 0.8000, F1 score = 0.7733
# This is epoch 422/600
# Adapt Time: 0.1687929630279541 s
# Support set metrics: Loss = 0.1868, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8611
# Adapt Time: 0.18843293190002441 s
# Support set metrics: Loss = 0.8540, accuracy = 0.5625, precision = 0.6200, recall = 0.5667, F1 score = 0.5710
# Adapt Time: 0.2100827693939209 s
# Support set metrics: Loss = 0.8785, accuracy = 0.6875, precision = 0.7867, recall = 0.7000, F1 score = 0.6976
# Adapt Time: 0.16837668418884277 s
# Support set metrics: Loss = 0.0625, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19346213340759277 s
# Support set metrics: Loss = 0.3667, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 423/600
# Adapt Time: 0.16750192642211914 s
# Support set metrics: Loss = 0.5030, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.21500754356384277 s
# Support set metrics: Loss = 1.5213, accuracy = 0.3750, precision = 0.2857, recall = 0.4000, F1 score = 0.3200
# Adapt Time: 0.19950270652770996 s
# Support set metrics: Loss = 0.9511, accuracy = 0.6250, precision = 0.5667, recall = 0.6500, F1 score = 0.6000
# Adapt Time: 0.17346477508544922 s
# Support set metrics: Loss = 0.0043, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.20946216583251953 s
# Support set metrics: Loss = 1.1019, accuracy = 0.5625, precision = 0.4833, recall = 0.5000, F1 score = 0.4600
# This is epoch 424/600
# Adapt Time: 0.16562294960021973 s
# Support set metrics: Loss = 0.1981, accuracy = 0.9375, precision = 1.0000, recall = 0.9375, F1 score = 0.9643
# Adapt Time: 0.19010019302368164 s
# Support set metrics: Loss = 0.6318, accuracy = 0.7500, precision = 0.7833, recall = 0.7667, F1 score = 0.7657
# Adapt Time: 0.1889793872833252 s
# Support set metrics: Loss = 0.8090, accuracy = 0.6250, precision = 0.6200, recall = 0.6167, F1 score = 0.5957
# Adapt Time: 0.16934609413146973 s
# Support set metrics: Loss = 0.0171, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19530034065246582 s
# Support set metrics: Loss = 0.9070, accuracy = 0.8125, precision = 0.7833, recall = 0.8000, F1 score = 0.7767
# This is epoch 425/600
# Adapt Time: 0.16696476936340332 s
# Support set metrics: Loss = 0.0998, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18524503707885742 s
# Support set metrics: Loss = 1.2011, accuracy = 0.5625, precision = 0.5200, recall = 0.5833, F1 score = 0.5100
# Adapt Time: 0.19139528274536133 s
# Support set metrics: Loss = 1.0304, accuracy = 0.7500, precision = 0.8000, recall = 0.7667, F1 score = 0.7505
# Adapt Time: 0.17197608947753906 s
# Support set metrics: Loss = 0.0052, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19038176536560059 s
# Support set metrics: Loss = 0.9899, accuracy = 0.6250, precision = 0.5000, recall = 0.5500, F1 score = 0.5167
# This is epoch 426/600
# Adapt Time: 0.16393065452575684 s
# Support set metrics: Loss = 0.1399, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.1852118968963623 s
# Support set metrics: Loss = 0.9581, accuracy = 0.6250, precision = 0.7633, recall = 0.6333, F1 score = 0.6381
# Adapt Time: 0.1920464038848877 s
# Support set metrics: Loss = 1.3501, accuracy = 0.5000, precision = 0.5000, recall = 0.5000, F1 score = 0.4895
# Adapt Time: 0.16941070556640625 s
# Support set metrics: Loss = 0.0458, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18837547302246094 s
# Support set metrics: Loss = 0.5302, accuracy = 0.8750, precision = 0.8167, recall = 0.8500, F1 score = 0.8133
# This is epoch 427/600
# Adapt Time: 0.16387677192687988 s
# Support set metrics: Loss = 0.3181, accuracy = 0.8750, precision = 0.8875, recall = 0.8750, F1 score = 0.8740
# Adapt Time: 0.19233274459838867 s
# Support set metrics: Loss = 0.8367, accuracy = 0.6875, precision = 0.7433, recall = 0.6667, F1 score = 0.6625
# Adapt Time: 0.21697402000427246 s
# Support set metrics: Loss = 0.7428, accuracy = 0.7500, precision = 0.8500, recall = 0.7333, F1 score = 0.7457
# Adapt Time: 0.17284345626831055 s
# Support set metrics: Loss = 0.0051, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19212603569030762 s
# Support set metrics: Loss = 1.3174, accuracy = 0.5625, precision = 0.5700, recall = 0.6000, F1 score = 0.5619
# This is epoch 428/600
# Adapt Time: 0.16736865043640137 s
# Support set metrics: Loss = 0.1171, accuracy = 0.9375, precision = 0.9500, recall = 0.9375, F1 score = 0.9365
# Adapt Time: 0.19509339332580566 s
# Support set metrics: Loss = 0.9624, accuracy = 0.6875, precision = 0.8000, recall = 0.6667, F1 score = 0.6867
# Adapt Time: 0.1939384937286377 s
# Support set metrics: Loss = 0.7178, accuracy = 0.6875, precision = 0.6867, recall = 0.6833, F1 score = 0.6681
# Adapt Time: 0.17131900787353516 s
# Support set metrics: Loss = 0.0072, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19956016540527344 s
# Support set metrics: Loss = 0.7500, accuracy = 0.6875, precision = 0.6833, recall = 0.6500, F1 score = 0.6433
# This is epoch 429/600
# Adapt Time: 0.16428756713867188 s
# Support set metrics: Loss = 0.4232, accuracy = 0.8750, precision = 0.9000, recall = 0.8750, F1 score = 0.8730
# Adapt Time: 0.18809866905212402 s
# Support set metrics: Loss = 1.2286, accuracy = 0.5625, precision = 0.4667, recall = 0.5500, F1 score = 0.5024
# Adapt Time: 0.21494746208190918 s
# Support set metrics: Loss = 1.1075, accuracy = 0.3125, precision = 0.2800, recall = 0.3000, F1 score = 0.2889
# Adapt Time: 0.17421793937683105 s
# Support set metrics: Loss = 0.0147, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19356679916381836 s
# Support set metrics: Loss = 0.4542, accuracy = 0.8750, precision = 0.9167, recall = 0.9000, F1 score = 0.8800
# This is epoch 430/600
# Adapt Time: 0.164139986038208 s
# Support set metrics: Loss = 0.3626, accuracy = 0.8750, precision = 0.9167, recall = 0.8750, F1 score = 0.8667
# Adapt Time: 0.20223283767700195 s
# Support set metrics: Loss = 0.8568, accuracy = 0.5625, precision = 0.6333, recall = 0.5667, F1 score = 0.5765
# Adapt Time: 0.19336271286010742 s
# Support set metrics: Loss = 1.0642, accuracy = 0.4375, precision = 0.4167, recall = 0.4333, F1 score = 0.3905
# Adapt Time: 0.1713721752166748 s
# Support set metrics: Loss = 0.0061, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19227838516235352 s
# Support set metrics: Loss = 0.6806, accuracy = 0.7500, precision = 0.6000, recall = 0.6000, F1 score = 0.6000
# This is epoch 431/600
# Adapt Time: 0.16537761688232422 s
# Support set metrics: Loss = 0.1243, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.21929264068603516 s
# Support set metrics: Loss = 0.9299, accuracy = 0.8125, precision = 0.8600, recall = 0.8000, F1 score = 0.7806
# Adapt Time: 0.1963367462158203 s
# Support set metrics: Loss = 1.0349, accuracy = 0.5625, precision = 0.5500, recall = 0.5500, F1 score = 0.5386
# Adapt Time: 0.16991186141967773 s
# Support set metrics: Loss = 0.0054, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.19457697868347168 s
# Support set metrics: Loss = 0.8959, accuracy = 0.8125, precision = 0.7667, recall = 0.8000, F1 score = 0.7633
# This is epoch 432/600
# Adapt Time: 0.16470098495483398 s
# Support set metrics: Loss = 0.0589, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.18287086486816406 s
# Support set metrics: Loss = 1.0603, accuracy = 0.4375, precision = 0.3500, recall = 0.4333, F1 score = 0.3857
# Adapt Time: 0.19827771186828613 s
# Support set metrics: Loss = 1.1756, accuracy = 0.6250, precision = 0.6700, recall = 0.6167, F1 score = 0.6000
# Adapt Time: 0.174515962600708 s
# Support set metrics: Loss = 0.0310, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.22835540771484375 s
# Support set metrics: Loss = 1.2627, accuracy = 0.6875, precision = 0.6667, recall = 0.7000, F1 score = 0.6633
# This is epoch 433/600
# Adapt Time: 0.16447806358337402 s
# Support set metrics: Loss = 0.0492, accuracy = 1.0000, precision = 1.0000, recall = 1.0000, F1 score = 1.0000
# Adapt Time: 0.1852715015411377 s
# Support set metrics: Loss = 0.8058, accuracy = 0.6250, precision = 0.7300, recall = 0.6167, F1 score = 0.6243
# Adapt Time: 0.21032309532165527 s

# %%
print("Support of each class: ")
for class_idx in range(len(memory_buffer.meta_score)):
    total_support = np.sum(memory_buffer.meta_score[class_idx, :TRIM_ER, 1])
    mean_support = np.mean(memory_buffer.meta_score[class_idx, :TRIM_ER, 1])
    print(f"\t#Class {class_idx}: {total_support} , Avg: {mean_support}")

# %%
print("Average Score of each class: ")
for class_idx in range(len(memory_buffer.meta_score)):
    #mean_score = np.mean(memory_buffer.meta_score[class_idx, ..., 0])
    mean_score = np.mean(memory_buffer.meta_score[class_idx][memory_buffer.meta_score[class_idx, ...,1] != 0][:TRIM_ER, 0])
    print(f"\tScore Class {class_idx}: {mean_score}")

# %%
print(memory_buffer.meta_score[0,:TRIM_ER,0].shape)
print(memory_buffer.meta_score[0,:TRIM_ER,0][memory_buffer.meta_score[0,:TRIM_ER,1] != 0].shape)

# %%
_model_path0 = os.path.splitext(model_path)[0]
MEMORY_SAVE_LOC = _model_path0 + "_memory_ss6.pickle"
pickle.dump( memory_buffer, open( MEMORY_SAVE_LOC, "wb" ), protocol=pickle.HIGHEST_PROTOCOL)
print(f"Done writing Memory Pickle File at {MEMORY_SAVE_LOC}")

# %%
# new_memory_path = "/data/model_runs/original_oml/aOML-order1-inlr010-2022-08-30-sr-query/OML-order1-id4-2022-08-30_05-21-18.854228_memory_ss4.pickle"
# with open(new_memory_path, 'rb') as f:
#     memory_buffer = pickle.load(f)

# %% [markdown]
# ### Plotting Distribution of Scores for each Class

# %%
class_idx = 1
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)

# %%
class_idx = 8
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)

# %%
class_idx = 30
#score_list = memory_buffer.meta_score[class_idx, ..., 0]
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,0][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)

# %% [markdown]
# ### Plotting Adapted Conf

# %%
class_idx = 30
# Remove the support = 0
score_list = memory_buffer.meta_score[class_idx,...,2][memory_buffer.meta_score[class_idx, ...,1] != 0]

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)

# %% [markdown]
# ### Plotting Distribution of Scores for one sample

# %%
class_idx = 0
sample_idx = 0
score_list = memory_buffer.meta_debug[class_idx][sample_idx]

print(f"#Scores in ScoreList {len(score_list)}")
print(f"# Score in sample_idx: {memory_buffer.meta_score[class_idx, sample_idx, 0]}")
print(f"# Support in sample_idx: {memory_buffer.meta_score[class_idx, sample_idx, 1]}")

fig, ax =  plt.subplots(figsize=(10,4))
ax.hist(score_list, bins=15)

# %%
memory_buffer.meta_debug[class_idx].keys()

# %% [markdown]
# # Testing
#
# Select specific column index per row
# https://stackoverflow.com/questions/23435782/numpy-selecting-specific-column-index-per-row-by-using-a-list-of-indexes

# %%
def evaluate(dataloader, updates, mini_batch_size, dataname=""):
    learner.rln.eval()
    learner.pln.train()
    
    all_losses, all_predictions, all_labels, all_label_conf = [], [], [], []
    all_adaptation_time = []
    # Get Query set first. and then find supporting support set
    for query_idx, (query_text, query_labels) in enumerate(dataloader):
        print(f"Query ID {query_idx}/{len(dataloader)}")
        # The task id to optimize to for support set
        # task_idx = get_task_from_label_list(query_labels, memory_buffer.task_dict)
        task_idx = dataclass_mapper[dataname]
        
    
        support_set = []
        for _ in range(updates):
            text, labels = memory_buffer.read_batch_task(batch_size=mini_batch_size, task_idx=task_idx, sort_score=True, \
                                                        sort_asc=True ) # this is changed!!!
            support_set.append((text, labels))

        with higher.innerloop_ctx(learner.pln, learner.inner_optimizer,
                                  copy_initial_weights=False, track_higher_grads=False) as (fpln, diffopt):
            
            INNER_tic = time.time()
            # Inner loop
            task_predictions, task_labels = [], []
            support_loss = []
            for text, labels in support_set:
                labels = torch.tensor(labels).to(device)
                input_dict = learner.rln.encode_text(text)
                _repr = learner.rln(input_dict)
                output = fpln(_repr)
                loss = learner.loss_fn(output, labels)
                diffopt.step(loss)
                pred = models.utils.make_prediction(output.detach())
                support_loss.append(loss.item())
                task_predictions.extend(pred.tolist())
                task_labels.extend(labels.tolist())
            INNER_toc = time.time() - INNER_tic
            all_adaptation_time.append(INNER_toc)

            acc, prec, rec, f1 = models.utils.calculate_metrics(task_predictions, task_labels)

            print('Support set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                        'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(support_loss), acc, prec, rec, f1))

            # Query set is now here!
            query_labels = torch.tensor(query_labels).to(device)
            query_input_dict = learner.rln.encode_text(query_text)
            with torch.no_grad():
                query_repr = learner.rln(query_input_dict)
                query_output = fpln(query_repr) # Output has size of torch.Size([16, 33]) [BATCH, CLASSES]
                query_loss = learner.loss_fn(query_output, query_labels)
            query_loss = query_loss.item()
            # print(output.detach().size())
            # output.detach().max(-1) max on each Batch, which will return [0] max, [1] indices
            query_output_softmax = F.softmax(query_output, -1)
            query_label_conf = query_output_softmax[np.arange(len(query_output_softmax)), query_labels] # Select labels in the softmax of 33 classes

            query_pred = models.utils.make_prediction(query_output.detach())
            query_acc, query_prec, query_rec, query_f1 = models.utils.calculate_metrics(query_pred.tolist(), query_labels.tolist())
            
            print('Query set metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, '
                'recall = {:.4f}, F1 score = {:.4f}'.format(np.mean(query_loss), query_acc, query_prec, query_rec, query_f1))

            all_losses.append(query_loss)
            all_predictions.extend(query_pred.tolist())
            all_labels.extend(query_labels.tolist())
            all_label_conf.extend(query_label_conf.tolist())

    acc, prec, rec, f1 = models.utils.calculate_metrics(all_predictions, all_labels)
    print('Test metrics: Loss = {:.4f}, accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
                'F1 score = {:.4f}'.format(np.mean(all_losses), acc, prec, rec, f1))
    return acc, prec, rec, f1, all_predictions, all_labels, all_label_conf, all_adaptation_time

# %%
tic = time.time()
print('----------Testing on test set starts here----------')

accuracies, precisions, recalls, f1s = [], [], [], []
all_adapt_time = []
# Data for Visualization: [data_idx, label, label_conf, pred]
data_for_visual = []

for test_dataset in test_datasets:
    print('Testing on {}'.format(test_dataset.__class__.__name__))
    test_dataloader = data.DataLoader(test_dataset, batch_size=mini_batch_size, shuffle=False,
                                      collate_fn=datasets.utils.batch_encode)
    acc, prec, rec, f1, all_pred, all_label, all_label_conf, all_adaptation_time = evaluate(dataloader=test_dataloader, updates=updates, 
                                                mini_batch_size=mini_batch_size, dataname=test_dataset.__class__.__name__)
    
    data_ids = [test_dataset.__class__.__name__ + str(i) for i in range(len(all_label))]
    data_for_visual.extend(list(zip(data_ids, all_label, all_label_conf, all_pred)))
    all_adapt_time.extend(all_adaptation_time)
#     print(data_ids)
#     print(all_label)
#     raise Exception("BREAKPOINT")
    
    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1s.append(f1)


print()
print("COPY PASTA - not really but ok")
for row in accuracies:
    print(row)
print()
print('Overall test metrics: Accuracy = {:.4f}, precision = {:.4f}, recall = {:.4f}, '
            'F1 score = {:.4f}'.format(np.mean(accuracies), np.mean(precisions), np.mean(recalls), np.mean(f1s)))

toc = time.time() - tic
print(f"Total Time used: {toc//60} minutes")

# %%
_model_path0 = os.path.splitext(model_path)[0]
csv_filename = _model_path0 + "_update"+ str(updates) +"_results_sr_ta_ss6.csv" # for selective replay
with open(csv_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["data_idx", "label", "label_conf", "pred"])
    csv_writer.writerows(data_for_visual)
print(f"Done writing CSV File at {csv_filename}")

# %%
# Log Time for Inference
_model_path0 = os.path.splitext(model_path)[0]
time_txt_filename = _model_path0 + "_update"+ str(updates) +"_time_inference_sr_ta_ss6.csv" 
with open(time_txt_filename, 'w') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["time_id", "time"])
    csv_writer.writerow(["Total Time", f"{toc//60} minutes"])
    csv_writer.writerow(["mean Adapt Time", f"{np.mean(all_adapt_time)} s"])
print(f"Done writing Time CSV File at {time_txt_filename}")
